# %% [markdown]
# <center><table>
#     <tr>
#         <th><img src="./INL1.png",align="middle",height="10000"/></th>
#         <th><img src="./MIT1.png",align="middle",height="10"\></th>
#         <th><img src="./ANL.png",align="middle",height="10"/></th>
#     </tr>
# </table>
# </center>

# %% [markdown]
# # <center>Cost Reduction Framework for the Sodium Fast Nuclear Reactor (SFR) Power Plant</center>
# # <center>Botros Hanna</center>

# %% [markdown]
# ## Section 0 : Essentials to Run the code

# %% [markdown]
# ### Section 0 - 1 : Importing the libraries

# %%
# Importing libararies
import pandas as pd
import numpy as np
from tabulate import tabulate
pd.set_option('mode.chained_assignment', None)
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_rows', None)
import re

# %% [markdown]
# ### Section 0 - 2 : Control the table style

# %%
def prettify(database1, caption, category):
    database1['Total Cost (USD)'] = database1['Total Cost (USD)'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Factory Equipment Cost'] = database1['Factory Equipment Cost'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Site Labor Cost'] = database1['Site Labor Cost'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Site Material Cost'] = database1['Site Material Cost'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Site Labor Hours'] =database1['Site Labor Hours'].apply(lambda x: '{:,.0f} hrs'.format(x))
    
    database1 = database1.fillna('') # remove nan
    database1= database1.replace({'$ nan':'', 'nan hrs':''}) # remove nan


    df_ = database1.loc[database1.Account.isin([10, 20, 30, 40, 50, 60])] # highlight high level accounts

    df_2 = database1.iloc[-10:] # final results
    
    df3 = pd.concat([df_, df_2])
    df4 = df_2 = database1.iloc[-2:]
    slice_ = pd.IndexSlice[df3.index, df3.columns]
    slice_2 = pd.IndexSlice[df4.index, df4.columns]


    
    slice_ = pd.IndexSlice[df3.index, df3.columns]
    slice_2 = pd.IndexSlice[df4.index, df4.columns]
    
    if category == "no_subsidies":
        database_styled = (database1.style.set_properties(**{'font-weight': 'bold'}, subset=slice_).set_properties(**{'color': 'white','background-color': 'white' }, subset=slice_2).set_caption(caption).set_table_styles([{'selector': 'caption','props': [('color', 'red'),('font-size', '20px')]}]))
            
    elif category == "subsidies":
        database_styled = (database1.style.set_properties(**{'font-weight': 'bold'}, subset=slice_).set_caption(caption).\
                           set_table_styles([{'selector': 'caption','props': [('color', 'red'),('font-size', '20px')]}]))
    
    return database_styled.hide()

def highlight_changes(row, baseline):
    return ['background-color: yellow' if val != baseline\
            and len(str(val))>0 and not (str(val)).startswith("Range")  else '' for val in row]

# %% [markdown]
# ### Section 0 - 3 : A function to update the cost summary table each time a change is made

# %%
# Update the high level costs in the database when changing the low level costs
reactor_power = 310.8 * 1000 # kw
def update_high_level_costs(db):
   
    # update total costs for accounts 21 : 26
    for x in [21, 22, 23, 24, 25, 26]: 
        (db.loc[db['Account'] == x, 'Total Cost (USD)']) = (db.loc[db['Account'] == x, 'Factory Equipment Cost'])+\
            (db.loc[db['Account'] == x, 'Site Labor Cost'])+ (db.loc[db['Account'] == x, 'Site Material Cost'])

    #update total costs for accounts 10
    (db.loc[db['Title'] == '10s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([11, 12, 13, 14, 15, 16, 17, 18]), 'Total Cost (USD)'].sum()
     
    # update total costs for accounts 20
    (db.loc[db['Title'] == '20s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([21, 22, 23, 24, 25, 26, 27, 28]), 'Total Cost (USD)'].sum()

    # update total costs for accounts 30
    (db.loc[db['Title'] == '30s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([31, 32, 33, 34, 35, 36, 37, 38]), 'Total Cost (USD)'].sum()

    # update total costs for accounts 40
    (db.loc[db['Title'] == '40s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([41, 42, 43, 44, 49]), 'Total Cost (USD)'].sum()

    # update total costs for accounts 50
    (db.loc[db['Title'] == '50s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([51, 52, 53, 54, 55, 58, 59]), 'Total Cost (USD)'].sum()

    # update total costs for accounts 60
    (db.loc[db['Title'] == '60s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([61, 62, 63, 69]), 'Total Cost (USD)'].sum()
    
    # uodate costs per kw
    
    
    (db.loc[db['Title'] == '10s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '10s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '20s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '20s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '30s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '30s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '40s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '40s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '50s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '50s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '60s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '60s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    
    
    
    # update final results
    (db.loc[db['Title'] == 'Total Direct Capital Cost (Accounts 10 to 20)', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == '10s - Subtotal', 'Total Cost (USD)']).values + (db.loc[db['Title'] == '20s - Subtotal', 'Total Cost (USD)']).values
    
    (db.loc[db['Title'] == 'Base Construction Cost (Accounts 10 to 30)', 'Total Cost (USD)']) =\
       (db.loc[db['Title'] == 'Total Direct Capital Cost (Accounts 10 to 20)', 'Total Cost (USD)']).values +\
        (db.loc[db['Title'] == '30s - Subtotal', 'Total Cost (USD)']).values

    (db.loc[db['Title'] == 'Total Overnight Cost (Accounts 10 to 50)', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Base Construction Cost (Accounts 10 to 30)', 'Total Cost (USD)']).values + \
        (db.loc[db['Title'] == '40s - Subtotal', 'Total Cost (USD)']).values+\
        (db.loc[db['Title'] == '50s - Subtotal', 'Total Cost (USD)']).values

    (db.loc[db['Title'] == 'Total Capital Investment Cost (Accounts 10 to 60)', 'Total Cost (USD)']) =\
       (db.loc[db['Title'] == 'Total Overnight Cost (Accounts 10 to 50)', 'Total Cost (USD)']).values +\
        (db.loc[db['Title'] == '60s - Subtotal', 'Total Cost (USD)']).values

   
    # update final results per kw
    (db.loc[db['Title'] == '(Accounts 10 to 20) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Total Direct Capital Cost (Accounts 10 to 20)', 'Total Cost (USD)']).values/reactor_power 

    (db.loc[db['Title'] == '(Accounts 10 to 30) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Base Construction Cost (Accounts 10 to 30)', 'Total Cost (USD)']).values/reactor_power 
   
    (db.loc[db['Title'] == '(Accounts 10 to 50) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Total Overnight Cost (Accounts 10 to 50)', 'Total Cost (USD)']).values/reactor_power 
    
    (db.loc[db['Title'] == '(Accounts 10 to 60) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Total Capital Investment Cost (Accounts 10 to 60)', 'Total Cost (USD)']).values/reactor_power

    	
    return db

# %% [markdown]
# ## Section 1 : Reading the Baseline SFR Cost Summary Table

# %%
# Reading excel or csv files
SFR_data_0 = pd.read_excel('SFR_allData.xlsx', sheet_name = "SA_Plus_MIT_Combined", nrows= 69)

db = pd.DataFrame()
db = SFR_data_0[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()
SFR_data = db
SFR_data_pretty = prettify(SFR_data, "SFR-FOAK Capital Cost Summary - Baseline hypothetical well-executeed project (duration = 64 months) ", "no_subsidies")
SFR_data_pretty
# Out:
# <style type="text/css">
# #T_68b92 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_68b92_row0_col0, #T_68b92_row0_col1, #T_68b92_row0_col2, #T_68b92_row0_col3, #T_68b92_row0_col4, #T_68b92_row0_col5, #T_68b92_row0_col6, #T_68b92_row12_col0, #T_68b92_row12_col1, #T_68b92_row12_col2, #T_68b92_row12_col3, #T_68b92_row12_col4, #T_68b92_row12_col5, #T_68b92_row12_col6, #T_68b92_row24_col0, #T_68b92_row24_col1, #T_68b92_row24_col2, #T_68b92_row24_col3, #T_68b92_row24_col4, #T_68b92_row24_col5, #T_68b92_row24_col6, #T_68b92_row36_col0, #T_68b92_row36_col1, #T_68b92_row36_col2, #T_68b92_row36_col3, #T_68b92_row36_col4, #T_68b92_row36_col5, #T_68b92_row36_col6, #T_68b92_row43_col0, #T_68b92_row43_col1, #T_68b92_row43_col2, #T_68b92_row43_col3, #T_68b92_row43_col4, #T_68b92_row43_col5, #T_68b92_row43_col6, #T_68b92_row52_col0, #T_68b92_row52_col1, #T_68b92_row52_col2, #T_68b92_row52_col3, #T_68b92_row52_col4, #T_68b92_row52_col5, #T_68b92_row52_col6, #T_68b92_row59_col0, #T_68b92_row59_col1, #T_68b92_row59_col2, #T_68b92_row59_col3, #T_68b92_row59_col4, #T_68b92_row59_col5, #T_68b92_row59_col6, #T_68b92_row60_col0, #T_68b92_row60_col1, #T_68b92_row60_col2, #T_68b92_row60_col3, #T_68b92_row60_col4, #T_68b92_row60_col5, #T_68b92_row60_col6, #T_68b92_row61_col0, #T_68b92_row61_col1, #T_68b92_row61_col2, #T_68b92_row61_col3, #T_68b92_row61_col4, #T_68b92_row61_col5, #T_68b92_row61_col6, #T_68b92_row62_col0, #T_68b92_row62_col1, #T_68b92_row62_col2, #T_68b92_row62_col3, #T_68b92_row62_col4, #T_68b92_row62_col5, #T_68b92_row62_col6, #T_68b92_row63_col0, #T_68b92_row63_col1, #T_68b92_row63_col2, #T_68b92_row63_col3, #T_68b92_row63_col4, #T_68b92_row63_col5, #T_68b92_row63_col6, #T_68b92_row64_col0, #T_68b92_row64_col1, #T_68b92_row64_col2, #T_68b92_row64_col3, #T_68b92_row64_col4, #T_68b92_row64_col5, #T_68b92_row64_col6, #T_68b92_row65_col0, #T_68b92_row65_col1, #T_68b92_row65_col2, #T_68b92_row65_col3, #T_68b92_row65_col4, #T_68b92_row65_col5, #T_68b92_row65_col6, #T_68b92_row66_col0, #T_68b92_row66_col1, #T_68b92_row66_col2, #T_68b92_row66_col3, #T_68b92_row66_col4, #T_68b92_row66_col5, #T_68b92_row66_col6 {
#   font-weight: bold;
# }
# #T_68b92_row67_col0, #T_68b92_row67_col1, #T_68b92_row67_col2, #T_68b92_row67_col3, #T_68b92_row67_col4, #T_68b92_row67_col5, #T_68b92_row67_col6, #T_68b92_row68_col0, #T_68b92_row68_col1, #T_68b92_row68_col2, #T_68b92_row68_col3, #T_68b92_row68_col4, #T_68b92_row68_col5, #T_68b92_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_68b92">
#   <caption>SFR-FOAK Capital Cost Summary - Baseline hypothetical well-executeed project (duration = 64 months) </caption>
#   <thead>
#     <tr>
#       <th id="T_68b92_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_68b92_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_68b92_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_68b92_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_68b92_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_68b92_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_68b92_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_68b92_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_68b92_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_68b92_row0_col2" class="data row0 col2" ></td>
#       <td id="T_68b92_row0_col3" class="data row0 col3" ></td>
#       <td id="T_68b92_row0_col4" class="data row0 col4" ></td>
#       <td id="T_68b92_row0_col5" class="data row0 col5" ></td>
#       <td id="T_68b92_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_68b92_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_68b92_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_68b92_row1_col3" class="data row1 col3" ></td>
#       <td id="T_68b92_row1_col4" class="data row1 col4" ></td>
#       <td id="T_68b92_row1_col5" class="data row1 col5" ></td>
#       <td id="T_68b92_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_68b92_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_68b92_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_68b92_row2_col3" class="data row2 col3" ></td>
#       <td id="T_68b92_row2_col4" class="data row2 col4" ></td>
#       <td id="T_68b92_row2_col5" class="data row2 col5" ></td>
#       <td id="T_68b92_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_68b92_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_68b92_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_68b92_row3_col3" class="data row3 col3" ></td>
#       <td id="T_68b92_row3_col4" class="data row3 col4" ></td>
#       <td id="T_68b92_row3_col5" class="data row3 col5" ></td>
#       <td id="T_68b92_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_68b92_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_68b92_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_68b92_row4_col3" class="data row4 col3" ></td>
#       <td id="T_68b92_row4_col4" class="data row4 col4" ></td>
#       <td id="T_68b92_row4_col5" class="data row4 col5" ></td>
#       <td id="T_68b92_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_68b92_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_68b92_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_68b92_row5_col3" class="data row5 col3" ></td>
#       <td id="T_68b92_row5_col4" class="data row5 col4" ></td>
#       <td id="T_68b92_row5_col5" class="data row5 col5" ></td>
#       <td id="T_68b92_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_68b92_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_68b92_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_68b92_row6_col3" class="data row6 col3" ></td>
#       <td id="T_68b92_row6_col4" class="data row6 col4" ></td>
#       <td id="T_68b92_row6_col5" class="data row6 col5" ></td>
#       <td id="T_68b92_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_68b92_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_68b92_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_68b92_row7_col3" class="data row7 col3" ></td>
#       <td id="T_68b92_row7_col4" class="data row7 col4" ></td>
#       <td id="T_68b92_row7_col5" class="data row7 col5" ></td>
#       <td id="T_68b92_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_68b92_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_68b92_row8_col2" class="data row8 col2" ></td>
#       <td id="T_68b92_row8_col3" class="data row8 col3" ></td>
#       <td id="T_68b92_row8_col4" class="data row8 col4" ></td>
#       <td id="T_68b92_row8_col5" class="data row8 col5" ></td>
#       <td id="T_68b92_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_68b92_row9_col0" class="data row9 col0" ></td>
#       <td id="T_68b92_row9_col1" class="data row9 col1" ></td>
#       <td id="T_68b92_row9_col2" class="data row9 col2" ></td>
#       <td id="T_68b92_row9_col3" class="data row9 col

# %% [markdown]
# ## Section - 2 : User Inputs

# %% [markdown]
# ### Section - 2 - 1 : User-defined Independent Variables (Global Levers)

# %%
## ## User-defined Independent Variables (Global Levers)

# This is a hypothetical well-executed project taking 64 months (TIMCAT simulation)
baseline_construction_duration = 64 # months

design_completion = 1  # 1 means 100%. This is not realistic. Cost increases occur because the design completion is less than 100%

#procurement service experience 
proc_exp = 2 # 2 means procurement experts. This is ideal. 


# Engineering & Construction service experience
ece = 2

# number of firm orders
num_orders = 1

# land cost
# From the SA report: the cost $22,000 per acre. The land area is 500 acres including recommended buffer
land_cost_per_acre =  0.8*22000 # dollars/acre


#investment tax credits subsidies
ITC  = 0 # 

# interest rate :
interest_rate = 0.04  # equals 5%. This is the baseline value in the SA report work

# Determining if the turbine and containemnt are non-nuclear or nuclear grade equipment 
naq_turbine = "non_nuclear"
naq_containment = "non_nuclear"

# modularization
mod = "stick_built"


# Design maturity
design_maturity = 2 # 0 if immature (never done). 2 if mature and ready. 1: in between

# th of a kind
n_th = 1


global_levers = pd.DataFrame()
global_levers.loc[:, 'Lever'] = ['Baseline Construction Duration (months)', 'Design Completion',\
                                 'Procurement service experience ','Engineering & Construction service experience',\
                                 'Number of firm orders',' Land Cost Per Acre (2023 USD)',\
                                'ITC ', ' Interest Rate', 'NQA-1 Turbine ', 'NQA-1 Containment', 'modulariziation',\
                                 "design maturity" , "#th of a kind"]

global_levers.loc[:, 'User-Input Value'] = [baseline_construction_duration, design_completion, proc_exp, ece, num_orders, 
                                            land_cost_per_acre, ITC, interest_rate, naq_turbine , naq_containment, mod,\
                                            design_maturity, n_th] 

global_levers.loc[:, 'Lever baseline value (for a hopothetical well-executed project)'] = [64, 1, 5, 5, 1, 22000, 0, 0.05 ,\
                                                                                           'nuclear', 'nuclear', "stick_built", 2, 1 ]

global_levers.loc[:, 'Range'] = ['30 - 130', '0 - 1', '1 - 5', '1 - 5', '0 - 10', '1000 - 100000', '0 - 0.5', '0 - 0.3',\
                                 "nuclear or non-nuclear", "nuclear or non-nuclear",  'stick_built or modularized', '0 : 2',
                                '1 - 1000']



global_levers_changes = global_levers[global_levers['User-Input Value'] != global_levers['Lever baseline value (for a hopothetical well-executed project)']]

slice_ = pd.IndexSlice[global_levers_changes .index, global_levers_changes .columns]
global_levers_styled = (global_levers.style.set_properties(**{'background-color': 'yellow'}, subset=slice_ )\
                            .set_caption("User-Input Global levers <br> (highlighted in yellow if different from the baseline)")\
                        .set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'red'),
        ('font-size', '20px')
    ]
}]))


global_levers_styled.hide()
# Out:
# <style type="text/css">
# #T_20c68 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_20c68_row1_col0, #T_20c68_row1_col1, #T_20c68_row1_col2, #T_20c68_row1_col3, #T_20c68_row2_col0, #T_20c68_row2_col1, #T_20c68_row2_col2, #T_20c68_row2_col3, #T_20c68_row3_col0, #T_20c68_row3_col1, #T_20c68_row3_col2, #T_20c68_row3_col3, #T_20c68_row4_col0, #T_20c68_row4_col1, #T_20c68_row4_col2, #T_20c68_row4_col3, #T_20c68_row5_col0, #T_20c68_row5_col1, #T_20c68_row5_col2, #T_20c68_row5_col3, #T_20c68_row6_col0, #T_20c68_row6_col1, #T_20c68_row6_col2, #T_20c68_row6_col3, #T_20c68_row7_col0, #T_20c68_row7_col1, #T_20c68_row7_col2, #T_20c68_row7_col3, #T_20c68_row8_col0, #T_20c68_row8_col1, #T_20c68_row8_col2, #T_20c68_row8_col3, #T_20c68_row9_col0, #T_20c68_row9_col1, #T_20c68_row9_col2, #T_20c68_row9_col3, #T_20c68_row12_col0, #T_20c68_row12_col1, #T_20c68_row12_col2, #T_20c68_row12_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_20c68">
#   <caption>User-Input Global levers <br> (highlighted in yellow if different from the baseline)</caption>
#   <thead>
#     <tr>
#       <th id="T_20c68_level0_col0" class="col_heading level0 col0" >Lever</th>
#       <th id="T_20c68_level0_col1" class="col_heading level0 col1" >User-Input Value</th>
#       <th id="T_20c68_level0_col2" class="col_heading level0 col2" >Lever baseline value (for a hopothetical well-executed project)</th>
#       <th id="T_20c68_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_20c68_row0_col0" class="data row0 col0" >Baseline Construction Duration (months)</td>
#       <td id="T_20c68_row0_col1" class="data row0 col1" >64</td>
#       <td id="T_20c68_row0_col2" class="data row0 col2" >64</td>
#       <td id="T_20c68_row0_col3" class="data row0 col3" >30 - 130</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row1_col0" class="data row1 col0" >Design Completion</td>
#       <td id="T_20c68_row1_col1" class="data row1 col1" >0.500000</td>
#       <td id="T_20c68_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_20c68_row1_col3" class="data row1 col3" >0 - 1</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row2_col0" class="data row2 col0" >Procurement service experience </td>
#       <td id="T_20c68_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_20c68_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_20c68_row2_col3" class="data row2 col3" >1 - 5</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row3_col0" class="data row3 col0" >Engineering & Construction service experience</td>
#       <td id="T_20c68_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_20c68_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_20c68_row3_col3" class="data row3 col3" >1 - 5</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row4_col0" class="data row4 col0" >Number of firm orders</td>
#       <td id="T_20c68_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_20c68_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_20c68_row4_col3" class="data row4 col3" >0 - 10</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row5_col0" class="data row5 col0" > Land Cost Per Acre (2023 USD)</td>
#       <td id="T_20c68_row5_col1" class="data row5 col1" >17600.000000</td>
#       <td id="T_20c68_row5_col2" class="data row5 col2" >22000</td>
#       <td id="T_20c68_row5_col3" class="data row5 col3" >1000 - 100000</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row6_col0" class="data row6 col0" >ITC </td>
#       <td id="T_20c68_row6_col1" class="data row6 col1" >0.400000</td>
#       <td id="T_20c68_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_20c68_row6_col3" class="data row6 col3" >0 - 0.5</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row7_col0" class="data row7 col0" > Interest Rate</td>
#       <td id="T_20c68_row7_col1" class="data row7 col1" >0.040000</td>
#       <td id="T_20c68_row7_col2" class="data row7 col2" >0.050000</td>
#       <td id="T_20c68_row7_col3" class="data row7 col3" >0 - 0.3</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row8_col0" class="data row8 col0" >NQA-1 Turbine </td>
#       <td id="T_20c68_row8_col1" class="data row8 col1" >non_nuclear</td>
#       <td id="T_20c68_row8_col2" class="data row8 col2" >nuclear</td>
#       <td id="T_20c68_row8_col3" class="data row8 col3" >nuclear or non-nuclear</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row9_col0" class="data row9 col0" >NQA-1 Containment</td>
#       <td id="T_20c68_row9_col1" class="data row9 col1" >non_nuclear</td>
#       <td id="T_20c68_row9_col2" class="data row9 col2" >nuclear</td>
#       <td id="T_20c68_row9_col3" class="data row9 col3" >nuclear or non-nuclear</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row10_col0" class="data row10 col0" >modulariziation</td>
#       <td id="T_20c68_row10_col1" class="data row10 col1" >stick_built</td>
#       <td id="T_20c68_row10_col2" class="data row10 col2" >stick_built</td>
#       <td id="T_20c68_row10_col3" class="data row10 col3" >stick_built or modularized</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row11_col0" class="data row11 col0" >design maturity</td>
#       <td id="T_20c68_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_20c68_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_20c68_row11_col3" class="data row11 col3" >0 : 2</td>
#     </tr>
#     <tr>
#       <td id="T_20c68_row12_col0" class="data row12 col0" >#th of a kind</td>
#       <td id="T_20c68_row12_col1" class="data row12 col1" >100</td>
#       <td id="T_20c68_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_20c68_row12_col3" class="data row12 col3" >1 - 1000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Section - 2 - 2 : User-defined Account-Based Variables

# %%
# Creating the table for the account based variables
accounts_vars = pd.DataFrame()
accounts_vars.loc[:, 'Account'] = SFR_data.loc[:, 'Account']
accounts_vars.loc[:, 'Title'] = SFR_data.loc[:, 'Title']


accounts_vars["Vol Production Learning Rate"] = None
accounts_vars["FOAK Delays (months)"] = None
accounts_vars["Task Acceleration factor"] = None
accounts_vars["Supply Chain Delay factor"] = None
accounts_vars["Labor Productivity Factor"] = None

accounts_vars = accounts_vars.loc[accounts_vars['Account'].isin([21, 22, 23, 24, 25, 26])]


# Assigning independent account-based variables
accounts_vars['Vol Production Learning Rate'] = [0.05, 0.25, 0, 0.2, 0, 0.15] 
accounts_vars['FOAK Delays (months)'] = [1, 2, 3, 0, 0, 0]

# task acceleration = 1 means no change. Task acceleration = 0.5 means the labor hours decreases by half (optimistic scenario)
accounts_vars['Task Acceleration factor'] = [1, 1, 1, 1, 1, 1] 


# Assigning dependent account-based variables

# supply chain delay factor = f(Procurement service experience level)
# The delay factor = 2 if the experience level = 1  && The delay factor = 1 if the experience level = 5
# Therefore, we can formulate a simple equation
# supply chain delay factor  = 0.25*(9 - Procurement service experience level )
supply_chain_delay_factor_1= 0.25*(9 - proc_exp)

# supply chain delay is also a function of the design maturity as follows
# - Supply chain delays - (0 - 2x supplychain delays, 1 - 1.5x supplychain delays, 2 - no effect on supplychain delays) 
if design_maturity == 0:
    supply_chain_delay_factor_2 = 2 
elif design_maturity == 1:    
    supply_chain_delay_factor_2 = 1.5 
elif design_maturity == 2:
    supply_chain_delay_factor_2 = 1 

supply_chain_delay_factor = min (supply_chain_delay_factor_1*supply_chain_delay_factor_2, 2)
accounts_vars['Supply Chain Delay factor']  = supply_chain_delay_factor


# labor productivity factor = f(engineering and construction experience level)
# labor productivity factor = 0.2 if the experience level = 1  && labor productivity factor =  = 1 if the experience level = 5
# Therefore, we can formulate a simple equation
#labor productivity factor  = 0.2* engineering and construction experience leve

accounts_vars['Labor Productivity Factor'] = 0.2*ece 


accounts_vars.loc[len(accounts_vars)] = pd.Series(dtype='float64')
accounts_vars = accounts_vars.fillna('') # remove nan

accounts_vars.loc[len(accounts_vars.index)] = \
    ['', 'Baseline Value = ', 0, 0, 1, 1, 0] 

accounts_vars.loc[len(accounts_vars.index)] = \
    ['', ' ', "Range = 0 : 1", "Range = 0 : 100", "Range = 0.5 : 1","Range = 1 : 2", "Range = 0 : 1"]  




accounts_vars_styled = accounts_vars.style.apply(highlight_changes, axis=1, subset=pd.IndexSlice[:, ['Vol Production Learning Rate']], baseline =0)\
    .apply(highlight_changes, axis=1, subset=pd.IndexSlice[:, ['FOAK Delays (months)']], baseline =0)\
    .apply(highlight_changes, axis=1, subset=pd.IndexSlice[:, ['Task Acceleration factor']], baseline =1)\
    .apply(highlight_changes, axis=1, subset=pd.IndexSlice[:, ['Supply Chain Delay factor']], baseline =1)\
    .apply(highlight_changes, axis=1, subset=pd.IndexSlice[:, ['Labor Productivity Factor']], baseline =0)\
    .set_caption("User-Input Account-Based levers <br> (highlighted in yellow if different from the baseline)").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'red'),
        ('font-size', '20px')
    ]}])
accounts_vars_styled.hide()
# Out:
# <style type="text/css">
# #T_f14b0 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_f14b0_row0_col2, #T_f14b0_row0_col3, #T_f14b0_row0_col5, #T_f14b0_row0_col6, #T_f14b0_row1_col2, #T_f14b0_row1_col3, #T_f14b0_row1_col5, #T_f14b0_row1_col6, #T_f14b0_row2_col3, #T_f14b0_row2_col5, #T_f14b0_row2_col6, #T_f14b0_row3_col2, #T_f14b0_row3_col5, #T_f14b0_row3_col6, #T_f14b0_row4_col5, #T_f14b0_row4_col6, #T_f14b0_row5_col2, #T_f14b0_row5_col5, #T_f14b0_row5_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f14b0">
#   <caption>User-Input Account-Based levers <br> (highlighted in yellow if different from the baseline)</caption>
#   <thead>
#     <tr>
#       <th id="T_f14b0_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_f14b0_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_f14b0_level0_col2" class="col_heading level0 col2" >Vol Production Learning Rate</th>
#       <th id="T_f14b0_level0_col3" class="col_heading level0 col3" >FOAK Delays (months)</th>
#       <th id="T_f14b0_level0_col4" class="col_heading level0 col4" >Task Acceleration factor</th>
#       <th id="T_f14b0_level0_col5" class="col_heading level0 col5" >Supply Chain Delay factor</th>
#       <th id="T_f14b0_level0_col6" class="col_heading level0 col6" >Labor Productivity Factor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f14b0_row0_col0" class="data row0 col0" >21</td>
#       <td id="T_f14b0_row0_col1" class="data row0 col1" >Structures & Improvements</td>
#       <td id="T_f14b0_row0_col2" class="data row0 col2" >0.050000</td>
#       <td id="T_f14b0_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_f14b0_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_f14b0_row0_col5" class="data row0 col5" >1.500000</td>
#       <td id="T_f14b0_row0_col6" class="data row0 col6" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_f14b0_row1_col1" class="data row1 col1" >Reactor System</td>
#       <td id="T_f14b0_row1_col2" class="data row1 col2" >0.250000</td>
#       <td id="T_f14b0_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_f14b0_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_f14b0_row1_col5" class="data row1 col5" >1.500000</td>
#       <td id="T_f14b0_row1_col6" class="data row1 col6" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_f14b0_row2_col1" class="data row2 col1" >Energy Conversion System</td>
#       <td id="T_f14b0_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_f14b0_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_f14b0_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_f14b0_row2_col5" class="data row2 col5" >1.500000</td>
#       <td id="T_f14b0_row2_col6" class="data row2 col6" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_f14b0_row3_col1" class="data row3 col1" >Electrical Equipment</td>
#       <td id="T_f14b0_row3_col2" class="data row3 col2" >0.200000</td>
#       <td id="T_f14b0_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_f14b0_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_f14b0_row3_col5" class="data row3 col5" >1.500000</td>
#       <td id="T_f14b0_row3_col6" class="data row3 col6" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row4_col0" class="data row4 col0" >25</td>
#       <td id="T_f14b0_row4_col1" class="data row4 col1" >Heat Rejection System</td>
#       <td id="T_f14b0_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_f14b0_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_f14b0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f14b0_row4_col5" class="data row4 col5" >1.500000</td>
#       <td id="T_f14b0_row4_col6" class="data row4 col6" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row5_col0" class="data row5 col0" >26</td>
#       <td id="T_f14b0_row5_col1" class="data row5 col1" >Miscellaneous Equipment</td>
#       <td id="T_f14b0_row5_col2" class="data row5 col2" >0.150000</td>
#       <td id="T_f14b0_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_f14b0_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_f14b0_row5_col5" class="data row5 col5" >1.500000</td>
#       <td id="T_f14b0_row5_col6" class="data row5 col6" >0.800000</td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row6_col0" class="data row6 col0" ></td>
#       <td id="T_f14b0_row6_col1" class="data row6 col1" ></td>
#       <td id="T_f14b0_row6_col2" class="data row6 col2" ></td>
#       <td id="T_f14b0_row6_col3" class="data row6 col3" ></td>
#       <td id="T_f14b0_row6_col4" class="data row6 col4" ></td>
#       <td id="T_f14b0_row6_col5" class="data row6 col5" ></td>
#       <td id="T_f14b0_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row7_col0" class="data row7 col0" ></td>
#       <td id="T_f14b0_row7_col1" class="data row7 col1" >Baseline Value = </td>
#       <td id="T_f14b0_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_f14b0_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_f14b0_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_f14b0_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_f14b0_row7_col6" class="data row7 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_f14b0_row8_col0" class="data row8 col0" ></td>
#       <td id="T_f14b0_row8_col1" class="data row8 col1" > </td>
#       <td id="T_f14b0_row8_col2" class="data row8 col2" >Range = 0 : 1</td>
#       <td id="T_f14b0_row8_col3" class="data row8 col3" >Range = 0 : 100</td>
#       <td id="T_f14b0_row8_col4" class="data row8 col4" >Range = 0.5 : 1</td>
#       <td id="T_f14b0_row8_col5" class="data row8 col5" >Range = 1 : 2</td>
#       <td id="T_f14b0_row8_col6" class="data row8 col6" >Range = 0 : 1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Section - 2 - 3 : Cost reduction framework
#
# <center><table>
#     <tr>
#         <th><img src="./diagram.png",align="middle",height="10000"/></th>
#     </tr>
# </table>
# </center>

# %% [markdown]
# ## Section - 3 : Updating the Cost Summary based on user inputs

# %% [markdown]
# ### Section 3-1 : The land cost

# %%
# The cost of the land is 22000$ per acre (500 acres
# The cost is multiplied by the new $/acre divided by the old one
# Accounts 11 and 12 are changed


db = pd.DataFrame()
db = SFR_data_0[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()


db.loc[db.Account == 11, 'Total Cost (USD)'] = None # clear old values
db.loc[db.Account == 12, 'Total Cost (USD)'] = None # clear old values

db.loc[db.Account == 11, 'Total Cost (USD)'] = (land_cost_per_acre /22000)*(SFR_data_0.loc[SFR_data_0.Account == 11, 'Total Cost (USD)'].values)
db.loc[db.Account == 12, 'Total Cost (USD)'] = (land_cost_per_acre /22000)*(SFR_data_0.loc[SFR_data_0.Account == 12, 'Total Cost (USD)'].values)

SFR_data_updated_1 = update_high_level_costs(db)


SFR_data_updated_1_ = pd.DataFrame()
SFR_data_updated_1_ = SFR_data_updated_1[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_1_pretty = prettify(SFR_data_updated_1_, "SFR-FOAK Capital Cost Summary - Updated ", 'no_subsidies')

SFR_data_updated_1_pretty
# Out:
# <style type="text/css">
# #T_688be caption {
#   color: red;
#   font-size: 20px;
# }
# #T_688be_row0_col0, #T_688be_row0_col1, #T_688be_row0_col2, #T_688be_row0_col3, #T_688be_row0_col4, #T_688be_row0_col5, #T_688be_row0_col6, #T_688be_row12_col0, #T_688be_row12_col1, #T_688be_row12_col2, #T_688be_row12_col3, #T_688be_row12_col4, #T_688be_row12_col5, #T_688be_row12_col6, #T_688be_row24_col0, #T_688be_row24_col1, #T_688be_row24_col2, #T_688be_row24_col3, #T_688be_row24_col4, #T_688be_row24_col5, #T_688be_row24_col6, #T_688be_row36_col0, #T_688be_row36_col1, #T_688be_row36_col2, #T_688be_row36_col3, #T_688be_row36_col4, #T_688be_row36_col5, #T_688be_row36_col6, #T_688be_row43_col0, #T_688be_row43_col1, #T_688be_row43_col2, #T_688be_row43_col3, #T_688be_row43_col4, #T_688be_row43_col5, #T_688be_row43_col6, #T_688be_row52_col0, #T_688be_row52_col1, #T_688be_row52_col2, #T_688be_row52_col3, #T_688be_row52_col4, #T_688be_row52_col5, #T_688be_row52_col6, #T_688be_row59_col0, #T_688be_row59_col1, #T_688be_row59_col2, #T_688be_row59_col3, #T_688be_row59_col4, #T_688be_row59_col5, #T_688be_row59_col6, #T_688be_row60_col0, #T_688be_row60_col1, #T_688be_row60_col2, #T_688be_row60_col3, #T_688be_row60_col4, #T_688be_row60_col5, #T_688be_row60_col6, #T_688be_row61_col0, #T_688be_row61_col1, #T_688be_row61_col2, #T_688be_row61_col3, #T_688be_row61_col4, #T_688be_row61_col5, #T_688be_row61_col6, #T_688be_row62_col0, #T_688be_row62_col1, #T_688be_row62_col2, #T_688be_row62_col3, #T_688be_row62_col4, #T_688be_row62_col5, #T_688be_row62_col6, #T_688be_row63_col0, #T_688be_row63_col1, #T_688be_row63_col2, #T_688be_row63_col3, #T_688be_row63_col4, #T_688be_row63_col5, #T_688be_row63_col6, #T_688be_row64_col0, #T_688be_row64_col1, #T_688be_row64_col2, #T_688be_row64_col3, #T_688be_row64_col4, #T_688be_row64_col5, #T_688be_row64_col6, #T_688be_row65_col0, #T_688be_row65_col1, #T_688be_row65_col2, #T_688be_row65_col3, #T_688be_row65_col4, #T_688be_row65_col5, #T_688be_row65_col6, #T_688be_row66_col0, #T_688be_row66_col1, #T_688be_row66_col2, #T_688be_row66_col3, #T_688be_row66_col4, #T_688be_row66_col5, #T_688be_row66_col6 {
#   font-weight: bold;
# }
# #T_688be_row67_col0, #T_688be_row67_col1, #T_688be_row67_col2, #T_688be_row67_col3, #T_688be_row67_col4, #T_688be_row67_col5, #T_688be_row67_col6, #T_688be_row68_col0, #T_688be_row68_col1, #T_688be_row68_col2, #T_688be_row68_col3, #T_688be_row68_col4, #T_688be_row68_col5, #T_688be_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_688be">
#   <caption>SFR-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_688be_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_688be_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_688be_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_688be_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_688be_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_688be_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_688be_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_688be_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_688be_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_688be_row0_col2" class="data row0 col2" ></td>
#       <td id="T_688be_row0_col3" class="data row0 col3" ></td>
#       <td id="T_688be_row0_col4" class="data row0 col4" ></td>
#       <td id="T_688be_row0_col5" class="data row0 col5" ></td>
#       <td id="T_688be_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_688be_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_688be_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_688be_row1_col3" class="data row1 col3" ></td>
#       <td id="T_688be_row1_col4" class="data row1 col4" ></td>
#       <td id="T_688be_row1_col5" class="data row1 col5" ></td>
#       <td id="T_688be_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_688be_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_688be_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_688be_row2_col3" class="data row2 col3" ></td>
#       <td id="T_688be_row2_col4" class="data row2 col4" ></td>
#       <td id="T_688be_row2_col5" class="data row2 col5" ></td>
#       <td id="T_688be_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_688be_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_688be_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_688be_row3_col3" class="data row3 col3" ></td>
#       <td id="T_688be_row3_col4" class="data row3 col4" ></td>
#       <td id="T_688be_row3_col5" class="data row3 col5" ></td>
#       <td id="T_688be_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_688be_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_688be_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_688be_row4_col3" class="data row4 col3" ></td>
#       <td id="T_688be_row4_col4" class="data row4 col4" ></td>
#       <td id="T_688be_row4_col5" class="data row4 col5" ></td>
#       <td id="T_688be_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_688be_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_688be_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_688be_row5_col3" class="data row5 col3" ></td>
#       <td id="T_688be_row5_col4" class="data row5 col4" ></td>
#       <td id="T_688be_row5_col5" class="data row5 col5" ></td>
#       <td id="T_688be_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_688be_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_688be_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_688be_row6_col3" class="data row6 col3" ></td>
#       <td id="T_688be_row6_col4" class="data row6 col4" ></td>
#       <td id="T_688be_row6_col5" class="data row6 col5" ></td>
#       <td id="T_688be_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_688be_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_688be_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_688be_row7_col3" class="data row7 col3" ></td>
#       <td id="T_688be_row7_col4" class="data row7 col4" ></td>
#       <td id="T_688be_row7_col5" class="data row7 col5" ></td>
#       <td id="T_688be_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_688be_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_688be_row8_col2" class="data row8 col2" ></td>
#       <td id="T_688be_row8_col3" class="data row8 col3" ></td>
#       <td id="T_688be_row8_col4" class="data row8 col4" ></td>
#       <td id="T_688be_row8_col5" class="data row8 col5" ></td>
#       <td id="T_688be_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_688be_row9_col0" class="data row9 col0" ></td>
#       <td id="T_688be_row9_col1" class="data row9 col1" ></td>
#       <td id="T_688be_row9_col2" class="data row9 col2" ></td>
#       <td id="T_688be_row9_col3" class="data row9 col3" ></td>
#       <td id="T_688be_row9_col4" class="data row9 c

# %% [markdown]
# ### Section 3-2 : Factory equipment cost reduction due to firm ordering

# %%
# The change in factory equipment cost due to LR and number of orders
# cost reduction factor = (1 - Learning rate)^(log2(N))
db = pd.DataFrame()

db = SFR_data_updated_1[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

for x in [21, 22, 23, 24, 25, 26]:  
    db.loc[db.Account == x, 'Factory Equipment Cost'] = None # clear old values


for x in [21, 22, 23, 24, 25, 26]: 
    if num_orders == 0:
        reduction_factor = 1 # no reduction
    else:    
        reduction_factor = (1 - (accounts_vars.loc[accounts_vars['Account'] == x, 'Vol Production Learning Rate']).values)**np.log2(num_orders)

    # cost reduction factor multiplied by factory cost
    db.loc[db.Account == x, 'Factory Equipment Cost'] =\
        ((( SFR_data_updated_1.loc[ SFR_data_updated_1.Account == x, 'Factory Equipment Cost']).values)[0])*reduction_factor

SFR_data_updated_2 = update_high_level_costs(db)

SFR_data_updated_2_ = pd.DataFrame()
SFR_data_updated_2_ = SFR_data_updated_2[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()
SFR_data_updated_2_pretty = prettify(SFR_data_updated_2_, "SFR-FOAK Capital Cost Summary - Updated", "no_subsidies")
SFR_data_updated_2_pretty
# Out:
# <style type="text/css">
# #T_dbc4e caption {
#   color: red;
#   font-size: 20px;
# }
# #T_dbc4e_row0_col0, #T_dbc4e_row0_col1, #T_dbc4e_row0_col2, #T_dbc4e_row0_col3, #T_dbc4e_row0_col4, #T_dbc4e_row0_col5, #T_dbc4e_row0_col6, #T_dbc4e_row12_col0, #T_dbc4e_row12_col1, #T_dbc4e_row12_col2, #T_dbc4e_row12_col3, #T_dbc4e_row12_col4, #T_dbc4e_row12_col5, #T_dbc4e_row12_col6, #T_dbc4e_row24_col0, #T_dbc4e_row24_col1, #T_dbc4e_row24_col2, #T_dbc4e_row24_col3, #T_dbc4e_row24_col4, #T_dbc4e_row24_col5, #T_dbc4e_row24_col6, #T_dbc4e_row36_col0, #T_dbc4e_row36_col1, #T_dbc4e_row36_col2, #T_dbc4e_row36_col3, #T_dbc4e_row36_col4, #T_dbc4e_row36_col5, #T_dbc4e_row36_col6, #T_dbc4e_row43_col0, #T_dbc4e_row43_col1, #T_dbc4e_row43_col2, #T_dbc4e_row43_col3, #T_dbc4e_row43_col4, #T_dbc4e_row43_col5, #T_dbc4e_row43_col6, #T_dbc4e_row52_col0, #T_dbc4e_row52_col1, #T_dbc4e_row52_col2, #T_dbc4e_row52_col3, #T_dbc4e_row52_col4, #T_dbc4e_row52_col5, #T_dbc4e_row52_col6, #T_dbc4e_row59_col0, #T_dbc4e_row59_col1, #T_dbc4e_row59_col2, #T_dbc4e_row59_col3, #T_dbc4e_row59_col4, #T_dbc4e_row59_col5, #T_dbc4e_row59_col6, #T_dbc4e_row60_col0, #T_dbc4e_row60_col1, #T_dbc4e_row60_col2, #T_dbc4e_row60_col3, #T_dbc4e_row60_col4, #T_dbc4e_row60_col5, #T_dbc4e_row60_col6, #T_dbc4e_row61_col0, #T_dbc4e_row61_col1, #T_dbc4e_row61_col2, #T_dbc4e_row61_col3, #T_dbc4e_row61_col4, #T_dbc4e_row61_col5, #T_dbc4e_row61_col6, #T_dbc4e_row62_col0, #T_dbc4e_row62_col1, #T_dbc4e_row62_col2, #T_dbc4e_row62_col3, #T_dbc4e_row62_col4, #T_dbc4e_row62_col5, #T_dbc4e_row62_col6, #T_dbc4e_row63_col0, #T_dbc4e_row63_col1, #T_dbc4e_row63_col2, #T_dbc4e_row63_col3, #T_dbc4e_row63_col4, #T_dbc4e_row63_col5, #T_dbc4e_row63_col6, #T_dbc4e_row64_col0, #T_dbc4e_row64_col1, #T_dbc4e_row64_col2, #T_dbc4e_row64_col3, #T_dbc4e_row64_col4, #T_dbc4e_row64_col5, #T_dbc4e_row64_col6, #T_dbc4e_row65_col0, #T_dbc4e_row65_col1, #T_dbc4e_row65_col2, #T_dbc4e_row65_col3, #T_dbc4e_row65_col4, #T_dbc4e_row65_col5, #T_dbc4e_row65_col6, #T_dbc4e_row66_col0, #T_dbc4e_row66_col1, #T_dbc4e_row66_col2, #T_dbc4e_row66_col3, #T_dbc4e_row66_col4, #T_dbc4e_row66_col5, #T_dbc4e_row66_col6 {
#   font-weight: bold;
# }
# #T_dbc4e_row67_col0, #T_dbc4e_row67_col1, #T_dbc4e_row67_col2, #T_dbc4e_row67_col3, #T_dbc4e_row67_col4, #T_dbc4e_row67_col5, #T_dbc4e_row67_col6, #T_dbc4e_row68_col0, #T_dbc4e_row68_col1, #T_dbc4e_row68_col2, #T_dbc4e_row68_col3, #T_dbc4e_row68_col4, #T_dbc4e_row68_col5, #T_dbc4e_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_dbc4e">
#   <caption>SFR-FOAK Capital Cost Summary - Updated</caption>
#   <thead>
#     <tr>
#       <th id="T_dbc4e_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_dbc4e_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_dbc4e_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_dbc4e_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_dbc4e_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_dbc4e_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_dbc4e_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dbc4e_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_dbc4e_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_dbc4e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_dbc4e_row0_col3" class="data row0 col3" ></td>
#       <td id="T_dbc4e_row0_col4" class="data row0 col4" ></td>
#       <td id="T_dbc4e_row0_col5" class="data row0 col5" ></td>
#       <td id="T_dbc4e_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_dbc4e_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_dbc4e_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_dbc4e_row1_col3" class="data row1 col3" ></td>
#       <td id="T_dbc4e_row1_col4" class="data row1 col4" ></td>
#       <td id="T_dbc4e_row1_col5" class="data row1 col5" ></td>
#       <td id="T_dbc4e_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_dbc4e_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_dbc4e_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_dbc4e_row2_col3" class="data row2 col3" ></td>
#       <td id="T_dbc4e_row2_col4" class="data row2 col4" ></td>
#       <td id="T_dbc4e_row2_col5" class="data row2 col5" ></td>
#       <td id="T_dbc4e_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_dbc4e_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_dbc4e_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_dbc4e_row3_col3" class="data row3 col3" ></td>
#       <td id="T_dbc4e_row3_col4" class="data row3 col4" ></td>
#       <td id="T_dbc4e_row3_col5" class="data row3 col5" ></td>
#       <td id="T_dbc4e_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_dbc4e_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_dbc4e_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_dbc4e_row4_col3" class="data row4 col3" ></td>
#       <td id="T_dbc4e_row4_col4" class="data row4 col4" ></td>
#       <td id="T_dbc4e_row4_col5" class="data row4 col5" ></td>
#       <td id="T_dbc4e_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_dbc4e_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_dbc4e_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_dbc4e_row5_col3" class="data row5 col3" ></td>
#       <td id="T_dbc4e_row5_col4" class="data row5 col4" ></td>
#       <td id="T_dbc4e_row5_col5" class="data row5 col5" ></td>
#       <td id="T_dbc4e_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_dbc4e_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_dbc4e_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_dbc4e_row6_col3" class="data row6 col3" ></td>
#       <td id="T_dbc4e_row6_col4" class="data row6 col4" ></td>
#       <td id="T_dbc4e_row6_col5" class="data row6 col5" ></td>
#       <td id="T_dbc4e_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_dbc4e_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_dbc4e_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_dbc4e_row7_col3" class="data row7 col3" ></td>
#       <td id="T_dbc4e_row7_col4" class="data row7 col4" ></td>
#       <td id="T_dbc4e_row7_col5" class="data row7 col5" ></td>
#       <td id="T_dbc4e_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_dbc4e_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_dbc4e_row8_col2" class="data row8 col2" ></td>
#       <td id="T_dbc4e_row8_col3" class="data row8 col3" ></td>
#       <td id="T_dbc4e_row8_col4" class="data row8 col4" ></td>
#       <td id="T_dbc4e_row8_col5" class="data row8 col5" ></td>
#       <td id="T_dbc4e_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_dbc4e_row9_col0" class="data row9 col0" ></td>
#       <td id="T_dbc4e_row9_col1" class="data row9 col1" ></td>
#       <td id="T_dbc4e_row9_col2" class="data row9 col2" ></td>
#       <td id="T_dbc4e_row9_col3" class="data row9 col3" ></td>
#       <td id="T_dbc4e_row9_col4" class="data row9 co

# %% [markdown]
# ### Section 3-3 : Whether the containment and turbine are nuclear grade equipment

# %%
# If nuclear, the materials cost is 50% higher, the labor cost is 30% higher
# if non-nuclear, the cost reduction factors for the materials and labor are 0.67 and 0.77 respectively
db = pd.DataFrame()

db = SFR_data_updated_2[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

db.loc[db.Account == 21, 'Site Material Cost'] = None # clear old values
db.loc[db.Account == 21, 'Site Labor Cost'] = None # clear old values
db.loc[db.Account ==  21, 'Site Labor Hours'] = None
db.loc[db.Account ==  23, 'Site Material Cost'] = None
db.loc[db.Account ==  23, 'Site Labor Cost']  = None
db.loc[db.Account ==  23, 'Site Labor Hours'] = None

if naq_containment == "non_nuclear":
    db.loc[db.Account == 21, 'Site Material Cost'] = 0.67*((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 21, 'Site Material Cost']).values)
    db.loc[db.Account == 21, 'Site Labor Cost'] = 0.77*((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 21, 'Site Labor Cost']).values)
    db.loc[db.Account == 21,'Site Labor Hours'] = 0.77*((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 21, 'Site Labor Hours']).values)

else:
    db.loc[db.Account == 21, 'Site Material Cost'] = ((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 21, 'Site Material Cost']).values)
    db.loc[db.Account == 21, 'Site Labor Cost'] = ((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 21, 'Site Labor Cost']).values)
    db.loc[db.Account == 21,'Site Labor Hours'] = ((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 21, 'Site Labor Hours']).values)

if naq_turbine == "non_nuclear":
    db.loc[db.Account == 23, 'Site Material Cost'] = 0.67*((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 23, 'Site Material Cost']).values)
    db.loc[db.Account == 23, 'Site Labor Cost'] = 0.77*((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 23, 'Site Labor Cost']).values)
    db.loc[db.Account == 23, 'Site Labor Hours'] = 0.77*((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 23, 'Site Labor Hours']).values)

else:
    db.loc[db.Account == 23, 'Site Material Cost'] = ((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 23, 'Site Material Cost']).values)
    db.loc[db.Account == 23, 'Site Labor Cost'] = ((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 23, 'Site Labor Cost']).values)
    db.loc[db.Account == 23, 'Site Labor Hours'] = ((SFR_data_updated_2.loc[SFR_data_updated_2.Account == 23, 'Site Labor Hours']).values)
db

SFR_data_updated_3 = update_high_level_costs(db)

SFR_data_updated_3_ = pd.DataFrame()
SFR_data_updated_3_ = SFR_data_updated_3[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_3_pretty = prettify(SFR_data_updated_3_, "SFR-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
SFR_data_updated_3_pretty
# Out:
# <style type="text/css">
# #T_8760f caption {
#   color: red;
#   font-size: 20px;
# }
# #T_8760f_row0_col0, #T_8760f_row0_col1, #T_8760f_row0_col2, #T_8760f_row0_col3, #T_8760f_row0_col4, #T_8760f_row0_col5, #T_8760f_row0_col6, #T_8760f_row12_col0, #T_8760f_row12_col1, #T_8760f_row12_col2, #T_8760f_row12_col3, #T_8760f_row12_col4, #T_8760f_row12_col5, #T_8760f_row12_col6, #T_8760f_row24_col0, #T_8760f_row24_col1, #T_8760f_row24_col2, #T_8760f_row24_col3, #T_8760f_row24_col4, #T_8760f_row24_col5, #T_8760f_row24_col6, #T_8760f_row36_col0, #T_8760f_row36_col1, #T_8760f_row36_col2, #T_8760f_row36_col3, #T_8760f_row36_col4, #T_8760f_row36_col5, #T_8760f_row36_col6, #T_8760f_row43_col0, #T_8760f_row43_col1, #T_8760f_row43_col2, #T_8760f_row43_col3, #T_8760f_row43_col4, #T_8760f_row43_col5, #T_8760f_row43_col6, #T_8760f_row52_col0, #T_8760f_row52_col1, #T_8760f_row52_col2, #T_8760f_row52_col3, #T_8760f_row52_col4, #T_8760f_row52_col5, #T_8760f_row52_col6, #T_8760f_row59_col0, #T_8760f_row59_col1, #T_8760f_row59_col2, #T_8760f_row59_col3, #T_8760f_row59_col4, #T_8760f_row59_col5, #T_8760f_row59_col6, #T_8760f_row60_col0, #T_8760f_row60_col1, #T_8760f_row60_col2, #T_8760f_row60_col3, #T_8760f_row60_col4, #T_8760f_row60_col5, #T_8760f_row60_col6, #T_8760f_row61_col0, #T_8760f_row61_col1, #T_8760f_row61_col2, #T_8760f_row61_col3, #T_8760f_row61_col4, #T_8760f_row61_col5, #T_8760f_row61_col6, #T_8760f_row62_col0, #T_8760f_row62_col1, #T_8760f_row62_col2, #T_8760f_row62_col3, #T_8760f_row62_col4, #T_8760f_row62_col5, #T_8760f_row62_col6, #T_8760f_row63_col0, #T_8760f_row63_col1, #T_8760f_row63_col2, #T_8760f_row63_col3, #T_8760f_row63_col4, #T_8760f_row63_col5, #T_8760f_row63_col6, #T_8760f_row64_col0, #T_8760f_row64_col1, #T_8760f_row64_col2, #T_8760f_row64_col3, #T_8760f_row64_col4, #T_8760f_row64_col5, #T_8760f_row64_col6, #T_8760f_row65_col0, #T_8760f_row65_col1, #T_8760f_row65_col2, #T_8760f_row65_col3, #T_8760f_row65_col4, #T_8760f_row65_col5, #T_8760f_row65_col6, #T_8760f_row66_col0, #T_8760f_row66_col1, #T_8760f_row66_col2, #T_8760f_row66_col3, #T_8760f_row66_col4, #T_8760f_row66_col5, #T_8760f_row66_col6 {
#   font-weight: bold;
# }
# #T_8760f_row67_col0, #T_8760f_row67_col1, #T_8760f_row67_col2, #T_8760f_row67_col3, #T_8760f_row67_col4, #T_8760f_row67_col5, #T_8760f_row67_col6, #T_8760f_row68_col0, #T_8760f_row68_col1, #T_8760f_row68_col2, #T_8760f_row68_col3, #T_8760f_row68_col4, #T_8760f_row68_col5, #T_8760f_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_8760f">
#   <caption>SFR-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_8760f_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_8760f_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_8760f_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_8760f_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_8760f_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_8760f_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_8760f_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8760f_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_8760f_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_8760f_row0_col2" class="data row0 col2" ></td>
#       <td id="T_8760f_row0_col3" class="data row0 col3" ></td>
#       <td id="T_8760f_row0_col4" class="data row0 col4" ></td>
#       <td id="T_8760f_row0_col5" class="data row0 col5" ></td>
#       <td id="T_8760f_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_8760f_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_8760f_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_8760f_row1_col3" class="data row1 col3" ></td>
#       <td id="T_8760f_row1_col4" class="data row1 col4" ></td>
#       <td id="T_8760f_row1_col5" class="data row1 col5" ></td>
#       <td id="T_8760f_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_8760f_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_8760f_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_8760f_row2_col3" class="data row2 col3" ></td>
#       <td id="T_8760f_row2_col4" class="data row2 col4" ></td>
#       <td id="T_8760f_row2_col5" class="data row2 col5" ></td>
#       <td id="T_8760f_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_8760f_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_8760f_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_8760f_row3_col3" class="data row3 col3" ></td>
#       <td id="T_8760f_row3_col4" class="data row3 col4" ></td>
#       <td id="T_8760f_row3_col5" class="data row3 col5" ></td>
#       <td id="T_8760f_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_8760f_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_8760f_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_8760f_row4_col3" class="data row4 col3" ></td>
#       <td id="T_8760f_row4_col4" class="data row4 col4" ></td>
#       <td id="T_8760f_row4_col5" class="data row4 col5" ></td>
#       <td id="T_8760f_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_8760f_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_8760f_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_8760f_row5_col3" class="data row5 col3" ></td>
#       <td id="T_8760f_row5_col4" class="data row5 col4" ></td>
#       <td id="T_8760f_row5_col5" class="data row5 col5" ></td>
#       <td id="T_8760f_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_8760f_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_8760f_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_8760f_row6_col3" class="data row6 col3" ></td>
#       <td id="T_8760f_row6_col4" class="data row6 col4" ></td>
#       <td id="T_8760f_row6_col5" class="data row6 col5" ></td>
#       <td id="T_8760f_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_8760f_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_8760f_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_8760f_row7_col3" class="data row7 col3" ></td>
#       <td id="T_8760f_row7_col4" class="data row7 col4" ></td>
#       <td id="T_8760f_row7_col5" class="data row7 col5" ></td>
#       <td id="T_8760f_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_8760f_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_8760f_row8_col2" class="data row8 col2" ></td>
#       <td id="T_8760f_row8_col3" class="data row8 col3" ></td>
#       <td id="T_8760f_row8_col4" class="data row8 col4" ></td>
#       <td id="T_8760f_row8_col5" class="data row8 col5" ></td>
#       <td id="T_8760f_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8760f_row9_col0" class="data row9 col0" ></td>
#       <td id="T_8760f_row9_col1" class="data row9 col1" ></td>
#       <td id="T_8760f_row9_col2" class="data row9 col2" ></td>
#       <td id="T_8760f_row9_col3" class="data row9 col3" ></td>
#       <td id="T_8760f_row9_col4" class="data row9 c

# %% [markdown]
# ### Section 3-4 :  The change in the labor hours (and labor cost) under Account 20 due to multiple factors

# %%
# The change in the labor hours under Account 20 due to 4 factors
# 1- task acceleration factor #(if <1, the labor hours decrease per account. if 0.5, labor hours are divided by 2
# 2- supply chain delay factor,  #if 1, no change, if 1.5, labor hours increase by 50%
# 3- labor producitivy factor,  # if 1, perfect scenario, if <1, labor hours increase
# 4- FOAK delays (months)

# The first three factors can be lumped together in one multiplier
# multiplier = (Task Acceleration factor * supply chain delay factor)/labor producitivy factor



# change in labor hours due to the FOAK delays (months)
# The current labor hours are based on a total construction duration of 64 month. 
#Therefore, the labor hours per each account will be multiplied by (64 + FOAK delay) / 64

db = pd.DataFrame()
db = SFR_data_updated_3[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()


# clear old values
for x in [21, 22, 23, 24, 25, 26]: 
    db.loc[db.Account == x, 'Site Labor Hours'] = None
    db.loc[db.Account == x, 'Site Labor Cost']  = None
    

for x in [21, 22, 23, 24, 25, 26]: 
    multiplier = ((accounts_vars.loc[accounts_vars['Account'] == x, 'Task Acceleration factor']).values)*\
        ((accounts_vars.loc[accounts_vars['Account'] == x, 'Supply Chain Delay factor']).values)/\
        ((accounts_vars.loc[accounts_vars['Account'] == x, 'Labor Productivity Factor']).values)
    
    multiplier_FOAK = (((accounts_vars.loc[accounts_vars['Account'] == x, 'FOAK Delays (months)']).values) +\
        baseline_construction_duration)/ baseline_construction_duration


    db.loc[db.Account == x, 'Site Labor Hours'] =  ((SFR_data_updated_3.loc[ SFR_data_updated_3.Account == x, 'Site Labor Hours']).values)\
        *multiplier*multiplier_FOAK

    #  # labor cost will increase due to increaseing labor hours

    db.loc[db.Account == x, 'Site Labor Cost'] =  (( SFR_data_updated_3.loc[ SFR_data_updated_3.Account == x, 'Site Labor Cost']).values)\
        *multiplier*multiplier_FOAK


SFR_data_updated_4 = update_high_level_costs(db)

SFR_data_updated_4_ = pd.DataFrame()
SFR_data_updated_4_ = SFR_data_updated_4[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_4_pretty = prettify(SFR_data_updated_4_, "SFR-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
SFR_data_updated_4_pretty
# Out:
# <style type="text/css">
# #T_1f7ff caption {
#   color: red;
#   font-size: 20px;
# }
# #T_1f7ff_row0_col0, #T_1f7ff_row0_col1, #T_1f7ff_row0_col2, #T_1f7ff_row0_col3, #T_1f7ff_row0_col4, #T_1f7ff_row0_col5, #T_1f7ff_row0_col6, #T_1f7ff_row12_col0, #T_1f7ff_row12_col1, #T_1f7ff_row12_col2, #T_1f7ff_row12_col3, #T_1f7ff_row12_col4, #T_1f7ff_row12_col5, #T_1f7ff_row12_col6, #T_1f7ff_row24_col0, #T_1f7ff_row24_col1, #T_1f7ff_row24_col2, #T_1f7ff_row24_col3, #T_1f7ff_row24_col4, #T_1f7ff_row24_col5, #T_1f7ff_row24_col6, #T_1f7ff_row36_col0, #T_1f7ff_row36_col1, #T_1f7ff_row36_col2, #T_1f7ff_row36_col3, #T_1f7ff_row36_col4, #T_1f7ff_row36_col5, #T_1f7ff_row36_col6, #T_1f7ff_row43_col0, #T_1f7ff_row43_col1, #T_1f7ff_row43_col2, #T_1f7ff_row43_col3, #T_1f7ff_row43_col4, #T_1f7ff_row43_col5, #T_1f7ff_row43_col6, #T_1f7ff_row52_col0, #T_1f7ff_row52_col1, #T_1f7ff_row52_col2, #T_1f7ff_row52_col3, #T_1f7ff_row52_col4, #T_1f7ff_row52_col5, #T_1f7ff_row52_col6, #T_1f7ff_row59_col0, #T_1f7ff_row59_col1, #T_1f7ff_row59_col2, #T_1f7ff_row59_col3, #T_1f7ff_row59_col4, #T_1f7ff_row59_col5, #T_1f7ff_row59_col6, #T_1f7ff_row60_col0, #T_1f7ff_row60_col1, #T_1f7ff_row60_col2, #T_1f7ff_row60_col3, #T_1f7ff_row60_col4, #T_1f7ff_row60_col5, #T_1f7ff_row60_col6, #T_1f7ff_row61_col0, #T_1f7ff_row61_col1, #T_1f7ff_row61_col2, #T_1f7ff_row61_col3, #T_1f7ff_row61_col4, #T_1f7ff_row61_col5, #T_1f7ff_row61_col6, #T_1f7ff_row62_col0, #T_1f7ff_row62_col1, #T_1f7ff_row62_col2, #T_1f7ff_row62_col3, #T_1f7ff_row62_col4, #T_1f7ff_row62_col5, #T_1f7ff_row62_col6, #T_1f7ff_row63_col0, #T_1f7ff_row63_col1, #T_1f7ff_row63_col2, #T_1f7ff_row63_col3, #T_1f7ff_row63_col4, #T_1f7ff_row63_col5, #T_1f7ff_row63_col6, #T_1f7ff_row64_col0, #T_1f7ff_row64_col1, #T_1f7ff_row64_col2, #T_1f7ff_row64_col3, #T_1f7ff_row64_col4, #T_1f7ff_row64_col5, #T_1f7ff_row64_col6, #T_1f7ff_row65_col0, #T_1f7ff_row65_col1, #T_1f7ff_row65_col2, #T_1f7ff_row65_col3, #T_1f7ff_row65_col4, #T_1f7ff_row65_col5, #T_1f7ff_row65_col6, #T_1f7ff_row66_col0, #T_1f7ff_row66_col1, #T_1f7ff_row66_col2, #T_1f7ff_row66_col3, #T_1f7ff_row66_col4, #T_1f7ff_row66_col5, #T_1f7ff_row66_col6 {
#   font-weight: bold;
# }
# #T_1f7ff_row67_col0, #T_1f7ff_row67_col1, #T_1f7ff_row67_col2, #T_1f7ff_row67_col3, #T_1f7ff_row67_col4, #T_1f7ff_row67_col5, #T_1f7ff_row67_col6, #T_1f7ff_row68_col0, #T_1f7ff_row68_col1, #T_1f7ff_row68_col2, #T_1f7ff_row68_col3, #T_1f7ff_row68_col4, #T_1f7ff_row68_col5, #T_1f7ff_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_1f7ff">
#   <caption>SFR-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_1f7ff_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_1f7ff_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_1f7ff_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_1f7ff_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_1f7ff_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_1f7ff_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_1f7ff_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1f7ff_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_1f7ff_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_1f7ff_row0_col2" class="data row0 col2" ></td>
#       <td id="T_1f7ff_row0_col3" class="data row0 col3" ></td>
#       <td id="T_1f7ff_row0_col4" class="data row0 col4" ></td>
#       <td id="T_1f7ff_row0_col5" class="data row0 col5" ></td>
#       <td id="T_1f7ff_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_1f7ff_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_1f7ff_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_1f7ff_row1_col3" class="data row1 col3" ></td>
#       <td id="T_1f7ff_row1_col4" class="data row1 col4" ></td>
#       <td id="T_1f7ff_row1_col5" class="data row1 col5" ></td>
#       <td id="T_1f7ff_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_1f7ff_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_1f7ff_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_1f7ff_row2_col3" class="data row2 col3" ></td>
#       <td id="T_1f7ff_row2_col4" class="data row2 col4" ></td>
#       <td id="T_1f7ff_row2_col5" class="data row2 col5" ></td>
#       <td id="T_1f7ff_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_1f7ff_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_1f7ff_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_1f7ff_row3_col3" class="data row3 col3" ></td>
#       <td id="T_1f7ff_row3_col4" class="data row3 col4" ></td>
#       <td id="T_1f7ff_row3_col5" class="data row3 col5" ></td>
#       <td id="T_1f7ff_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_1f7ff_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_1f7ff_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_1f7ff_row4_col3" class="data row4 col3" ></td>
#       <td id="T_1f7ff_row4_col4" class="data row4 col4" ></td>
#       <td id="T_1f7ff_row4_col5" class="data row4 col5" ></td>
#       <td id="T_1f7ff_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_1f7ff_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_1f7ff_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_1f7ff_row5_col3" class="data row5 col3" ></td>
#       <td id="T_1f7ff_row5_col4" class="data row5 col4" ></td>
#       <td id="T_1f7ff_row5_col5" class="data row5 col5" ></td>
#       <td id="T_1f7ff_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_1f7ff_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_1f7ff_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_1f7ff_row6_col3" class="data row6 col3" ></td>
#       <td id="T_1f7ff_row6_col4" class="data row6 col4" ></td>
#       <td id="T_1f7ff_row6_col5" class="data row6 col5" ></td>
#       <td id="T_1f7ff_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_1f7ff_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_1f7ff_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_1f7ff_row7_col3" class="data row7 col3" ></td>
#       <td id="T_1f7ff_row7_col4" class="data row7 col4" ></td>
#       <td id="T_1f7ff_row7_col5" class="data row7 col5" ></td>
#       <td id="T_1f7ff_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_1f7ff_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_1f7ff_row8_col2" class="data row8 col2" ></td>
#       <td id="T_1f7ff_row8_col3" class="data row8 col3" ></td>
#       <td id="T_1f7ff_row8_col4" class="data row8 col4" ></td>
#       <td id="T_1f7ff_row8_col5" class="data row8 col5" ></td>
#       <td id="T_1f7ff_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_1f7ff_row9_col0" class="data row9 col0" ></td>
#       <td id="T_1f7ff_row9_col1" class="data row9 col1" ></td>
#       <td id="T_1f7ff_row9_col2" class="data row9 col2" ></td>
#       <td id="T_1f7ff_row9_col3" class="data row9 col3" ></td>
#       <td id="T_1f7ff_row9_col4" class="data row9 c

# %% [markdown]
# ### Section 3-5 :  Updating the construction duration and Indirect Cost

# %%
# Construction duration: Use Vogtle example - 2x duration for 50% design completion. 1x duration for 100% design completion. 
# we derive a simple equation: construction duration multiplier = 3 -2 * design completion
# note that design completion ranges from 0 to 1

actual_construction_duration = baseline_construction_duration*(3 - 2*design_completion)


#sum of labor hours for Account 20 in the initial estimation (well exectued scenario)
sum_old = (SFR_data_0.loc[SFR_data_0.Account == 21, 'Site Labor Hours']).values +\
(SFR_data_0.loc[SFR_data_0.Account == 22, 'Site Labor Hours']).values +\
(SFR_data_0.loc[SFR_data_0.Account == 23, 'Site Labor Hours']).values+\
(SFR_data_0.loc[SFR_data_0.Account == 24, 'Site Labor Hours']).values+\
(SFR_data_0.loc[SFR_data_0.Account == 25, 'Site Labor Hours']).values+\
(SFR_data_0.loc[SFR_data_0.Account == 26, 'Site Labor Hours']).values



#sum of labor hours for Account 20 in the new estimation (well exectued scenario)
db = SFR_data_updated_4 
sum_new = (db.loc[db.Account == 21, 'Site Labor Hours']).values +\
(db.loc[db.Account == 22, 'Site Labor Hours']).values +\
(db.loc[db.Account == 23, 'Site Labor Hours']).values+\
(db.loc[db.Account == 24, 'Site Labor Hours']).values+\
(db.loc[db.Account == 25, 'Site Labor Hours']).values+\
(db.loc[db.Account == 26, 'Site Labor Hours']).values



# # change in labor hours for account 20
change = (sum_new - sum_old)/sum_old   # note that this number can be positive or negative


# # From EPRI 2019 report, the decrease in total hours to 50$ leads to 24% decrease in construction timeline.
# # so I assume that the change in the construction timeline equals 50% of the the change in the total labor hours

construction_duration_change = 0.5*change  *baseline_construction_duration

final_construction_duration = (actual_construction_duration + construction_duration_change)[0]

print("\nThe actual construction duration is estimated to be : ", int(final_construction_duration), "months\n") 

# # From the TIMCAT simulation, the indirect cost changes almost linearly by 28% if the number of construction duration increased from 64 to 100 months
# # Using this, we can derive a simple equation :
# # Indirect cost / Indirect cost (well exectued scenario : 64 months)  =  0.0081* construction duration + 0.4627
# we assume that all the subaccounts under the indriect cost will increae by the same ratio
# # upadting the indirect cost as follows
indirect_cost_multiplier = 0.0081*final_construction_duration + 0.4627


# create new database to add the new costs
# all the subaccounts under the indirect cost are increased equally
db = pd.DataFrame()
db = SFR_data_updated_4[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

for x in [31, 32, 33, 34 ,35, 36, 37, 38]: 
    db.loc[db.Account == x, 'Total Cost (USD)'] = None

for x in [31, 32, 33, 34 ,35, 36, 37, 38]:
    db.loc[db.Account == x, 'Total Cost (USD)'] =  indirect_cost_multiplier*SFR_data_updated_4.loc[ SFR_data_updated_4.Account == x, 'Total Cost (USD)'] 



SFR_data_updated_5 = update_high_level_costs(db)

SFR_data_updated_5_ = pd.DataFrame()
SFR_data_updated_5_ = SFR_data_updated_5[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_5_pretty = prettify(SFR_data_updated_5_, "SFR-FOAK Capital Cost Summary - Updated ", "no_subsidies")
SFR_data_updated_5_pretty
# Out:
# The actual construction duration is estimated to be :  149 months
# <style type="text/css">
# #T_b2a69 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_b2a69_row0_col0, #T_b2a69_row0_col1, #T_b2a69_row0_col2, #T_b2a69_row0_col3, #T_b2a69_row0_col4, #T_b2a69_row0_col5, #T_b2a69_row0_col6, #T_b2a69_row12_col0, #T_b2a69_row12_col1, #T_b2a69_row12_col2, #T_b2a69_row12_col3, #T_b2a69_row12_col4, #T_b2a69_row12_col5, #T_b2a69_row12_col6, #T_b2a69_row24_col0, #T_b2a69_row24_col1, #T_b2a69_row24_col2, #T_b2a69_row24_col3, #T_b2a69_row24_col4, #T_b2a69_row24_col5, #T_b2a69_row24_col6, #T_b2a69_row36_col0, #T_b2a69_row36_col1, #T_b2a69_row36_col2, #T_b2a69_row36_col3, #T_b2a69_row36_col4, #T_b2a69_row36_col5, #T_b2a69_row36_col6, #T_b2a69_row43_col0, #T_b2a69_row43_col1, #T_b2a69_row43_col2, #T_b2a69_row43_col3, #T_b2a69_row43_col4, #T_b2a69_row43_col5, #T_b2a69_row43_col6, #T_b2a69_row52_col0, #T_b2a69_row52_col1, #T_b2a69_row52_col2, #T_b2a69_row52_col3, #T_b2a69_row52_col4, #T_b2a69_row52_col5, #T_b2a69_row52_col6, #T_b2a69_row59_col0, #T_b2a69_row59_col1, #T_b2a69_row59_col2, #T_b2a69_row59_col3, #T_b2a69_row59_col4, #T_b2a69_row59_col5, #T_b2a69_row59_col6, #T_b2a69_row60_col0, #T_b2a69_row60_col1, #T_b2a69_row60_col2, #T_b2a69_row60_col3, #T_b2a69_row60_col4, #T_b2a69_row60_col5, #T_b2a69_row60_col6, #T_b2a69_row61_col0, #T_b2a69_row61_col1, #T_b2a69_row61_col2, #T_b2a69_row61_col3, #T_b2a69_row61_col4, #T_b2a69_row61_col5, #T_b2a69_row61_col6, #T_b2a69_row62_col0, #T_b2a69_row62_col1, #T_b2a69_row62_col2, #T_b2a69_row62_col3, #T_b2a69_row62_col4, #T_b2a69_row62_col5, #T_b2a69_row62_col6, #T_b2a69_row63_col0, #T_b2a69_row63_col1, #T_b2a69_row63_col2, #T_b2a69_row63_col3, #T_b2a69_row63_col4, #T_b2a69_row63_col5, #T_b2a69_row63_col6, #T_b2a69_row64_col0, #T_b2a69_row64_col1, #T_b2a69_row64_col2, #T_b2a69_row64_col3, #T_b2a69_row64_col4, #T_b2a69_row64_col5, #T_b2a69_row64_col6, #T_b2a69_row65_col0, #T_b2a69_row65_col1, #T_b2a69_row65_col2, #T_b2a69_row65_col3, #T_b2a69_row65_col4, #T_b2a69_row65_col5, #T_b2a69_row65_col6, #T_b2a69_row66_col0, #T_b2a69_row66_col1, #T_b2a69_row66_col2, #T_b2a69_row66_col3, #T_b2a69_row66_col4, #T_b2a69_row66_col5, #T_b2a69_row66_col6 {
#   font-weight: bold;
# }
# #T_b2a69_row67_col0, #T_b2a69_row67_col1, #T_b2a69_row67_col2, #T_b2a69_row67_col3, #T_b2a69_row67_col4, #T_b2a69_row67_col5, #T_b2a69_row67_col6, #T_b2a69_row68_col0, #T_b2a69_row68_col1, #T_b2a69_row68_col2, #T_b2a69_row68_col3, #T_b2a69_row68_col4, #T_b2a69_row68_col5, #T_b2a69_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_b2a69">
#   <caption>SFR-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_b2a69_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_b2a69_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_b2a69_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_b2a69_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_b2a69_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_b2a69_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_b2a69_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b2a69_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_b2a69_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_b2a69_row0_col2" class="data row0 col2" ></td>
#       <td id="T_b2a69_row0_col3" class="data row0 col3" ></td>
#       <td id="T_b2a69_row0_col4" class="data row0 col4" ></td>
#       <td id="T_b2a69_row0_col5" class="data row0 col5" ></td>
#       <td id="T_b2a69_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_b2a69_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_b2a69_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_b2a69_row1_col3" class="data row1 col3" ></td>
#       <td id="T_b2a69_row1_col4" class="data row1 col4" ></td>
#       <td id="T_b2a69_row1_col5" class="data row1 col5" ></td>
#       <td id="T_b2a69_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_b2a69_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_b2a69_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_b2a69_row2_col3" class="data row2 col3" ></td>
#       <td id="T_b2a69_row2_col4" class="data row2 col4" ></td>
#       <td id="T_b2a69_row2_col5" class="data row2 col5" ></td>
#       <td id="T_b2a69_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_b2a69_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_b2a69_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_b2a69_row3_col3" class="data row3 col3" ></td>
#       <td id="T_b2a69_row3_col4" class="data row3 col4" ></td>
#       <td id="T_b2a69_row3_col5" class="data row3 col5" ></td>
#       <td id="T_b2a69_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_b2a69_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_b2a69_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_b2a69_row4_col3" class="data row4 col3" ></td>
#       <td id="T_b2a69_row4_col4" class="data row4 col4" ></td>
#       <td id="T_b2a69_row4_col5" class="data row4 col5" ></td>
#       <td id="T_b2a69_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_b2a69_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_b2a69_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_b2a69_row5_col3" class="data row5 col3" ></td>
#       <td id="T_b2a69_row5_col4" class="data row5 col4" ></td>
#       <td id="T_b2a69_row5_col5" class="data row5 col5" ></td>
#       <td id="T_b2a69_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_b2a69_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_b2a69_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_b2a69_row6_col3" class="data row6 col3" ></td>
#       <td id="T_b2a69_row6_col4" class="data row6 col4" ></td>
#       <td id="T_b2a69_row6_col5" class="data row6 col5" ></td>
#       <td id="T_b2a69_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_b2a69_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_b2a69_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_b2a69_row7_col3" class="data row7 col3" ></td>
#       <td id="T_b2a69_row7_col4" class="data row7 col4" ></td>
#       <td id="T_b2a69_row7_col5" class="data row7 col5" ></td>
#       <td id="T_b2a69_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_b2a69_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_b2a69_row8_col2" class="data row8 col2" ></td>
#       <td id="T_b2a69_row8_col3" class="data row8 col3" ></td>
#       <td id="T_b2a69_row8_col4" class="data row8 col4" ></td>
#       <td id="T_b2a69_row8_col5" class="data row8 col5" ></td>
#       <td id="T_b2a69_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_b2a69_row9_col0" class="data row9 col0" ></td>
#       <td id="T_b2a69_row9_col1" class="data row9 col1" ></td>
#       <td id="T_b2a69_row9_col2" class="data row9 col2" ></td>
#       <td id="T_b2a69_row9_col3" class="data row9 col3" ></td>
#       <td id="T_b2a69_row9_col4" class="data row9 c

# %% [markdown]
# ### Section 3-6 :  Interest

# %%
# # tot overnight cost = accounts 10 - 50
# # I cheated this from Levi : SC-HTGR-costreduction_LML.xlsx
tot_overnight_cost = (SFR_data_updated_5.loc[SFR_data_updated_5.Title == 'Total Overnight Cost (Accounts 10 to 50)' , 'Total Cost (USD)']).values[0]


# # Interest rate from this equation (from Levi)
B =(1+ np.exp((np.log(1+ interest_rate)) * final_construction_duration/12))
C  =((np.log(1+ interest_rate)*(final_construction_duration/12)/3.14)**2+1)
Interest_expenses = tot_overnight_cost*((0.5*B/C)-1)

db = pd.DataFrame()

db = SFR_data_updated_5[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()
db.loc[db.Account == 63, 'Total Cost (USD)'] = None # clear old values
Interest_expenses
(db.loc[db.Account == 63, 'Total Cost (USD)']) = Interest_expenses

SFR_data_updated_6 = update_high_level_costs(db)

FR_data_updated_6_ = pd.DataFrame()
SFR_data_updated_6_ = SFR_data_updated_6[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_6_pretty = prettify(SFR_data_updated_6_, "SFR-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
SFR_data_updated_6_pretty
# Out:
# <style type="text/css">
# #T_06a36 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_06a36_row0_col0, #T_06a36_row0_col1, #T_06a36_row0_col2, #T_06a36_row0_col3, #T_06a36_row0_col4, #T_06a36_row0_col5, #T_06a36_row0_col6, #T_06a36_row12_col0, #T_06a36_row12_col1, #T_06a36_row12_col2, #T_06a36_row12_col3, #T_06a36_row12_col4, #T_06a36_row12_col5, #T_06a36_row12_col6, #T_06a36_row24_col0, #T_06a36_row24_col1, #T_06a36_row24_col2, #T_06a36_row24_col3, #T_06a36_row24_col4, #T_06a36_row24_col5, #T_06a36_row24_col6, #T_06a36_row36_col0, #T_06a36_row36_col1, #T_06a36_row36_col2, #T_06a36_row36_col3, #T_06a36_row36_col4, #T_06a36_row36_col5, #T_06a36_row36_col6, #T_06a36_row43_col0, #T_06a36_row43_col1, #T_06a36_row43_col2, #T_06a36_row43_col3, #T_06a36_row43_col4, #T_06a36_row43_col5, #T_06a36_row43_col6, #T_06a36_row52_col0, #T_06a36_row52_col1, #T_06a36_row52_col2, #T_06a36_row52_col3, #T_06a36_row52_col4, #T_06a36_row52_col5, #T_06a36_row52_col6, #T_06a36_row59_col0, #T_06a36_row59_col1, #T_06a36_row59_col2, #T_06a36_row59_col3, #T_06a36_row59_col4, #T_06a36_row59_col5, #T_06a36_row59_col6, #T_06a36_row60_col0, #T_06a36_row60_col1, #T_06a36_row60_col2, #T_06a36_row60_col3, #T_06a36_row60_col4, #T_06a36_row60_col5, #T_06a36_row60_col6, #T_06a36_row61_col0, #T_06a36_row61_col1, #T_06a36_row61_col2, #T_06a36_row61_col3, #T_06a36_row61_col4, #T_06a36_row61_col5, #T_06a36_row61_col6, #T_06a36_row62_col0, #T_06a36_row62_col1, #T_06a36_row62_col2, #T_06a36_row62_col3, #T_06a36_row62_col4, #T_06a36_row62_col5, #T_06a36_row62_col6, #T_06a36_row63_col0, #T_06a36_row63_col1, #T_06a36_row63_col2, #T_06a36_row63_col3, #T_06a36_row63_col4, #T_06a36_row63_col5, #T_06a36_row63_col6, #T_06a36_row64_col0, #T_06a36_row64_col1, #T_06a36_row64_col2, #T_06a36_row64_col3, #T_06a36_row64_col4, #T_06a36_row64_col5, #T_06a36_row64_col6, #T_06a36_row65_col0, #T_06a36_row65_col1, #T_06a36_row65_col2, #T_06a36_row65_col3, #T_06a36_row65_col4, #T_06a36_row65_col5, #T_06a36_row65_col6, #T_06a36_row66_col0, #T_06a36_row66_col1, #T_06a36_row66_col2, #T_06a36_row66_col3, #T_06a36_row66_col4, #T_06a36_row66_col5, #T_06a36_row66_col6 {
#   font-weight: bold;
# }
# #T_06a36_row67_col0, #T_06a36_row67_col1, #T_06a36_row67_col2, #T_06a36_row67_col3, #T_06a36_row67_col4, #T_06a36_row67_col5, #T_06a36_row67_col6, #T_06a36_row68_col0, #T_06a36_row68_col1, #T_06a36_row68_col2, #T_06a36_row68_col3, #T_06a36_row68_col4, #T_06a36_row68_col5, #T_06a36_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_06a36">
#   <caption>SFR-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_06a36_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_06a36_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_06a36_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_06a36_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_06a36_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_06a36_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_06a36_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_06a36_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_06a36_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_06a36_row0_col2" class="data row0 col2" ></td>
#       <td id="T_06a36_row0_col3" class="data row0 col3" ></td>
#       <td id="T_06a36_row0_col4" class="data row0 col4" ></td>
#       <td id="T_06a36_row0_col5" class="data row0 col5" ></td>
#       <td id="T_06a36_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_06a36_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_06a36_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_06a36_row1_col3" class="data row1 col3" ></td>
#       <td id="T_06a36_row1_col4" class="data row1 col4" ></td>
#       <td id="T_06a36_row1_col5" class="data row1 col5" ></td>
#       <td id="T_06a36_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_06a36_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_06a36_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_06a36_row2_col3" class="data row2 col3" ></td>
#       <td id="T_06a36_row2_col4" class="data row2 col4" ></td>
#       <td id="T_06a36_row2_col5" class="data row2 col5" ></td>
#       <td id="T_06a36_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_06a36_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_06a36_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_06a36_row3_col3" class="data row3 col3" ></td>
#       <td id="T_06a36_row3_col4" class="data row3 col4" ></td>
#       <td id="T_06a36_row3_col5" class="data row3 col5" ></td>
#       <td id="T_06a36_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_06a36_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_06a36_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_06a36_row4_col3" class="data row4 col3" ></td>
#       <td id="T_06a36_row4_col4" class="data row4 col4" ></td>
#       <td id="T_06a36_row4_col5" class="data row4 col5" ></td>
#       <td id="T_06a36_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_06a36_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_06a36_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_06a36_row5_col3" class="data row5 col3" ></td>
#       <td id="T_06a36_row5_col4" class="data row5 col4" ></td>
#       <td id="T_06a36_row5_col5" class="data row5 col5" ></td>
#       <td id="T_06a36_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_06a36_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_06a36_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_06a36_row6_col3" class="data row6 col3" ></td>
#       <td id="T_06a36_row6_col4" class="data row6 col4" ></td>
#       <td id="T_06a36_row6_col5" class="data row6 col5" ></td>
#       <td id="T_06a36_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_06a36_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_06a36_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_06a36_row7_col3" class="data row7 col3" ></td>
#       <td id="T_06a36_row7_col4" class="data row7 col4" ></td>
#       <td id="T_06a36_row7_col5" class="data row7 col5" ></td>
#       <td id="T_06a36_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_06a36_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_06a36_row8_col2" class="data row8 col2" ></td>
#       <td id="T_06a36_row8_col3" class="data row8 col3" ></td>
#       <td id="T_06a36_row8_col4" class="data row8 col4" ></td>
#       <td id="T_06a36_row8_col5" class="data row8 col5" ></td>
#       <td id="T_06a36_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_06a36_row9_col0" class="data row9 col0" ></td>
#       <td id="T_06a36_row9_col1" class="data row9 col1" ></td>
#       <td id="T_06a36_row9_col2" class="data row9 col2" ></td>
#       <td id="T_06a36_row9_col3" class="data row9 col3" ></td>
#       <td id="T_06a36_row9_col4" class="data row9 c

# %% [markdown]
# ### Section 3-7 :  Insurance

# %%
# insurance increases linearly when increaing the sum of the 20s and 30s account
db = pd.DataFrame()

db = SFR_data_updated_6[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()
db0 = SFR_data_0
db.loc[db.Account == 54, 'Total Cost (USD)'] = None # clear old values

change_in_insuance_cost = (db.loc[db.Title =='20s - Subtotal', 'Total Cost (USD)'].values\
                        + db.loc[db.Title =='30s - Subtotal', 'Total Cost (USD)'].values)/ (db0.loc[db0.Title =='20s - Subtotal', 'Total Cost (USD)'].values\
                        + db0.loc[db0.Title =='30s - Subtotal', 'Total Cost (USD)'].values)

db.loc[db.Account == 54, 'Total Cost (USD)'] =  (change_in_insuance_cost[0])* (SFR_data_updated_6.loc[db.Account == 54, 'Total Cost (USD)'])

SFR_data_updated_7 = update_high_level_costs(db)

SFR_data_updated_7_ = pd.DataFrame()
SFR_data_updated_7_ = SFR_data_updated_7[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_7_pretty = prettify(SFR_data_updated_7_, "SFR-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
SFR_data_updated_7_pretty
# Out:
# <style type="text/css">
# #T_f257e caption {
#   color: red;
#   font-size: 20px;
# }
# #T_f257e_row0_col0, #T_f257e_row0_col1, #T_f257e_row0_col2, #T_f257e_row0_col3, #T_f257e_row0_col4, #T_f257e_row0_col5, #T_f257e_row0_col6, #T_f257e_row12_col0, #T_f257e_row12_col1, #T_f257e_row12_col2, #T_f257e_row12_col3, #T_f257e_row12_col4, #T_f257e_row12_col5, #T_f257e_row12_col6, #T_f257e_row24_col0, #T_f257e_row24_col1, #T_f257e_row24_col2, #T_f257e_row24_col3, #T_f257e_row24_col4, #T_f257e_row24_col5, #T_f257e_row24_col6, #T_f257e_row36_col0, #T_f257e_row36_col1, #T_f257e_row36_col2, #T_f257e_row36_col3, #T_f257e_row36_col4, #T_f257e_row36_col5, #T_f257e_row36_col6, #T_f257e_row43_col0, #T_f257e_row43_col1, #T_f257e_row43_col2, #T_f257e_row43_col3, #T_f257e_row43_col4, #T_f257e_row43_col5, #T_f257e_row43_col6, #T_f257e_row52_col0, #T_f257e_row52_col1, #T_f257e_row52_col2, #T_f257e_row52_col3, #T_f257e_row52_col4, #T_f257e_row52_col5, #T_f257e_row52_col6, #T_f257e_row59_col0, #T_f257e_row59_col1, #T_f257e_row59_col2, #T_f257e_row59_col3, #T_f257e_row59_col4, #T_f257e_row59_col5, #T_f257e_row59_col6, #T_f257e_row60_col0, #T_f257e_row60_col1, #T_f257e_row60_col2, #T_f257e_row60_col3, #T_f257e_row60_col4, #T_f257e_row60_col5, #T_f257e_row60_col6, #T_f257e_row61_col0, #T_f257e_row61_col1, #T_f257e_row61_col2, #T_f257e_row61_col3, #T_f257e_row61_col4, #T_f257e_row61_col5, #T_f257e_row61_col6, #T_f257e_row62_col0, #T_f257e_row62_col1, #T_f257e_row62_col2, #T_f257e_row62_col3, #T_f257e_row62_col4, #T_f257e_row62_col5, #T_f257e_row62_col6, #T_f257e_row63_col0, #T_f257e_row63_col1, #T_f257e_row63_col2, #T_f257e_row63_col3, #T_f257e_row63_col4, #T_f257e_row63_col5, #T_f257e_row63_col6, #T_f257e_row64_col0, #T_f257e_row64_col1, #T_f257e_row64_col2, #T_f257e_row64_col3, #T_f257e_row64_col4, #T_f257e_row64_col5, #T_f257e_row64_col6, #T_f257e_row65_col0, #T_f257e_row65_col1, #T_f257e_row65_col2, #T_f257e_row65_col3, #T_f257e_row65_col4, #T_f257e_row65_col5, #T_f257e_row65_col6, #T_f257e_row66_col0, #T_f257e_row66_col1, #T_f257e_row66_col2, #T_f257e_row66_col3, #T_f257e_row66_col4, #T_f257e_row66_col5, #T_f257e_row66_col6 {
#   font-weight: bold;
# }
# #T_f257e_row67_col0, #T_f257e_row67_col1, #T_f257e_row67_col2, #T_f257e_row67_col3, #T_f257e_row67_col4, #T_f257e_row67_col5, #T_f257e_row67_col6, #T_f257e_row68_col0, #T_f257e_row68_col1, #T_f257e_row68_col2, #T_f257e_row68_col3, #T_f257e_row68_col4, #T_f257e_row68_col5, #T_f257e_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_f257e">
#   <caption>SFR-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_f257e_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_f257e_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_f257e_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_f257e_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_f257e_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_f257e_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_f257e_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f257e_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_f257e_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_f257e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_f257e_row0_col3" class="data row0 col3" ></td>
#       <td id="T_f257e_row0_col4" class="data row0 col4" ></td>
#       <td id="T_f257e_row0_col5" class="data row0 col5" ></td>
#       <td id="T_f257e_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_f257e_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_f257e_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_f257e_row1_col3" class="data row1 col3" ></td>
#       <td id="T_f257e_row1_col4" class="data row1 col4" ></td>
#       <td id="T_f257e_row1_col5" class="data row1 col5" ></td>
#       <td id="T_f257e_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_f257e_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_f257e_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_f257e_row2_col3" class="data row2 col3" ></td>
#       <td id="T_f257e_row2_col4" class="data row2 col4" ></td>
#       <td id="T_f257e_row2_col5" class="data row2 col5" ></td>
#       <td id="T_f257e_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_f257e_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_f257e_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_f257e_row3_col3" class="data row3 col3" ></td>
#       <td id="T_f257e_row3_col4" class="data row3 col4" ></td>
#       <td id="T_f257e_row3_col5" class="data row3 col5" ></td>
#       <td id="T_f257e_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_f257e_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_f257e_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_f257e_row4_col3" class="data row4 col3" ></td>
#       <td id="T_f257e_row4_col4" class="data row4 col4" ></td>
#       <td id="T_f257e_row4_col5" class="data row4 col5" ></td>
#       <td id="T_f257e_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_f257e_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_f257e_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_f257e_row5_col3" class="data row5 col3" ></td>
#       <td id="T_f257e_row5_col4" class="data row5 col4" ></td>
#       <td id="T_f257e_row5_col5" class="data row5 col5" ></td>
#       <td id="T_f257e_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_f257e_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_f257e_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_f257e_row6_col3" class="data row6 col3" ></td>
#       <td id="T_f257e_row6_col4" class="data row6 col4" ></td>
#       <td id="T_f257e_row6_col5" class="data row6 col5" ></td>
#       <td id="T_f257e_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_f257e_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_f257e_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_f257e_row7_col3" class="data row7 col3" ></td>
#       <td id="T_f257e_row7_col4" class="data row7 col4" ></td>
#       <td id="T_f257e_row7_col5" class="data row7 col5" ></td>
#       <td id="T_f257e_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_f257e_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_f257e_row8_col2" class="data row8 col2" ></td>
#       <td id="T_f257e_row8_col3" class="data row8 col3" ></td>
#       <td id="T_f257e_row8_col4" class="data row8 col4" ></td>
#       <td id="T_f257e_row8_col5" class="data row8 col5" ></td>
#       <td id="T_f257e_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_f257e_row9_col0" class="data row9 col0" ></td>
#       <td id="T_f257e_row9_col1" class="data row9 col1" ></td>
#       <td id="T_f257e_row9_col2" class="data row9 col2" ></td>
#       <td id="T_f257e_row9_col3" class="data row9 col3" ></td>
#       <td id="T_f257e_row9_col4" class="data row9 c

# %% [markdown]
# ### Section 3 - 8 :  ITC Subsidies

# %%
db = SFR_data_updated_7
tot_cap_investment = db.loc[db.Title =='Total Capital Investment Cost (Accounts 10 to 60)', 'Total Cost (USD)'].values

# #from levi's equation, the multipliers change with the ITC as follows

cost_multiplier = min(-0.9387*ITC+ 1.0046, 1)
ITC_reduced_capital_cost  = cost_multiplier*tot_cap_investment


db1 = pd.DataFrame()
db1 = SFR_data_updated_7[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced)', 'Total Cost (USD)'] = None
db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced) - US$/kWe', 'Total Cost (USD)'] = None


db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced)', 'Total Cost (USD)'] = ITC_reduced_capital_cost
db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced) - US$/kWe', 'Total Cost (USD)'] = ITC_reduced_capital_cost/reactor_power


SFR_data_updated_8 = update_high_level_costs(db1)

SFR_data_updated_8_ = pd.DataFrame()
SFR_data_updated_8_ = SFR_data_updated_8[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_8_pretty = prettify(SFR_data_updated_8_, "SFR-FOAK Capital Cost Summary - Updated ", 'subsidies')
SFR_data_updated_8_pretty
# Out:
# <style type="text/css">
# #T_17e72 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_17e72_row0_col0, #T_17e72_row0_col1, #T_17e72_row0_col2, #T_17e72_row0_col3, #T_17e72_row0_col4, #T_17e72_row0_col5, #T_17e72_row0_col6, #T_17e72_row12_col0, #T_17e72_row12_col1, #T_17e72_row12_col2, #T_17e72_row12_col3, #T_17e72_row12_col4, #T_17e72_row12_col5, #T_17e72_row12_col6, #T_17e72_row24_col0, #T_17e72_row24_col1, #T_17e72_row24_col2, #T_17e72_row24_col3, #T_17e72_row24_col4, #T_17e72_row24_col5, #T_17e72_row24_col6, #T_17e72_row36_col0, #T_17e72_row36_col1, #T_17e72_row36_col2, #T_17e72_row36_col3, #T_17e72_row36_col4, #T_17e72_row36_col5, #T_17e72_row36_col6, #T_17e72_row43_col0, #T_17e72_row43_col1, #T_17e72_row43_col2, #T_17e72_row43_col3, #T_17e72_row43_col4, #T_17e72_row43_col5, #T_17e72_row43_col6, #T_17e72_row52_col0, #T_17e72_row52_col1, #T_17e72_row52_col2, #T_17e72_row52_col3, #T_17e72_row52_col4, #T_17e72_row52_col5, #T_17e72_row52_col6, #T_17e72_row59_col0, #T_17e72_row59_col1, #T_17e72_row59_col2, #T_17e72_row59_col3, #T_17e72_row59_col4, #T_17e72_row59_col5, #T_17e72_row59_col6, #T_17e72_row60_col0, #T_17e72_row60_col1, #T_17e72_row60_col2, #T_17e72_row60_col3, #T_17e72_row60_col4, #T_17e72_row60_col5, #T_17e72_row60_col6, #T_17e72_row61_col0, #T_17e72_row61_col1, #T_17e72_row61_col2, #T_17e72_row61_col3, #T_17e72_row61_col4, #T_17e72_row61_col5, #T_17e72_row61_col6, #T_17e72_row62_col0, #T_17e72_row62_col1, #T_17e72_row62_col2, #T_17e72_row62_col3, #T_17e72_row62_col4, #T_17e72_row62_col5, #T_17e72_row62_col6, #T_17e72_row63_col0, #T_17e72_row63_col1, #T_17e72_row63_col2, #T_17e72_row63_col3, #T_17e72_row63_col4, #T_17e72_row63_col5, #T_17e72_row63_col6, #T_17e72_row64_col0, #T_17e72_row64_col1, #T_17e72_row64_col2, #T_17e72_row64_col3, #T_17e72_row64_col4, #T_17e72_row64_col5, #T_17e72_row64_col6, #T_17e72_row65_col0, #T_17e72_row65_col1, #T_17e72_row65_col2, #T_17e72_row65_col3, #T_17e72_row65_col4, #T_17e72_row65_col5, #T_17e72_row65_col6, #T_17e72_row66_col0, #T_17e72_row66_col1, #T_17e72_row66_col2, #T_17e72_row66_col3, #T_17e72_row66_col4, #T_17e72_row66_col5, #T_17e72_row66_col6, #T_17e72_row67_col0, #T_17e72_row67_col1, #T_17e72_row67_col2, #T_17e72_row67_col3, #T_17e72_row67_col4, #T_17e72_row67_col5, #T_17e72_row67_col6, #T_17e72_row68_col0, #T_17e72_row68_col1, #T_17e72_row68_col2, #T_17e72_row68_col3, #T_17e72_row68_col4, #T_17e72_row68_col5, #T_17e72_row68_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_17e72">
#   <caption>SFR-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_17e72_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_17e72_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_17e72_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_17e72_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_17e72_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_17e72_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_17e72_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_17e72_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_17e72_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_17e72_row0_col2" class="data row0 col2" ></td>
#       <td id="T_17e72_row0_col3" class="data row0 col3" ></td>
#       <td id="T_17e72_row0_col4" class="data row0 col4" ></td>
#       <td id="T_17e72_row0_col5" class="data row0 col5" ></td>
#       <td id="T_17e72_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_17e72_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_17e72_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_17e72_row1_col3" class="data row1 col3" ></td>
#       <td id="T_17e72_row1_col4" class="data row1 col4" ></td>
#       <td id="T_17e72_row1_col5" class="data row1 col5" ></td>
#       <td id="T_17e72_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_17e72_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_17e72_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_17e72_row2_col3" class="data row2 col3" ></td>
#       <td id="T_17e72_row2_col4" class="data row2 col4" ></td>
#       <td id="T_17e72_row2_col5" class="data row2 col5" ></td>
#       <td id="T_17e72_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_17e72_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_17e72_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_17e72_row3_col3" class="data row3 col3" ></td>
#       <td id="T_17e72_row3_col4" class="data row3 col4" ></td>
#       <td id="T_17e72_row3_col5" class="data row3 col5" ></td>
#       <td id="T_17e72_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_17e72_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_17e72_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_17e72_row4_col3" class="data row4 col3" ></td>
#       <td id="T_17e72_row4_col4" class="data row4 col4" ></td>
#       <td id="T_17e72_row4_col5" class="data row4 col5" ></td>
#       <td id="T_17e72_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_17e72_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_17e72_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_17e72_row5_col3" class="data row5 col3" ></td>
#       <td id="T_17e72_row5_col4" class="data row5 col4" ></td>
#       <td id="T_17e72_row5_col5" class="data row5 col5" ></td>
#       <td id="T_17e72_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_17e72_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_17e72_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_17e72_row6_col3" class="data row6 col3" ></td>
#       <td id="T_17e72_row6_col4" class="data row6 col4" ></td>
#       <td id="T_17e72_row6_col5" class="data row6 col5" ></td>
#       <td id="T_17e72_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_17e72_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_17e72_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_17e72_row7_col3" class="data row7 col3" ></td>
#       <td id="T_17e72_row7_col4" class="data row7 col4" ></td>
#       <td id="T_17e72_row7_col5" class="data row7 col5" ></td>
#       <td id="T_17e72_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_17e72_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_17e72_row8_col2" class="data row8 col2" ></td>
#       <td id="T_17e72_row8_col3" class="data row8 col3" ></td>
#       <td id="T_17e72_row8_col4" class="data row8 col4" ></td>
#       <td id="T_17e72_row8_col5" class="data row8 col5" ></td>
#       <td id="T_17e72_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_17e72_row9_col0" class="data row9 col0" ></td>
#       <td id="T_17e72_row9_col1" class="data row9 col1" ></td>
#       <td id="T_17e72_row9_col2" class="data row9 col2" ></td>
#       <td id="T_17e72_row9_col3" class="data row9 col3" ></td>
#       <td id="T_17e72_row9_col4" class="data row9 col4" ></td>
#       <td id="T_17e72_row9_col5" class="data row9 col5"

# %% [markdown]
# ### Section 3 - 9 : FOAK to NOAK (change direct, indirect cost, and cost duration)

# %%
# FOAK to NOAK

db = pd.DataFrame()
db = SFR_data_updated_8[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

# remove old values
for x in [21, 22, 23, 24, 25, 26]:
    db.loc[db.Account== x, 'Total Cost (USD)']       = None
    db.loc[db.Account== x, 'Factory Equipment Cost'] = None
    db.loc[db.Account== x, 'Site Labor Hours']       = None
    db.loc[db.Account== x, 'Site Labor Cost']        = None
    db.loc[db.Account== x, 'Site Material Cost']     = None

for x in [31, 32, 33, 34 ,35, 36, 37, 38]: 
    db.loc[db.Account == x, 'Total Cost (USD)'] = None


# # # Equation for accounts 21, 24, 25, 26 factory equipment cost for the nth of a kind reactor
#  y = x ^ (-0.015)

for x in [21, 24, 25, 26]: 
    db.loc[db.Account == x, 'Factory Equipment Cost'] =\
        ((SFR_data_updated_8.loc[SFR_data_updated_8.Account == x, 'Factory Equipment Cost']).values) * (n_th ** (-0.015))



# # Equation for accounts 22, 23 factory equipment
#  y = x ^ (-0.074)
for x in [22, 23]: 
    db.loc[db.Account == x, 'Factory Equipment Cost'] =\
        ((SFR_data_updated_8.loc[SFR_data_updated_8.Account == x, 'Factory Equipment Cost']).values) * (n_th ** (-0.074))



# # Equation for accounts 21, 24, 25, 26
# # labor cost and labor hours
#  y = x ^ (-0.2)
for x in [21, 24, 25, 26]: 
    db.loc[db.Account == x, 'Site Labor Hours'] =\
        ((SFR_data_updated_8.loc[SFR_data_updated_8.Account == x, 'Site Labor Hours']).values) * (n_th ** (-0.2))
    db.loc[db.Account == x, 'Site Labor Cost'] =\
        ((SFR_data_updated_8.loc[SFR_data_updated_8.Account == x, 'Site Labor Cost']).values) * (n_th ** (-0.2))

    
# # Equation for accounts 22, 23
# # labor cost and labor hours
#  y = x ^ (-0.025)

for x in [22, 23]: 
    db.loc[db.Account == x, 'Site Labor Hours'] =\
        ((SFR_data_updated_8.loc[SFR_data_updated_8.Account == x, 'Site Labor Hours']).values) * (n_th ** (-0.025))
    db.loc[db.Account == x, 'Site Labor Cost'] =\
        ((SFR_data_updated_8.loc[SFR_data_updated_8.Account == x, 'Site Labor Cost']).values) * (n_th ** (-0.025))

# # Equation for all the accounts
# # material cost
#  y = x ^ (-0.105)
for x in [21, 22, 23, 24, 25, 26]:
    db.loc[db.Account == x, 'Site Material Cost'] =\
        ((SFR_data_updated_8.loc[SFR_data_updated_8.Account == x, 'Site Material Cost']).values) * (n_th ** (-0.105))


# # Equation for all the accounts (indirect cost)
#  y = x ^ (-0.101)

for x in [31, 32, 33, 34 ,35, 36, 37, 38]:
    db.loc[db.Account == x, 'Total Cost (USD)'] =\
    ((SFR_data_updated_8.loc[ SFR_data_updated_8.Account == x, 'Total Cost (USD)'] ).values)* (n_th ** (-0.101))


# # Equation for the construction durationc
#  y = x ^ (-0.174)
nth_reactor_construction_duration = final_construction_duration* (n_th ** (-0.174))

print("\nThe construction duration of reactor #", n_th, "is estimated to be : ", int(nth_reactor_construction_duration ), "months\n") 


# Remove the ITC adjusted cost for the NOAK reactor because it is not updated yet
# db.drop(db.tail(3).index,inplace=True) # drop last n rows

SFR_data_updated_9 = update_high_level_costs(db)

SFR_data_updated_9_ = pd.DataFrame()
SFR_data_updated_9_ = SFR_data_updated_9[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_9_pretty = prettify(SFR_data_updated_9_, f"SFR NOAK ({n_th}th) Capital Cost Summary - Updated ", 'no_subsidies')
SFR_data_updated_9_pretty
# Out:
# The construction duration of reactor # 100 is estimated to be :  67 months
# <style type="text/css">
# #T_5f6a6 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_5f6a6_row0_col0, #T_5f6a6_row0_col1, #T_5f6a6_row0_col2, #T_5f6a6_row0_col3, #T_5f6a6_row0_col4, #T_5f6a6_row0_col5, #T_5f6a6_row0_col6, #T_5f6a6_row12_col0, #T_5f6a6_row12_col1, #T_5f6a6_row12_col2, #T_5f6a6_row12_col3, #T_5f6a6_row12_col4, #T_5f6a6_row12_col5, #T_5f6a6_row12_col6, #T_5f6a6_row24_col0, #T_5f6a6_row24_col1, #T_5f6a6_row24_col2, #T_5f6a6_row24_col3, #T_5f6a6_row24_col4, #T_5f6a6_row24_col5, #T_5f6a6_row24_col6, #T_5f6a6_row36_col0, #T_5f6a6_row36_col1, #T_5f6a6_row36_col2, #T_5f6a6_row36_col3, #T_5f6a6_row36_col4, #T_5f6a6_row36_col5, #T_5f6a6_row36_col6, #T_5f6a6_row43_col0, #T_5f6a6_row43_col1, #T_5f6a6_row43_col2, #T_5f6a6_row43_col3, #T_5f6a6_row43_col4, #T_5f6a6_row43_col5, #T_5f6a6_row43_col6, #T_5f6a6_row52_col0, #T_5f6a6_row52_col1, #T_5f6a6_row52_col2, #T_5f6a6_row52_col3, #T_5f6a6_row52_col4, #T_5f6a6_row52_col5, #T_5f6a6_row52_col6, #T_5f6a6_row59_col0, #T_5f6a6_row59_col1, #T_5f6a6_row59_col2, #T_5f6a6_row59_col3, #T_5f6a6_row59_col4, #T_5f6a6_row59_col5, #T_5f6a6_row59_col6, #T_5f6a6_row60_col0, #T_5f6a6_row60_col1, #T_5f6a6_row60_col2, #T_5f6a6_row60_col3, #T_5f6a6_row60_col4, #T_5f6a6_row60_col5, #T_5f6a6_row60_col6, #T_5f6a6_row61_col0, #T_5f6a6_row61_col1, #T_5f6a6_row61_col2, #T_5f6a6_row61_col3, #T_5f6a6_row61_col4, #T_5f6a6_row61_col5, #T_5f6a6_row61_col6, #T_5f6a6_row62_col0, #T_5f6a6_row62_col1, #T_5f6a6_row62_col2, #T_5f6a6_row62_col3, #T_5f6a6_row62_col4, #T_5f6a6_row62_col5, #T_5f6a6_row62_col6, #T_5f6a6_row63_col0, #T_5f6a6_row63_col1, #T_5f6a6_row63_col2, #T_5f6a6_row63_col3, #T_5f6a6_row63_col4, #T_5f6a6_row63_col5, #T_5f6a6_row63_col6, #T_5f6a6_row64_col0, #T_5f6a6_row64_col1, #T_5f6a6_row64_col2, #T_5f6a6_row64_col3, #T_5f6a6_row64_col4, #T_5f6a6_row64_col5, #T_5f6a6_row64_col6, #T_5f6a6_row65_col0, #T_5f6a6_row65_col1, #T_5f6a6_row65_col2, #T_5f6a6_row65_col3, #T_5f6a6_row65_col4, #T_5f6a6_row65_col5, #T_5f6a6_row65_col6, #T_5f6a6_row66_col0, #T_5f6a6_row66_col1, #T_5f6a6_row66_col2, #T_5f6a6_row66_col3, #T_5f6a6_row66_col4, #T_5f6a6_row66_col5, #T_5f6a6_row66_col6 {
#   font-weight: bold;
# }
# #T_5f6a6_row67_col0, #T_5f6a6_row67_col1, #T_5f6a6_row67_col2, #T_5f6a6_row67_col3, #T_5f6a6_row67_col4, #T_5f6a6_row67_col5, #T_5f6a6_row67_col6, #T_5f6a6_row68_col0, #T_5f6a6_row68_col1, #T_5f6a6_row68_col2, #T_5f6a6_row68_col3, #T_5f6a6_row68_col4, #T_5f6a6_row68_col5, #T_5f6a6_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_5f6a6">
#   <caption>SFR NOAK (100th) Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_5f6a6_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_5f6a6_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_5f6a6_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_5f6a6_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_5f6a6_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_5f6a6_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_5f6a6_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f6a6_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_5f6a6_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_5f6a6_row0_col2" class="data row0 col2" ></td>
#       <td id="T_5f6a6_row0_col3" class="data row0 col3" ></td>
#       <td id="T_5f6a6_row0_col4" class="data row0 col4" ></td>
#       <td id="T_5f6a6_row0_col5" class="data row0 col5" ></td>
#       <td id="T_5f6a6_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_5f6a6_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_5f6a6_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_5f6a6_row1_col3" class="data row1 col3" ></td>
#       <td id="T_5f6a6_row1_col4" class="data row1 col4" ></td>
#       <td id="T_5f6a6_row1_col5" class="data row1 col5" ></td>
#       <td id="T_5f6a6_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_5f6a6_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_5f6a6_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_5f6a6_row2_col3" class="data row2 col3" ></td>
#       <td id="T_5f6a6_row2_col4" class="data row2 col4" ></td>
#       <td id="T_5f6a6_row2_col5" class="data row2 col5" ></td>
#       <td id="T_5f6a6_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_5f6a6_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_5f6a6_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_5f6a6_row3_col3" class="data row3 col3" ></td>
#       <td id="T_5f6a6_row3_col4" class="data row3 col4" ></td>
#       <td id="T_5f6a6_row3_col5" class="data row3 col5" ></td>
#       <td id="T_5f6a6_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_5f6a6_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_5f6a6_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_5f6a6_row4_col3" class="data row4 col3" ></td>
#       <td id="T_5f6a6_row4_col4" class="data row4 col4" ></td>
#       <td id="T_5f6a6_row4_col5" class="data row4 col5" ></td>
#       <td id="T_5f6a6_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_5f6a6_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_5f6a6_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_5f6a6_row5_col3" class="data row5 col3" ></td>
#       <td id="T_5f6a6_row5_col4" class="data row5 col4" ></td>
#       <td id="T_5f6a6_row5_col5" class="data row5 col5" ></td>
#       <td id="T_5f6a6_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_5f6a6_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_5f6a6_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_5f6a6_row6_col3" class="data row6 col3" ></td>
#       <td id="T_5f6a6_row6_col4" class="data row6 col4" ></td>
#       <td id="T_5f6a6_row6_col5" class="data row6 col5" ></td>
#       <td id="T_5f6a6_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_5f6a6_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_5f6a6_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_5f6a6_row7_col3" class="data row7 col3" ></td>
#       <td id="T_5f6a6_row7_col4" class="data row7 col4" ></td>
#       <td id="T_5f6a6_row7_col5" class="data row7 col5" ></td>
#       <td id="T_5f6a6_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_5f6a6_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_5f6a6_row8_col2" class="data row8 col2" ></td>
#       <td id="T_5f6a6_row8_col3" class="data row8 col3" ></td>
#       <td id="T_5f6a6_row8_col4" class="data row8 col4" ></td>
#       <td id="T_5f6a6_row8_col5" class="data row8 col5" ></td>
#       <td id="T_5f6a6_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_5f6a6_row9_col0" class="data row9 col0" ></td>
#       <td id="T_5f6a6_row9_col1" class="data row9 col1" ></td>
#       <td id="T_5f6a6_row9_col2" class="data row9 col2" ></td>
#       <td id="T_5f6a6_row9_col3" class="data row9 col3" ></td>
#       <td id="T_5f6a6_row9_col4" class="dat

# %% [markdown]
# ### Section 3 - 10 : NOAK (update interest and insurance)

# %%
# # tot overnight cost = accounts 10 - 50
tot_overnight_cost_noak = (SFR_data_updated_9.loc[SFR_data_updated_9.Title\
                           == 'Total Overnight Cost (Accounts 10 to 50)' , 'Total Cost (USD)']).values[0]
 
# # # Interest rate from this equation (from Levi)
Bn =(1+ np.exp((np.log(1+ interest_rate)) * nth_reactor_construction_duration/12))
Cn  =((np.log(1+ interest_rate)*(nth_reactor_construction_duration/12)/3.14)**2+1)
Interest_expenses_noak = tot_overnight_cost_noak*((0.5*Bn/Cn)-1)

# create the new database and copy columns from the previous database
db = pd.DataFrame()
db = SFR_data_updated_9[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()


# clear old values
db.loc[db.Account == 63, 'Total Cost (USD)'] = None # clear old values
db.loc[db.Account == 54, 'Total Cost (USD)'] = None # clear old values


# Interest_expenses
(db.loc[db.Account == 63, 'Total Cost (USD)']) = Interest_expenses_noak


# update insurance account

db0 = SFR_data_0

change_in_insuance_cost = (db.loc[db.Title =='20s - Subtotal', 'Total Cost (USD)'].values\
                        + db.loc[db.Title =='30s - Subtotal', 'Total Cost (USD)'].values)/ (db0.loc[db0.Title =='20s - Subtotal', 'Total Cost (USD)'].values\
                        + db0.loc[db0.Title =='30s - Subtotal', 'Total Cost (USD)'].values)

db.loc[db.Account == 54, 'Total Cost (USD)'] =  (change_in_insuance_cost[0])* (SFR_data_updated_9.loc[db.Account == 54, 'Total Cost (USD)'])


SFR_data_updated_10 = update_high_level_costs(db)

SFR_data_updated_10_ = pd.DataFrame()
SFR_data_updated_10_ = SFR_data_updated_10[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

SFR_data_updated_10_pretty = prettify(SFR_data_updated_10_, f"SFR NOAK ({n_th}th) Capital Cost Summary - Updated ", 'no_subsidies')
SFR_data_updated_10_pretty
# Out:
# <style type="text/css">
# #T_9ac87 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_9ac87_row0_col0, #T_9ac87_row0_col1, #T_9ac87_row0_col2, #T_9ac87_row0_col3, #T_9ac87_row0_col4, #T_9ac87_row0_col5, #T_9ac87_row0_col6, #T_9ac87_row12_col0, #T_9ac87_row12_col1, #T_9ac87_row12_col2, #T_9ac87_row12_col3, #T_9ac87_row12_col4, #T_9ac87_row12_col5, #T_9ac87_row12_col6, #T_9ac87_row24_col0, #T_9ac87_row24_col1, #T_9ac87_row24_col2, #T_9ac87_row24_col3, #T_9ac87_row24_col4, #T_9ac87_row24_col5, #T_9ac87_row24_col6, #T_9ac87_row36_col0, #T_9ac87_row36_col1, #T_9ac87_row36_col2, #T_9ac87_row36_col3, #T_9ac87_row36_col4, #T_9ac87_row36_col5, #T_9ac87_row36_col6, #T_9ac87_row43_col0, #T_9ac87_row43_col1, #T_9ac87_row43_col2, #T_9ac87_row43_col3, #T_9ac87_row43_col4, #T_9ac87_row43_col5, #T_9ac87_row43_col6, #T_9ac87_row52_col0, #T_9ac87_row52_col1, #T_9ac87_row52_col2, #T_9ac87_row52_col3, #T_9ac87_row52_col4, #T_9ac87_row52_col5, #T_9ac87_row52_col6, #T_9ac87_row59_col0, #T_9ac87_row59_col1, #T_9ac87_row59_col2, #T_9ac87_row59_col3, #T_9ac87_row59_col4, #T_9ac87_row59_col5, #T_9ac87_row59_col6, #T_9ac87_row60_col0, #T_9ac87_row60_col1, #T_9ac87_row60_col2, #T_9ac87_row60_col3, #T_9ac87_row60_col4, #T_9ac87_row60_col5, #T_9ac87_row60_col6, #T_9ac87_row61_col0, #T_9ac87_row61_col1, #T_9ac87_row61_col2, #T_9ac87_row61_col3, #T_9ac87_row61_col4, #T_9ac87_row61_col5, #T_9ac87_row61_col6, #T_9ac87_row62_col0, #T_9ac87_row62_col1, #T_9ac87_row62_col2, #T_9ac87_row62_col3, #T_9ac87_row62_col4, #T_9ac87_row62_col5, #T_9ac87_row62_col6, #T_9ac87_row63_col0, #T_9ac87_row63_col1, #T_9ac87_row63_col2, #T_9ac87_row63_col3, #T_9ac87_row63_col4, #T_9ac87_row63_col5, #T_9ac87_row63_col6, #T_9ac87_row64_col0, #T_9ac87_row64_col1, #T_9ac87_row64_col2, #T_9ac87_row64_col3, #T_9ac87_row64_col4, #T_9ac87_row64_col5, #T_9ac87_row64_col6, #T_9ac87_row65_col0, #T_9ac87_row65_col1, #T_9ac87_row65_col2, #T_9ac87_row65_col3, #T_9ac87_row65_col4, #T_9ac87_row65_col5, #T_9ac87_row65_col6, #T_9ac87_row66_col0, #T_9ac87_row66_col1, #T_9ac87_row66_col2, #T_9ac87_row66_col3, #T_9ac87_row66_col4, #T_9ac87_row66_col5, #T_9ac87_row66_col6 {
#   font-weight: bold;
# }
# #T_9ac87_row67_col0, #T_9ac87_row67_col1, #T_9ac87_row67_col2, #T_9ac87_row67_col3, #T_9ac87_row67_col4, #T_9ac87_row67_col5, #T_9ac87_row67_col6, #T_9ac87_row68_col0, #T_9ac87_row68_col1, #T_9ac87_row68_col2, #T_9ac87_row68_col3, #T_9ac87_row68_col4, #T_9ac87_row68_col5, #T_9ac87_row68_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_9ac87">
#   <caption>SFR NOAK (100th) Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_9ac87_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_9ac87_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_9ac87_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_9ac87_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_9ac87_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_9ac87_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_9ac87_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ac87_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_9ac87_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_9ac87_row0_col2" class="data row0 col2" ></td>
#       <td id="T_9ac87_row0_col3" class="data row0 col3" ></td>
#       <td id="T_9ac87_row0_col4" class="data row0 col4" ></td>
#       <td id="T_9ac87_row0_col5" class="data row0 col5" ></td>
#       <td id="T_9ac87_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_9ac87_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_9ac87_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_9ac87_row1_col3" class="data row1 col3" ></td>
#       <td id="T_9ac87_row1_col4" class="data row1 col4" ></td>
#       <td id="T_9ac87_row1_col5" class="data row1 col5" ></td>
#       <td id="T_9ac87_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ac87_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_9ac87_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_9ac87_row2_col3" class="data row2 col3" ></td>
#       <td id="T_9ac87_row2_col4" class="data row2 col4" ></td>
#       <td id="T_9ac87_row2_col5" class="data row2 col5" ></td>
#       <td id="T_9ac87_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_9ac87_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_9ac87_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_9ac87_row3_col3" class="data row3 col3" ></td>
#       <td id="T_9ac87_row3_col4" class="data row3 col4" ></td>
#       <td id="T_9ac87_row3_col5" class="data row3 col5" ></td>
#       <td id="T_9ac87_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_9ac87_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_9ac87_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_9ac87_row4_col3" class="data row4 col3" ></td>
#       <td id="T_9ac87_row4_col4" class="data row4 col4" ></td>
#       <td id="T_9ac87_row4_col5" class="data row4 col5" ></td>
#       <td id="T_9ac87_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_9ac87_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_9ac87_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_9ac87_row5_col3" class="data row5 col3" ></td>
#       <td id="T_9ac87_row5_col4" class="data row5 col4" ></td>
#       <td id="T_9ac87_row5_col5" class="data row5 col5" ></td>
#       <td id="T_9ac87_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_9ac87_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_9ac87_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_9ac87_row6_col3" class="data row6 col3" ></td>
#       <td id="T_9ac87_row6_col4" class="data row6 col4" ></td>
#       <td id="T_9ac87_row6_col5" class="data row6 col5" ></td>
#       <td id="T_9ac87_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_9ac87_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_9ac87_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_9ac87_row7_col3" class="data row7 col3" ></td>
#       <td id="T_9ac87_row7_col4" class="data row7 col4" ></td>
#       <td id="T_9ac87_row7_col5" class="data row7 col5" ></td>
#       <td id="T_9ac87_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_9ac87_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_9ac87_row8_col2" class="data row8 col2" ></td>
#       <td id="T_9ac87_row8_col3" class="data row8 col3" ></td>
#       <td id="T_9ac87_row8_col4" class="data row8 col4" ></td>
#       <td id="T_9ac87_row8_col5" class="data row8 col5" ></td>
#       <td id="T_9ac87_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_9ac87_row9_col0" class="data row9 col0" ></td>
#       <td id="T_9ac87_row9_col1" class="data row9 col1" ></td>
#       <td id="T_9ac87_row9_col2" class="data row9 col2" ></td>
#       <td id="T_9ac87_row9_col3" class="data row9 col3" ></td>
#       <td id="T_9ac87_row9_col4" class="dat

# %% [markdown]
# ### Section 3 - 11 : NOAK (update ITC)

# %%
db = SFR_data_updated_10
tot_cap_investment_noak = db.loc[db.Title =='Total Capital Investment Cost (Accounts 10 to 60)', 'Total Cost (USD)'].values

ITC_reduced_capital_cost_noak  = cost_multiplier*tot_cap_investment_noak 

# create new database
db1 = pd.DataFrame()
db1 = SFR_data_updated_10[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()





db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced)', 'Total Cost (USD)'] = None
db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced) - US$/kWe', 'Total Cost (USD)'] = None


db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced)', 'Total Cost (USD)'] = ITC_reduced_capital_cost_noak
db1.loc[db1.Title== 'Total Capital Investment Cost (ITC reduced) - US$/kWe', 'Total Cost (USD)'] = ITC_reduced_capital_cost_noak/reactor_power

SFR_data_updated_11 = update_high_level_costs(db1)

SFR_data_updated_11_ = pd.DataFrame()
SFR_data_updated_11_ = SFR_data_updated_11[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()


SFR_data_updated_11_pretty = prettify(SFR_data_updated_11_, f"SFR NOAK ({n_th}th) Capital Cost Summary - Updated ", 'subsidies')
SFR_data_updated_11_pretty
# Out:
# <style type="text/css">
# #T_598cf caption {
#   color: red;
#   font-size: 20px;
# }
# #T_598cf_row0_col0, #T_598cf_row0_col1, #T_598cf_row0_col2, #T_598cf_row0_col3, #T_598cf_row0_col4, #T_598cf_row0_col5, #T_598cf_row0_col6, #T_598cf_row12_col0, #T_598cf_row12_col1, #T_598cf_row12_col2, #T_598cf_row12_col3, #T_598cf_row12_col4, #T_598cf_row12_col5, #T_598cf_row12_col6, #T_598cf_row24_col0, #T_598cf_row24_col1, #T_598cf_row24_col2, #T_598cf_row24_col3, #T_598cf_row24_col4, #T_598cf_row24_col5, #T_598cf_row24_col6, #T_598cf_row36_col0, #T_598cf_row36_col1, #T_598cf_row36_col2, #T_598cf_row36_col3, #T_598cf_row36_col4, #T_598cf_row36_col5, #T_598cf_row36_col6, #T_598cf_row43_col0, #T_598cf_row43_col1, #T_598cf_row43_col2, #T_598cf_row43_col3, #T_598cf_row43_col4, #T_598cf_row43_col5, #T_598cf_row43_col6, #T_598cf_row52_col0, #T_598cf_row52_col1, #T_598cf_row52_col2, #T_598cf_row52_col3, #T_598cf_row52_col4, #T_598cf_row52_col5, #T_598cf_row52_col6, #T_598cf_row59_col0, #T_598cf_row59_col1, #T_598cf_row59_col2, #T_598cf_row59_col3, #T_598cf_row59_col4, #T_598cf_row59_col5, #T_598cf_row59_col6, #T_598cf_row60_col0, #T_598cf_row60_col1, #T_598cf_row60_col2, #T_598cf_row60_col3, #T_598cf_row60_col4, #T_598cf_row60_col5, #T_598cf_row60_col6, #T_598cf_row61_col0, #T_598cf_row61_col1, #T_598cf_row61_col2, #T_598cf_row61_col3, #T_598cf_row61_col4, #T_598cf_row61_col5, #T_598cf_row61_col6, #T_598cf_row62_col0, #T_598cf_row62_col1, #T_598cf_row62_col2, #T_598cf_row62_col3, #T_598cf_row62_col4, #T_598cf_row62_col5, #T_598cf_row62_col6, #T_598cf_row63_col0, #T_598cf_row63_col1, #T_598cf_row63_col2, #T_598cf_row63_col3, #T_598cf_row63_col4, #T_598cf_row63_col5, #T_598cf_row63_col6, #T_598cf_row64_col0, #T_598cf_row64_col1, #T_598cf_row64_col2, #T_598cf_row64_col3, #T_598cf_row64_col4, #T_598cf_row64_col5, #T_598cf_row64_col6, #T_598cf_row65_col0, #T_598cf_row65_col1, #T_598cf_row65_col2, #T_598cf_row65_col3, #T_598cf_row65_col4, #T_598cf_row65_col5, #T_598cf_row65_col6, #T_598cf_row66_col0, #T_598cf_row66_col1, #T_598cf_row66_col2, #T_598cf_row66_col3, #T_598cf_row66_col4, #T_598cf_row66_col5, #T_598cf_row66_col6, #T_598cf_row67_col0, #T_598cf_row67_col1, #T_598cf_row67_col2, #T_598cf_row67_col3, #T_598cf_row67_col4, #T_598cf_row67_col5, #T_598cf_row67_col6, #T_598cf_row68_col0, #T_598cf_row68_col1, #T_598cf_row68_col2, #T_598cf_row68_col3, #T_598cf_row68_col4, #T_598cf_row68_col5, #T_598cf_row68_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_598cf">
#   <caption>SFR NOAK (100th) Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_598cf_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_598cf_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_598cf_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_598cf_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_598cf_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_598cf_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_598cf_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_598cf_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_598cf_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_598cf_row0_col2" class="data row0 col2" ></td>
#       <td id="T_598cf_row0_col3" class="data row0 col3" ></td>
#       <td id="T_598cf_row0_col4" class="data row0 col4" ></td>
#       <td id="T_598cf_row0_col5" class="data row0 col5" ></td>
#       <td id="T_598cf_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_598cf_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_598cf_row1_col2" class="data row1 col2" >$ 8,800,000</td>
#       <td id="T_598cf_row1_col3" class="data row1 col3" ></td>
#       <td id="T_598cf_row1_col4" class="data row1 col4" ></td>
#       <td id="T_598cf_row1_col5" class="data row1 col5" ></td>
#       <td id="T_598cf_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_598cf_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_598cf_row2_col2" class="data row2 col2" >$ 1,279,113</td>
#       <td id="T_598cf_row2_col3" class="data row2 col3" ></td>
#       <td id="T_598cf_row2_col4" class="data row2 col4" ></td>
#       <td id="T_598cf_row2_col5" class="data row2 col5" ></td>
#       <td id="T_598cf_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_598cf_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_598cf_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_598cf_row3_col3" class="data row3 col3" ></td>
#       <td id="T_598cf_row3_col4" class="data row3 col4" ></td>
#       <td id="T_598cf_row3_col5" class="data row3 col5" ></td>
#       <td id="T_598cf_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_598cf_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_598cf_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_598cf_row4_col3" class="data row4 col3" ></td>
#       <td id="T_598cf_row4_col4" class="data row4 col4" ></td>
#       <td id="T_598cf_row4_col5" class="data row4 col5" ></td>
#       <td id="T_598cf_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_598cf_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_598cf_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_598cf_row5_col3" class="data row5 col3" ></td>
#       <td id="T_598cf_row5_col4" class="data row5 col4" ></td>
#       <td id="T_598cf_row5_col5" class="data row5 col5" ></td>
#       <td id="T_598cf_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_598cf_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_598cf_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_598cf_row6_col3" class="data row6 col3" ></td>
#       <td id="T_598cf_row6_col4" class="data row6 col4" ></td>
#       <td id="T_598cf_row6_col5" class="data row6 col5" ></td>
#       <td id="T_598cf_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row7_col0" class="data row7 col0" >17</td>
#       <td id="T_598cf_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_598cf_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_598cf_row7_col3" class="data row7 col3" ></td>
#       <td id="T_598cf_row7_col4" class="data row7 col4" ></td>
#       <td id="T_598cf_row7_col5" class="data row7 col5" ></td>
#       <td id="T_598cf_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row8_col0" class="data row8 col0" >18</td>
#       <td id="T_598cf_row8_col1" class="data row8 col1" >Community Outreach & Education</td>
#       <td id="T_598cf_row8_col2" class="data row8 col2" ></td>
#       <td id="T_598cf_row8_col3" class="data row8 col3" ></td>
#       <td id="T_598cf_row8_col4" class="data row8 col4" ></td>
#       <td id="T_598cf_row8_col5" class="data row8 col5" ></td>
#       <td id="T_598cf_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_598cf_row9_col0" class="data row9 col0" ></td>
#       <td id="T_598cf_row9_col1" class="data row9 col1" ></td>
#       <td id="T_598cf_row9_col2" class="data row9 col2" ></td>
#       <td id="T_598cf_row9_col3" class="data row9 col3" ></td>
#       <td id="T_598cf_row9_col4" class="data row9 col4" ></td>
#       <td id="T_598cf_row9_col5" class="data ro
