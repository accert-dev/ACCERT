# %% [markdown]
# <center><table>
#     <tr>
#         <th><img src="./INL1.png",align="middle",height="10000"/></th>
#         <th><img src="./MIT1.png",align="middle",height="10"\></th>
#         <th><img src="./ANL.png",align="middle",height="10"/></th>
#     </tr>
# </table>
# </center>

# %% [markdown]
# # <center>Cost Reduction Framework for Nuclear Reactor Power Plants</center>

# %% [markdown]
# ## Section 0 : Essentials to Run the code

# %% [markdown]
# ### Section 0 - 1 : Importing the libraries

# %%
# Importing libararies
import pandas as pd
import numpy as np



import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_rows', None)

# Things to do
# indirect cost scales with ... ? only standaridzation affect one account which is 25.

# %% [markdown]
# ### Section 0 - 2 : Control the table style

# %%
def prettify(database1, caption, category):
    database1['Total Cost (USD)'] = database1['Total Cost (USD)'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Factory Equipment Cost'] = database1['Factory Equipment Cost'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Site Labor Cost'] = database1['Site Labor Cost'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Site Material Cost'] = database1['Site Material Cost'].apply(lambda x: '$ {:,.0f}'.format(x))
    database1['Site Labor Hours'] =database1['Site Labor Hours'].apply(lambda x: '{:,.0f} hrs'.format(x))
    
    database1 = database1.fillna('') # remove nan
    database1= database1.replace({'$ nan':'', 'nan hrs':''}) # remove nan


    df_ = database1.loc[database1.Account.isin([10, 20, 30, 40, 50, 60])] # highlight high level accounts

    df_2 = database1.iloc[-15:] # final results  # df_2 = database1.iloc[-10:]
    
    df3 = pd.concat([df_, df_2])
    df4 = df_2 = database1.iloc[-2:]
    slice_ = pd.IndexSlice[df3.index, df3.columns]
    slice_2 = pd.IndexSlice[df4.index, df4.columns]


    
    slice_ = pd.IndexSlice[df3.index, df3.columns]
    slice_2 = pd.IndexSlice[df4.index, df4.columns]
    
    if category == "no_subsidies":
        database_styled = (database1.style.set_properties(**{'font-weight': 'bold'}, subset=slice_).\
                           set_properties(**{'color': 'white','background-color': 'white' }, subset=slice_2).\
                           set_caption(caption).set_table_styles([{'selector': 'caption','props': [('color', 'red'),('font-size', '20px')]}]))
            
    elif category == "subsidies":
        database_styled = (database1.style.set_properties(**{'font-weight': 'bold'}, subset=slice_).set_caption(caption).\
                           set_table_styles([{'selector': 'caption','props': [('color', 'red'),('font-size', '20px')]}]))
    
    return database_styled.hide()

def highlight_changes(row, baseline):
    return ['background-color: yellow' if val != baseline\
            and len(str(val))>0 and not (str(val)).startswith("Range")  else '' for val in row]

# %% [markdown]
# ## Section 1 : Reading the Baseline reactor Cost Summary Table

# %%
reactor_type = "SFR" # This can be SFR or HTGR

if reactor_type == "SFR":
    # Reading excel or csv files
    Reactor_data_0 = pd.read_excel('SFR_HTGR_data.xlsx', sheet_name = "SFR_SA_Plus_MIT_Combined", nrows= 66)
    reactor_power = 310.8 * 1000 # kw

elif reactor_type == "HTGR":
    # Reading excel or csv files
    Reactor_data_0 = pd.read_excel('SFR_HTGR_data.xlsx', sheet_name = "HTGR", nrows= 66)
    reactor_power = 1056 * 1000 # kw
    
db = pd.DataFrame()
db = Reactor_data_0[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()
Reactor_data = db
Reactor_data_pretty = prettify(Reactor_data, f"{reactor_type} Reactor-FOAK Capital Cost Summary - Baseline hypothetical well-executeed project  ", "no_subsidies")
Reactor_data_pretty
# Out:
# <style type="text/css">
# #T_69c4e caption {
#   color: red;
#   font-size: 20px;
# }
# #T_69c4e_row0_col0, #T_69c4e_row0_col1, #T_69c4e_row0_col2, #T_69c4e_row0_col3, #T_69c4e_row0_col4, #T_69c4e_row0_col5, #T_69c4e_row0_col6, #T_69c4e_row12_col0, #T_69c4e_row12_col1, #T_69c4e_row12_col2, #T_69c4e_row12_col3, #T_69c4e_row12_col4, #T_69c4e_row12_col5, #T_69c4e_row12_col6, #T_69c4e_row29_col0, #T_69c4e_row29_col1, #T_69c4e_row29_col2, #T_69c4e_row29_col3, #T_69c4e_row29_col4, #T_69c4e_row29_col5, #T_69c4e_row29_col6, #T_69c4e_row39_col0, #T_69c4e_row39_col1, #T_69c4e_row39_col2, #T_69c4e_row39_col3, #T_69c4e_row39_col4, #T_69c4e_row39_col5, #T_69c4e_row39_col6, #T_69c4e_row47_col0, #T_69c4e_row47_col1, #T_69c4e_row47_col2, #T_69c4e_row47_col3, #T_69c4e_row47_col4, #T_69c4e_row47_col5, #T_69c4e_row47_col6, #T_69c4e_row51_col0, #T_69c4e_row51_col1, #T_69c4e_row51_col2, #T_69c4e_row51_col3, #T_69c4e_row51_col4, #T_69c4e_row51_col5, #T_69c4e_row51_col6, #T_69c4e_row52_col0, #T_69c4e_row52_col1, #T_69c4e_row52_col2, #T_69c4e_row52_col3, #T_69c4e_row52_col4, #T_69c4e_row52_col5, #T_69c4e_row52_col6, #T_69c4e_row53_col0, #T_69c4e_row53_col1, #T_69c4e_row53_col2, #T_69c4e_row53_col3, #T_69c4e_row53_col4, #T_69c4e_row53_col5, #T_69c4e_row53_col6, #T_69c4e_row54_col0, #T_69c4e_row54_col1, #T_69c4e_row54_col2, #T_69c4e_row54_col3, #T_69c4e_row54_col4, #T_69c4e_row54_col5, #T_69c4e_row54_col6, #T_69c4e_row55_col0, #T_69c4e_row55_col1, #T_69c4e_row55_col2, #T_69c4e_row55_col3, #T_69c4e_row55_col4, #T_69c4e_row55_col5, #T_69c4e_row55_col6, #T_69c4e_row56_col0, #T_69c4e_row56_col1, #T_69c4e_row56_col2, #T_69c4e_row56_col3, #T_69c4e_row56_col4, #T_69c4e_row56_col5, #T_69c4e_row56_col6, #T_69c4e_row57_col0, #T_69c4e_row57_col1, #T_69c4e_row57_col2, #T_69c4e_row57_col3, #T_69c4e_row57_col4, #T_69c4e_row57_col5, #T_69c4e_row57_col6, #T_69c4e_row58_col0, #T_69c4e_row58_col1, #T_69c4e_row58_col2, #T_69c4e_row58_col3, #T_69c4e_row58_col4, #T_69c4e_row58_col5, #T_69c4e_row58_col6, #T_69c4e_row59_col0, #T_69c4e_row59_col1, #T_69c4e_row59_col2, #T_69c4e_row59_col3, #T_69c4e_row59_col4, #T_69c4e_row59_col5, #T_69c4e_row59_col6, #T_69c4e_row60_col0, #T_69c4e_row60_col1, #T_69c4e_row60_col2, #T_69c4e_row60_col3, #T_69c4e_row60_col4, #T_69c4e_row60_col5, #T_69c4e_row60_col6, #T_69c4e_row61_col0, #T_69c4e_row61_col1, #T_69c4e_row61_col2, #T_69c4e_row61_col3, #T_69c4e_row61_col4, #T_69c4e_row61_col5, #T_69c4e_row61_col6, #T_69c4e_row62_col0, #T_69c4e_row62_col1, #T_69c4e_row62_col2, #T_69c4e_row62_col3, #T_69c4e_row62_col4, #T_69c4e_row62_col5, #T_69c4e_row62_col6, #T_69c4e_row63_col0, #T_69c4e_row63_col1, #T_69c4e_row63_col2, #T_69c4e_row63_col3, #T_69c4e_row63_col4, #T_69c4e_row63_col5, #T_69c4e_row63_col6 {
#   font-weight: bold;
# }
# #T_69c4e_row64_col0, #T_69c4e_row64_col1, #T_69c4e_row64_col2, #T_69c4e_row64_col3, #T_69c4e_row64_col4, #T_69c4e_row64_col5, #T_69c4e_row64_col6, #T_69c4e_row65_col0, #T_69c4e_row65_col1, #T_69c4e_row65_col2, #T_69c4e_row65_col3, #T_69c4e_row65_col4, #T_69c4e_row65_col5, #T_69c4e_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_69c4e">
#   <caption>SFR Reactor-FOAK Capital Cost Summary - Baseline hypothetical well-executeed project  </caption>
#   <thead>
#     <tr>
#       <th id="T_69c4e_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_69c4e_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_69c4e_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_69c4e_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_69c4e_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_69c4e_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_69c4e_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_69c4e_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_69c4e_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_69c4e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_69c4e_row0_col3" class="data row0 col3" ></td>
#       <td id="T_69c4e_row0_col4" class="data row0 col4" ></td>
#       <td id="T_69c4e_row0_col5" class="data row0 col5" ></td>
#       <td id="T_69c4e_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_69c4e_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_69c4e_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_69c4e_row1_col3" class="data row1 col3" ></td>
#       <td id="T_69c4e_row1_col4" class="data row1 col4" ></td>
#       <td id="T_69c4e_row1_col5" class="data row1 col5" ></td>
#       <td id="T_69c4e_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_69c4e_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_69c4e_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_69c4e_row2_col3" class="data row2 col3" ></td>
#       <td id="T_69c4e_row2_col4" class="data row2 col4" ></td>
#       <td id="T_69c4e_row2_col5" class="data row2 col5" ></td>
#       <td id="T_69c4e_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_69c4e_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_69c4e_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_69c4e_row3_col3" class="data row3 col3" ></td>
#       <td id="T_69c4e_row3_col4" class="data row3 col4" ></td>
#       <td id="T_69c4e_row3_col5" class="data row3 col5" ></td>
#       <td id="T_69c4e_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_69c4e_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_69c4e_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_69c4e_row4_col3" class="data row4 col3" ></td>
#       <td id="T_69c4e_row4_col4" class="data row4 col4" ></td>
#       <td id="T_69c4e_row4_col5" class="data row4 col5" ></td>
#       <td id="T_69c4e_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_69c4e_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_69c4e_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_69c4e_row5_col3" class="data row5 col3" ></td>
#       <td id="T_69c4e_row5_col4" class="data row5 col4" ></td>
#       <td id="T_69c4e_row5_col5" class="data row5 col5" ></td>
#       <td id="T_69c4e_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_69c4e_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_69c4e_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_69c4e_row6_col3" class="data row6 col3" ></td>
#       <td id="T_69c4e_row6_col4" class="data row6 col4" ></td>
#       <td id="T_69c4e_row6_col5" class="data row6 col5" ></td>
#       <td id="T_69c4e_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_69c4e_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_69c4e_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_69c4e_row7_col3" class="data row7 col3" ></td>
#       <td id="T_69c4e_row7_col4" class="data row7 col4" ></td>
#       <td id="T_69c4e_row7_col5" class="data row7 col5" ></td>
#       <td id="T_69c4e_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_69c4e_row8_col0" class="data row8 col0" ></td>
#       <td id="T_69c4e_row8_col1" class="data row8 col1" ></td>
#       <td id="T_69c4e_row8_col2" c

# %% [markdown]
# ## Section 2 : A function to update the cost summary table each time a change is made

# %%
# Update the high level costs in the database when changing the low level costs

def update_high_level_costs(db):


    # update account 21 : material, labor, factory
    db.loc[db.Account == 21, 'Factory Equipment Cost'] = (db.loc[db.Account == 212, 'Factory Equipment Cost']).values+\
    (db.loc[db.Account == 213, 'Factory Equipment Cost']).values +(db.loc[db.Account == '211 plus 214 to 219', 'Factory Equipment Cost']).values
   
    db.loc[db.Account == 21, 'Site Material Cost'] = (db.loc[db.Account == 212, 'Site Material Cost'].values)+\
    (db.loc[db.Account == 213, 'Site Material Cost']).values+(db.loc[db.Account == '211 plus 214 to 219', 'Site Material Cost']).values
    
    db.loc[db.Account == 21, 'Site Labor Cost'] = (db.loc[db.Account == 212, 'Site Labor Cost']).values+\
    (db.loc[db.Account == 213, 'Site Labor Cost']).values+(db.loc[db.Account == '211 plus 214 to 219', 'Site Labor Cost']).values
    
    db.loc[db.Account == 21, 'Site Labor Hours'] = (db.loc[db.Account == 212, 'Site Labor Hours']).values+\
    (db.loc[db.Account == 213, 'Site Labor Hours']).values+(db.loc[db.Account =='211 plus 214 to 219', 'Site Labor Hours']).values


    #     # update account 23 : material, labor, factory
    db.loc[db.Account == 23, 'Factory Equipment Cost'] = (db.loc[db.Account == '232.1', 'Factory Equipment Cost']).values+\
    (db.loc[db.Account == 233, 'Factory Equipment Cost']).values
    
    (db.loc[db['Account'] == 23, 'Site Material Cost']) = (db.loc[db['Account'] == '232.1', 'Site Material Cost']).values+\
    (db.loc[db['Account'] == 233, 'Site Material Cost']).values
    
    (db.loc[db['Account'] == 23, 'Site Labor Cost']) = (db.loc[db['Account'] == '232.1', 'Site Labor Cost']).values+\
    (db.loc[db['Account'] == 233, 'Site Labor Cost']).values
    
    (db.loc[db['Account'] == 23, 'Site Labor Hours']) = (db.loc[db['Account'] == '232.1', 'Site Labor Hours']).values+\
    (db.loc[db['Account'] == 233, 'Site Labor Hours']).values




    
    # update total costs for accounts 21 : 26
    
    # total = labor + factory + material
    for x in [21, 212, 213, '211 plus 214 to 219', 22, 23, '232.1', 233, 24, 26]: 
        (db.loc[db['Account'] == x, 'Total Cost (USD)']) = (db.loc[db['Account'] == x, 'Factory Equipment Cost'])+\
            (db.loc[db['Account'] == x, 'Site Labor Cost'])+ (db.loc[db['Account'] == x, 'Site Material Cost'])

    #update total costs for accounts 10
    (db.loc[db['Title'] == '10s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([11, 12, 13, 14, 15, 16, 18]), 'Total Cost (USD)'].sum()
     
    # update total costs for accounts 20
    (db.loc[db['Title'] == '20s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([21, 22, 23, 24, 25, 26, 28]), 'Total Cost (USD)'].sum()

    # update total costs for accounts 30
    (db.loc[db['Title'] == '30s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([31, 32, 33, 34, 35]), 'Total Cost (USD)'].sum()


    # update total costs for accounts 50
    (db.loc[db['Title'] == '50s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([51, 52, 54]), 'Total Cost (USD)'].sum()

    # update total costs for accounts 60
    (db.loc[db['Title'] == '60s - Subtotal', 'Total Cost (USD)']) =\
        db.loc[db['Account'].isin([ 62]), 'Total Cost (USD)'].sum()
    
    # uodate costs per kw
    
    
    (db.loc[db['Title'] == '10s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '10s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '20s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '20s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '30s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '30s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '40s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '40s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '50s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '50s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    (db.loc[db['Title'] == '60s - $/kWe', 'Total Cost (USD)']) = (db.loc[db['Title'] == '60s - Subtotal', 'Total Cost (USD)']).values/reactor_power 
    
    
    
    # update final results
    (db.loc[db['Title'] == 'Total Direct Capital Cost (Accounts 10 to 20)', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == '10s - Subtotal', 'Total Cost (USD)']).values + (db.loc[db['Title'] == '20s - Subtotal', 'Total Cost (USD)']).values
    
    (db.loc[db['Title'] == 'Base Construction Cost (Accounts 10 to 30)', 'Total Cost (USD)']) =\
       (db.loc[db['Title'] == 'Total Direct Capital Cost (Accounts 10 to 20)', 'Total Cost (USD)']).values +\
        (db.loc[db['Title'] == '30s - Subtotal', 'Total Cost (USD)']).values

    (db.loc[db['Title'] == 'Total Overnight Cost (Accounts 10 to 50)', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Base Construction Cost (Accounts 10 to 30)', 'Total Cost (USD)']).values +\
    (db.loc[db['Title'] == '50s - Subtotal', 'Total Cost (USD)']).values

    (db.loc[db['Title'] == 'Total Capital Investment Cost (All Accounts)', 'Total Cost (USD)']) =\
       (db.loc[db['Title'] == 'Total Overnight Cost (Accounts 10 to 50)', 'Total Cost (USD)']).values +\
        (db.loc[db['Title'] == '60s - Subtotal', 'Total Cost (USD)']).values

   
    # update final results per kw
    (db.loc[db['Title'] == '(Accounts 10 to 20) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Total Direct Capital Cost (Accounts 10 to 20)', 'Total Cost (USD)']).values/reactor_power 

    (db.loc[db['Title'] == '(Accounts 10 to 30) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Base Construction Cost (Accounts 10 to 30)', 'Total Cost (USD)']).values/reactor_power 
   
    (db.loc[db['Title'] == '(Accounts 10 to 50) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Total Overnight Cost (Accounts 10 to 50)', 'Total Cost (USD)']).values/reactor_power 
    
    (db.loc[db['Title'] == '(Accounts 10 to 60) US$/kWe', 'Total Cost (USD)']) =\
        (db.loc[db['Title'] == 'Total Capital Investment Cost (All Accounts)', 'Total Cost (USD)']).values/reactor_power
    	
    return db

# %% [markdown]
# ## Section - 2 : User Inputs

# %% [markdown]
# ### Section - 2 - 1 : User-defined Independent Variables (Global Levers)

# %%
## ## User-defined Independent Variables (Global Levers)

# number of firm orders
num_orders = 10

# th of a kind
n_th = 1

# land cost
# From the SA report: the cost $22,000 per acre. The land area is 500 acres including recommended buffer
land_cost_per_acre_0 =  22000 # dollars/acre
 
startup_0 = 16 # start up duration (months)

# interest rate :
interest_rate_0 = 0.06

design_completion_0 = 0.8 # 1 means 100%

Design_Maturity_0 = 1

# #procurement service experience (supply chain experience)
proc_exp_0= 1 # 2 means procurement experts. This is ideal. 
   
# #  architecture and engineeringexperience
ae_exp_0 = 0
    
# #  Construction service experience
ce_exp_0 = 1

# modularity (applied on civil construction only) "stick_built"  or "modularized"
mod_0 = "stick_built" 

# cross_site_standardization :
standardization_0 = 0.8 # 0.7 corresponds to 70% standardization for PWRs

# # Determining if the BOP and reactor building (containtment) are non-nuclear or nuclear grade equipment (safety related)
BOP_grade_0 = "non_nuclear"
RB_grade_0 = "nuclear"

# #investment tax credits subsidies
ITC_0 =  0#
#number of reactors claiming ITC
n_ITC = 3 

if n_th <= n_ITC:
    ITC = ITC_0
else:
    ITC =0

# This is a hypothetical well-executed project taking 64 months (TIMCAT simulation)
if reactor_type == "SFR": 
    baseline_construction_duration = 64 # months
elif reactor_type == "HTGR":  
     baseline_construction_duration = 100 # months
    

# numb er of projects for full efficiency
N_proc = 3
N_AE  = 4
N_cons =5



if n_th == 1:
    land_cost_per_acre = land_cost_per_acre_0 
     
    startup = startup_0
    
    interest_rate =interest_rate_0
    
    design_completion = design_completion_0 
    
    Design_Maturity = Design_Maturity_0
    
    proc_exp = proc_exp_0
       
    # #  architecture and engineeringexperience
    ae_exp =ae_exp_0
        
    # #  Construction service experience
    ce_exp = ce_exp_0
    
    # modularity (applied on civil construction only) "stick_built"  or "modularized"
    mod = mod_0
    
    # cross_site_standardization :
    standardization = standardization_0 
    
    # # Determining if the BOP and reactor building (containtment) are non-nuclear or nuclear grade equipment (safety related)
    BOP_grade = BOP_grade_0
    RB_grade = RB_grade_0
 



    


# Change the levers if n >1
if n_th >1:
    land_cost_per_acre = land_cost_per_acre_0
    
    startup = max( 7 , startup_0*(1-0.3)**np.log2(n_th)  )

    interest_rate =interest_rate_0

    design_completion  = 1

    Design_Maturity = 2
    proc_exp = min( (proc_exp_0 + (2/N_proc)*(n_th-1) ), 2)

    ae_exp = min( (ae_exp_0 + (2/N_AE)*(n_th-1) ), 2)

    ce_exp = min( (ce_exp_0 + (2/N_cons)*(n_th-1) ), 2)

    standardization = 0.8
    mod = "modularized"

    BOP_grade = "non_nuclear"
    RB_grade = "non_nuclear"


# labor productivity factor = f(construction experience level)
productivity = 0.145*ce_exp + 0.71

global_levers = pd.DataFrame()
global_levers.loc[:, 'Lever'] = ['Baseline Construction Duration (months)', 'Design Completion',\
                                  'Procurement (supply chain) experience ','Architecture & Engineering Experience',\
                                 'Construction service experience',' Land Cost Per Acre (2023 USD)',\
                                'ITC ', ' Interest Rate', 'BOP grade ', 'Reactor Building grade', 'modulariziation',\
                                 'standardization' , 'productivity',"#th of a kind", "Startup duration (months)"]

global_levers.loc[:, 'User-Input Value'] = [baseline_construction_duration, design_completion, proc_exp, ae_exp, ce_exp, 
                                            land_cost_per_acre, ITC, interest_rate, BOP_grade  , RB_grade , mod,\
                                            standardization, productivity ,n_th, startup] 

global_levers.loc[:, 'Lever baseline value (for a hopothetical well-executed project)'] = [baseline_construction_duration, 1, 2, 2, 2, 22000, 0, 0.06 ,\
                                                                                           'nuclear', 'nuclear', "stick_built", 0.7 , 1 , 1, 16 ]

global_levers.loc[:, 'Range'] = ['30 - 130', '0 - 1', '0 - 2', '0 - 2','0 - 2' , '1000 - 100000', '0 - 0.5', '0 - 0.3',\
                                 "nuclear or non-nuclear", "nuclear or non-nuclear",  'stick_built or modularized', '0 : 1','0 : 1',
                                '1 - 1000', '3 : 24']



global_levers_changes = global_levers[global_levers['User-Input Value'] != global_levers['Lever baseline value (for a hopothetical well-executed project)']]

slice_ = pd.IndexSlice[global_levers_changes .index, global_levers_changes .columns]
global_levers_styled = (global_levers.style.set_properties(**{'background-color': 'yellow'}, subset=slice_ )\
                            .set_caption("User-Input Global levers <br> (highlighted in yellow if different from the baseline) <br>")\
                        .set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'blue'),
        ('font-size', '20px')
    ]
}]))


global_levers_styled.hide()
# Out:
# <style type="text/css">
# #T_f3d15 caption {
#   color: blue;
#   font-size: 20px;
# }
# #T_f3d15_row1_col0, #T_f3d15_row1_col1, #T_f3d15_row1_col2, #T_f3d15_row1_col3, #T_f3d15_row2_col0, #T_f3d15_row2_col1, #T_f3d15_row2_col2, #T_f3d15_row2_col3, #T_f3d15_row3_col0, #T_f3d15_row3_col1, #T_f3d15_row3_col2, #T_f3d15_row3_col3, #T_f3d15_row4_col0, #T_f3d15_row4_col1, #T_f3d15_row4_col2, #T_f3d15_row4_col3, #T_f3d15_row8_col0, #T_f3d15_row8_col1, #T_f3d15_row8_col2, #T_f3d15_row8_col3, #T_f3d15_row11_col0, #T_f3d15_row11_col1, #T_f3d15_row11_col2, #T_f3d15_row11_col3, #T_f3d15_row12_col0, #T_f3d15_row12_col1, #T_f3d15_row12_col2, #T_f3d15_row12_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f3d15">
#   <caption>User-Input Global levers <br> (highlighted in yellow if different from the baseline) <br></caption>
#   <thead>
#     <tr>
#       <th id="T_f3d15_level0_col0" class="col_heading level0 col0" >Lever</th>
#       <th id="T_f3d15_level0_col1" class="col_heading level0 col1" >User-Input Value</th>
#       <th id="T_f3d15_level0_col2" class="col_heading level0 col2" >Lever baseline value (for a hopothetical well-executed project)</th>
#       <th id="T_f3d15_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3d15_row0_col0" class="data row0 col0" >Baseline Construction Duration (months)</td>
#       <td id="T_f3d15_row0_col1" class="data row0 col1" >64</td>
#       <td id="T_f3d15_row0_col2" class="data row0 col2" >64</td>
#       <td id="T_f3d15_row0_col3" class="data row0 col3" >30 - 130</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row1_col0" class="data row1 col0" >Design Completion</td>
#       <td id="T_f3d15_row1_col1" class="data row1 col1" >0.800000</td>
#       <td id="T_f3d15_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_f3d15_row1_col3" class="data row1 col3" >0 - 1</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row2_col0" class="data row2 col0" >Procurement (supply chain) experience </td>
#       <td id="T_f3d15_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_f3d15_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_f3d15_row2_col3" class="data row2 col3" >0 - 2</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row3_col0" class="data row3 col0" >Architecture & Engineering Experience</td>
#       <td id="T_f3d15_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_f3d15_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_f3d15_row3_col3" class="data row3 col3" >0 - 2</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row4_col0" class="data row4 col0" >Construction service experience</td>
#       <td id="T_f3d15_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_f3d15_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_f3d15_row4_col3" class="data row4 col3" >0 - 2</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row5_col0" class="data row5 col0" > Land Cost Per Acre (2023 USD)</td>
#       <td id="T_f3d15_row5_col1" class="data row5 col1" >22000</td>
#       <td id="T_f3d15_row5_col2" class="data row5 col2" >22000</td>
#       <td id="T_f3d15_row5_col3" class="data row5 col3" >1000 - 100000</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row6_col0" class="data row6 col0" >ITC </td>
#       <td id="T_f3d15_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_f3d15_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_f3d15_row6_col3" class="data row6 col3" >0 - 0.5</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row7_col0" class="data row7 col0" > Interest Rate</td>
#       <td id="T_f3d15_row7_col1" class="data row7 col1" >0.060000</td>
#       <td id="T_f3d15_row7_col2" class="data row7 col2" >0.060000</td>
#       <td id="T_f3d15_row7_col3" class="data row7 col3" >0 - 0.3</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row8_col0" class="data row8 col0" >BOP grade </td>
#       <td id="T_f3d15_row8_col1" class="data row8 col1" >non_nuclear</td>
#       <td id="T_f3d15_row8_col2" class="data row8 col2" >nuclear</td>
#       <td id="T_f3d15_row8_col3" class="data row8 col3" >nuclear or non-nuclear</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row9_col0" class="data row9 col0" >Reactor Building grade</td>
#       <td id="T_f3d15_row9_col1" class="data row9 col1" >nuclear</td>
#       <td id="T_f3d15_row9_col2" class="data row9 col2" >nuclear</td>
#       <td id="T_f3d15_row9_col3" class="data row9 col3" >nuclear or non-nuclear</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row10_col0" class="data row10 col0" >modulariziation</td>
#       <td id="T_f3d15_row10_col1" class="data row10 col1" >stick_built</td>
#       <td id="T_f3d15_row10_col2" class="data row10 col2" >stick_built</td>
#       <td id="T_f3d15_row10_col3" class="data row10 col3" >stick_built or modularized</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row11_col0" class="data row11 col0" >standardization</td>
#       <td id="T_f3d15_row11_col1" class="data row11 col1" >0.800000</td>
#       <td id="T_f3d15_row11_col2" class="data row11 col2" >0.700000</td>
#       <td id="T_f3d15_row11_col3" class="data row11 col3" >0 : 1</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row12_col0" class="data row12 col0" >productivity</td>
#       <td id="T_f3d15_row12_col1" class="data row12 col1" >0.855000</td>
#       <td id="T_f3d15_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_f3d15_row12_col3" class="data row12 col3" >0 : 1</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row13_col0" class="data row13 col0" >#th of a kind</td>
#       <td id="T_f3d15_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_f3d15_row13_col2" class="data row13 col2" >1</td>
#       <td id="T_f3d15_row13_col3" class="data row13 col3" >1 - 1000</td>
#     </tr>
#     <tr>
#       <td id="T_f3d15_row14_col0" class="data row14 col0" >Startup duration (months)</td>
#       <td id="T_f3d15_row14_col1" class="data row14 col1" >16</td>
#       <td id="T_f3d15_row14_col2" class="data row14 col2" >16</td>
#       <td id="T_f3d15_row14_col3" class="data row14 col3" >3 : 24</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Section - 2 - 2 : User-defined Account-Based Variables

# %%
# Creating the table for the account based variables
accounts_vars = pd.DataFrame()
accounts_vars.loc[:, 'Account'] = Reactor_data.loc[:, 'Account']
accounts_vars.loc[:, 'Title'] = Reactor_data.loc[:, 'Title']

accounts_vars["Design Maturity"] = None
accounts_vars["Supply Chain Delay (monthhs)"] = None

accounts_vars = accounts_vars.loc[accounts_vars['Account'].isin([21, 22, 23, 24, 25, 26])]


# Assigning independent account-based variables
# design_maturity = 2 # 0 if immature (never done). 2 if mature and ready. 1: in between



accounts_vars['Design Maturity'] = [Design_Maturity, Design_Maturity, Design_Maturity, Design_Maturity, Design_Maturity, Design_Maturity] 

    


# Assigning dependent account-based variables

# Supply chain delay(months)= supply chain delay due to design immaturity (months) * delayfactor due to procurement inexperience
# supply chain delay due to design immaturity (months)= -6*design immaturity+12
# delayfactor due to procurement inexperience leads to extra 12 months


accounts_vars["Supply Chain Delay (monthhs)"] = - 6 *(accounts_vars['Design Maturity']) - 3*proc_exp + 18


accounts_vars.loc[len(accounts_vars)] = pd.Series(dtype='float64')
accounts_vars = accounts_vars.fillna('') # remove nan

accounts_vars.loc[len(accounts_vars.index)] = \
    ['', 'Baseline Value = ', 2, 0] 

accounts_vars.loc[len(accounts_vars.index)] = \
    ['', ' ', "Range = 0 : 1", "Range = 0 : 18"]  


accounts_vars

accounts_vars_styled = accounts_vars.style.apply(highlight_changes, axis=1, subset=pd.IndexSlice[:, ['Design Maturity']], baseline = 2)\
    .apply(highlight_changes, axis=1, subset=pd.IndexSlice[:, ['Supply Chain Delay (monthhs)']], baseline =0)\
    .set_caption("User-Input Account-Based levers <br> (highlighted in yellow if different from the baseline)").set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'red'),
        ('font-size', '20px')
    ]}])
accounts_vars_styled.hide()
# Out:
# <style type="text/css">
# #T_0fe4f caption {
#   color: red;
#   font-size: 20px;
# }
# #T_0fe4f_row0_col2, #T_0fe4f_row0_col3, #T_0fe4f_row1_col2, #T_0fe4f_row1_col3, #T_0fe4f_row2_col2, #T_0fe4f_row2_col3, #T_0fe4f_row3_col2, #T_0fe4f_row3_col3, #T_0fe4f_row4_col2, #T_0fe4f_row4_col3, #T_0fe4f_row5_col2, #T_0fe4f_row5_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0fe4f">
#   <caption>User-Input Account-Based levers <br> (highlighted in yellow if different from the baseline)</caption>
#   <thead>
#     <tr>
#       <th id="T_0fe4f_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_0fe4f_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_0fe4f_level0_col2" class="col_heading level0 col2" >Design Maturity</th>
#       <th id="T_0fe4f_level0_col3" class="col_heading level0 col3" >Supply Chain Delay (monthhs)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0fe4f_row0_col0" class="data row0 col0" >21</td>
#       <td id="T_0fe4f_row0_col1" class="data row0 col1" >Structures & Improvements</td>
#       <td id="T_0fe4f_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_0fe4f_row0_col3" class="data row0 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_0fe4f_row1_col1" class="data row1 col1" >Reactor System</td>
#       <td id="T_0fe4f_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_0fe4f_row1_col3" class="data row1 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_0fe4f_row2_col1" class="data row2 col1" >Energy Conversion System</td>
#       <td id="T_0fe4f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0fe4f_row2_col3" class="data row2 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_0fe4f_row3_col1" class="data row3 col1" >Electrical Equipment</td>
#       <td id="T_0fe4f_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_0fe4f_row3_col3" class="data row3 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row4_col0" class="data row4 col0" >25</td>
#       <td id="T_0fe4f_row4_col1" class="data row4 col1" >Initial fuel inventory</td>
#       <td id="T_0fe4f_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_0fe4f_row4_col3" class="data row4 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row5_col0" class="data row5 col0" >26</td>
#       <td id="T_0fe4f_row5_col1" class="data row5 col1" >Miscellaneous Equipment</td>
#       <td id="T_0fe4f_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_0fe4f_row5_col3" class="data row5 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row6_col0" class="data row6 col0" ></td>
#       <td id="T_0fe4f_row6_col1" class="data row6 col1" ></td>
#       <td id="T_0fe4f_row6_col2" class="data row6 col2" ></td>
#       <td id="T_0fe4f_row6_col3" class="data row6 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row7_col0" class="data row7 col0" ></td>
#       <td id="T_0fe4f_row7_col1" class="data row7 col1" >Baseline Value = </td>
#       <td id="T_0fe4f_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_0fe4f_row7_col3" class="data row7 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_0fe4f_row8_col0" class="data row8 col0" ></td>
#       <td id="T_0fe4f_row8_col1" class="data row8 col1" > </td>
#       <td id="T_0fe4f_row8_col2" class="data row8 col2" >Range = 0 : 1</td>
#       <td id="T_0fe4f_row8_col3" class="data row8 col3" >Range = 0 : 18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Section - 2 - 3 : Cost reduction framework
#
# <center><table>
#     <tr>
#         <th><img src="./framework_diagram.png",align="middle",height="10000"/></th>
#     </tr>
# </table>
# </center>

# %% [markdown]
# ## Section - 3 : Updating the Cost Summary based on user inputs

# %% [markdown]
# ### Section - 3-0 : Adding the factory cost to accounts 22 and 232.1

# %%
db = pd.DataFrame()
db = Reactor_data_0[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

db.loc[db.Account == 22, 'Factory Equipment Cost'] = None # clear old values
db.loc[db.Account == '232.1', 'Factory Equipment Cost'] = None # clear old values

# factory building cost
f_22   = 250000000
f_2321 = 150000000
db.loc[db.Account == 22, 'Factory Equipment Cost'] = ((Reactor_data_0.loc[Reactor_data_0.Account == 22, 'Factory Equipment Cost']) + f_22/num_orders )
db.loc[db.Account == '232.1', 'Factory Equipment Cost'] = ((Reactor_data_0.loc[Reactor_data_0.Account == '232.1', 'Factory Equipment Cost']) + f_2321/num_orders)


Reactor_data_fac = update_high_level_costs(db)


Reactor_data_fac_ = pd.DataFrame()
Reactor_data_fac_ = Reactor_data_fac[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_fac_pretty = prettify(Reactor_data_fac_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')

Reactor_data_fac_pretty
# Out:
# <style type="text/css">
# #T_8bf2c caption {
#   color: red;
#   font-size: 20px;
# }
# #T_8bf2c_row0_col0, #T_8bf2c_row0_col1, #T_8bf2c_row0_col2, #T_8bf2c_row0_col3, #T_8bf2c_row0_col4, #T_8bf2c_row0_col5, #T_8bf2c_row0_col6, #T_8bf2c_row12_col0, #T_8bf2c_row12_col1, #T_8bf2c_row12_col2, #T_8bf2c_row12_col3, #T_8bf2c_row12_col4, #T_8bf2c_row12_col5, #T_8bf2c_row12_col6, #T_8bf2c_row29_col0, #T_8bf2c_row29_col1, #T_8bf2c_row29_col2, #T_8bf2c_row29_col3, #T_8bf2c_row29_col4, #T_8bf2c_row29_col5, #T_8bf2c_row29_col6, #T_8bf2c_row39_col0, #T_8bf2c_row39_col1, #T_8bf2c_row39_col2, #T_8bf2c_row39_col3, #T_8bf2c_row39_col4, #T_8bf2c_row39_col5, #T_8bf2c_row39_col6, #T_8bf2c_row47_col0, #T_8bf2c_row47_col1, #T_8bf2c_row47_col2, #T_8bf2c_row47_col3, #T_8bf2c_row47_col4, #T_8bf2c_row47_col5, #T_8bf2c_row47_col6, #T_8bf2c_row51_col0, #T_8bf2c_row51_col1, #T_8bf2c_row51_col2, #T_8bf2c_row51_col3, #T_8bf2c_row51_col4, #T_8bf2c_row51_col5, #T_8bf2c_row51_col6, #T_8bf2c_row52_col0, #T_8bf2c_row52_col1, #T_8bf2c_row52_col2, #T_8bf2c_row52_col3, #T_8bf2c_row52_col4, #T_8bf2c_row52_col5, #T_8bf2c_row52_col6, #T_8bf2c_row53_col0, #T_8bf2c_row53_col1, #T_8bf2c_row53_col2, #T_8bf2c_row53_col3, #T_8bf2c_row53_col4, #T_8bf2c_row53_col5, #T_8bf2c_row53_col6, #T_8bf2c_row54_col0, #T_8bf2c_row54_col1, #T_8bf2c_row54_col2, #T_8bf2c_row54_col3, #T_8bf2c_row54_col4, #T_8bf2c_row54_col5, #T_8bf2c_row54_col6, #T_8bf2c_row55_col0, #T_8bf2c_row55_col1, #T_8bf2c_row55_col2, #T_8bf2c_row55_col3, #T_8bf2c_row55_col4, #T_8bf2c_row55_col5, #T_8bf2c_row55_col6, #T_8bf2c_row56_col0, #T_8bf2c_row56_col1, #T_8bf2c_row56_col2, #T_8bf2c_row56_col3, #T_8bf2c_row56_col4, #T_8bf2c_row56_col5, #T_8bf2c_row56_col6, #T_8bf2c_row57_col0, #T_8bf2c_row57_col1, #T_8bf2c_row57_col2, #T_8bf2c_row57_col3, #T_8bf2c_row57_col4, #T_8bf2c_row57_col5, #T_8bf2c_row57_col6, #T_8bf2c_row58_col0, #T_8bf2c_row58_col1, #T_8bf2c_row58_col2, #T_8bf2c_row58_col3, #T_8bf2c_row58_col4, #T_8bf2c_row58_col5, #T_8bf2c_row58_col6, #T_8bf2c_row59_col0, #T_8bf2c_row59_col1, #T_8bf2c_row59_col2, #T_8bf2c_row59_col3, #T_8bf2c_row59_col4, #T_8bf2c_row59_col5, #T_8bf2c_row59_col6, #T_8bf2c_row60_col0, #T_8bf2c_row60_col1, #T_8bf2c_row60_col2, #T_8bf2c_row60_col3, #T_8bf2c_row60_col4, #T_8bf2c_row60_col5, #T_8bf2c_row60_col6, #T_8bf2c_row61_col0, #T_8bf2c_row61_col1, #T_8bf2c_row61_col2, #T_8bf2c_row61_col3, #T_8bf2c_row61_col4, #T_8bf2c_row61_col5, #T_8bf2c_row61_col6, #T_8bf2c_row62_col0, #T_8bf2c_row62_col1, #T_8bf2c_row62_col2, #T_8bf2c_row62_col3, #T_8bf2c_row62_col4, #T_8bf2c_row62_col5, #T_8bf2c_row62_col6, #T_8bf2c_row63_col0, #T_8bf2c_row63_col1, #T_8bf2c_row63_col2, #T_8bf2c_row63_col3, #T_8bf2c_row63_col4, #T_8bf2c_row63_col5, #T_8bf2c_row63_col6 {
#   font-weight: bold;
# }
# #T_8bf2c_row64_col0, #T_8bf2c_row64_col1, #T_8bf2c_row64_col2, #T_8bf2c_row64_col3, #T_8bf2c_row64_col4, #T_8bf2c_row64_col5, #T_8bf2c_row64_col6, #T_8bf2c_row65_col0, #T_8bf2c_row65_col1, #T_8bf2c_row65_col2, #T_8bf2c_row65_col3, #T_8bf2c_row65_col4, #T_8bf2c_row65_col5, #T_8bf2c_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_8bf2c">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_8bf2c_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_8bf2c_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_8bf2c_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_8bf2c_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_8bf2c_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_8bf2c_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_8bf2c_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8bf2c_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_8bf2c_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_8bf2c_row0_col2" class="data row0 col2" ></td>
#       <td id="T_8bf2c_row0_col3" class="data row0 col3" ></td>
#       <td id="T_8bf2c_row0_col4" class="data row0 col4" ></td>
#       <td id="T_8bf2c_row0_col5" class="data row0 col5" ></td>
#       <td id="T_8bf2c_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_8bf2c_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_8bf2c_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_8bf2c_row1_col3" class="data row1 col3" ></td>
#       <td id="T_8bf2c_row1_col4" class="data row1 col4" ></td>
#       <td id="T_8bf2c_row1_col5" class="data row1 col5" ></td>
#       <td id="T_8bf2c_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_8bf2c_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_8bf2c_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_8bf2c_row2_col3" class="data row2 col3" ></td>
#       <td id="T_8bf2c_row2_col4" class="data row2 col4" ></td>
#       <td id="T_8bf2c_row2_col5" class="data row2 col5" ></td>
#       <td id="T_8bf2c_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_8bf2c_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_8bf2c_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_8bf2c_row3_col3" class="data row3 col3" ></td>
#       <td id="T_8bf2c_row3_col4" class="data row3 col4" ></td>
#       <td id="T_8bf2c_row3_col5" class="data row3 col5" ></td>
#       <td id="T_8bf2c_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_8bf2c_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_8bf2c_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_8bf2c_row4_col3" class="data row4 col3" ></td>
#       <td id="T_8bf2c_row4_col4" class="data row4 col4" ></td>
#       <td id="T_8bf2c_row4_col5" class="data row4 col5" ></td>
#       <td id="T_8bf2c_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_8bf2c_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_8bf2c_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_8bf2c_row5_col3" class="data row5 col3" ></td>
#       <td id="T_8bf2c_row5_col4" class="data row5 col4" ></td>
#       <td id="T_8bf2c_row5_col5" class="data row5 col5" ></td>
#       <td id="T_8bf2c_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_8bf2c_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_8bf2c_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_8bf2c_row6_col3" class="data row6 col3" ></td>
#       <td id="T_8bf2c_row6_col4" class="data row6 col4" ></td>
#       <td id="T_8bf2c_row6_col5" class="data row6 col5" ></td>
#       <td id="T_8bf2c_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_8bf2c_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_8bf2c_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_8bf2c_row7_col3" class="data row7 col3" ></td>
#       <td id="T_8bf2c_row7_col4" class="data row7 col4" ></td>
#       <td id="T_8bf2c_row7_col5" class="data row7 col5" ></td>
#       <td id="T_8bf2c_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8bf2c_row8_col0" class="data row8 col0" ></td>
#       <td id="T_8bf2c_row8_col1" class="data row8 col1" ></td>
#       <td id="T_8bf2c_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-1 : The land cost & Taxes

# %%
# The cost of the land is 22000$ per acre (500 acres
# The cost is multiplied by the new $/acre divided by the old one
# Accounts 11 and 12 are changed


db = pd.DataFrame()
db = Reactor_data_fac[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()


db.loc[db.Account == 11, 'Total Cost (USD)'] = None # clear old values
db.loc[db.Account == 12, 'Total Cost (USD)'] = None # clear old values
db.loc[db.Account == 51, 'Total Cost (USD)'] = None # clear old values


db.loc[db.Account == 11, 'Total Cost (USD)'] = (land_cost_per_acre /22000)*(Reactor_data_fac.loc[Reactor_data_fac.Account == 11, 'Total Cost (USD)'].values)
db.loc[db.Account == 12, 'Total Cost (USD)'] = (land_cost_per_acre /22000)*(Reactor_data_fac.loc[Reactor_data_fac.Account == 12, 'Total Cost (USD)'].values)


# The taxes scale with increasing the land cost 
db.loc[db.Account == 51, 'Total Cost (USD)'] = (land_cost_per_acre /22000)*(Reactor_data_fac.loc[Reactor_data_fac.Account == 51, 'Total Cost (USD)'].values)

db.loc[db.Account == 51, 'Total Cost (USD)']
Reactor_data_updated_1 = update_high_level_costs(db)


Reactor_data_updated_1_ = pd.DataFrame()
Reactor_data_updated_1_ = Reactor_data_updated_1[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_1_pretty = prettify(Reactor_data_updated_1_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')

Reactor_data_updated_1_pretty
# Out:
# <style type="text/css">
# #T_2a283 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_2a283_row0_col0, #T_2a283_row0_col1, #T_2a283_row0_col2, #T_2a283_row0_col3, #T_2a283_row0_col4, #T_2a283_row0_col5, #T_2a283_row0_col6, #T_2a283_row12_col0, #T_2a283_row12_col1, #T_2a283_row12_col2, #T_2a283_row12_col3, #T_2a283_row12_col4, #T_2a283_row12_col5, #T_2a283_row12_col6, #T_2a283_row29_col0, #T_2a283_row29_col1, #T_2a283_row29_col2, #T_2a283_row29_col3, #T_2a283_row29_col4, #T_2a283_row29_col5, #T_2a283_row29_col6, #T_2a283_row39_col0, #T_2a283_row39_col1, #T_2a283_row39_col2, #T_2a283_row39_col3, #T_2a283_row39_col4, #T_2a283_row39_col5, #T_2a283_row39_col6, #T_2a283_row47_col0, #T_2a283_row47_col1, #T_2a283_row47_col2, #T_2a283_row47_col3, #T_2a283_row47_col4, #T_2a283_row47_col5, #T_2a283_row47_col6, #T_2a283_row51_col0, #T_2a283_row51_col1, #T_2a283_row51_col2, #T_2a283_row51_col3, #T_2a283_row51_col4, #T_2a283_row51_col5, #T_2a283_row51_col6, #T_2a283_row52_col0, #T_2a283_row52_col1, #T_2a283_row52_col2, #T_2a283_row52_col3, #T_2a283_row52_col4, #T_2a283_row52_col5, #T_2a283_row52_col6, #T_2a283_row53_col0, #T_2a283_row53_col1, #T_2a283_row53_col2, #T_2a283_row53_col3, #T_2a283_row53_col4, #T_2a283_row53_col5, #T_2a283_row53_col6, #T_2a283_row54_col0, #T_2a283_row54_col1, #T_2a283_row54_col2, #T_2a283_row54_col3, #T_2a283_row54_col4, #T_2a283_row54_col5, #T_2a283_row54_col6, #T_2a283_row55_col0, #T_2a283_row55_col1, #T_2a283_row55_col2, #T_2a283_row55_col3, #T_2a283_row55_col4, #T_2a283_row55_col5, #T_2a283_row55_col6, #T_2a283_row56_col0, #T_2a283_row56_col1, #T_2a283_row56_col2, #T_2a283_row56_col3, #T_2a283_row56_col4, #T_2a283_row56_col5, #T_2a283_row56_col6, #T_2a283_row57_col0, #T_2a283_row57_col1, #T_2a283_row57_col2, #T_2a283_row57_col3, #T_2a283_row57_col4, #T_2a283_row57_col5, #T_2a283_row57_col6, #T_2a283_row58_col0, #T_2a283_row58_col1, #T_2a283_row58_col2, #T_2a283_row58_col3, #T_2a283_row58_col4, #T_2a283_row58_col5, #T_2a283_row58_col6, #T_2a283_row59_col0, #T_2a283_row59_col1, #T_2a283_row59_col2, #T_2a283_row59_col3, #T_2a283_row59_col4, #T_2a283_row59_col5, #T_2a283_row59_col6, #T_2a283_row60_col0, #T_2a283_row60_col1, #T_2a283_row60_col2, #T_2a283_row60_col3, #T_2a283_row60_col4, #T_2a283_row60_col5, #T_2a283_row60_col6, #T_2a283_row61_col0, #T_2a283_row61_col1, #T_2a283_row61_col2, #T_2a283_row61_col3, #T_2a283_row61_col4, #T_2a283_row61_col5, #T_2a283_row61_col6, #T_2a283_row62_col0, #T_2a283_row62_col1, #T_2a283_row62_col2, #T_2a283_row62_col3, #T_2a283_row62_col4, #T_2a283_row62_col5, #T_2a283_row62_col6, #T_2a283_row63_col0, #T_2a283_row63_col1, #T_2a283_row63_col2, #T_2a283_row63_col3, #T_2a283_row63_col4, #T_2a283_row63_col5, #T_2a283_row63_col6 {
#   font-weight: bold;
# }
# #T_2a283_row64_col0, #T_2a283_row64_col1, #T_2a283_row64_col2, #T_2a283_row64_col3, #T_2a283_row64_col4, #T_2a283_row64_col5, #T_2a283_row64_col6, #T_2a283_row65_col0, #T_2a283_row65_col1, #T_2a283_row65_col2, #T_2a283_row65_col3, #T_2a283_row65_col4, #T_2a283_row65_col5, #T_2a283_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_2a283">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_2a283_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_2a283_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_2a283_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_2a283_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_2a283_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_2a283_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_2a283_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a283_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_2a283_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_2a283_row0_col2" class="data row0 col2" ></td>
#       <td id="T_2a283_row0_col3" class="data row0 col3" ></td>
#       <td id="T_2a283_row0_col4" class="data row0 col4" ></td>
#       <td id="T_2a283_row0_col5" class="data row0 col5" ></td>
#       <td id="T_2a283_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_2a283_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_2a283_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_2a283_row1_col3" class="data row1 col3" ></td>
#       <td id="T_2a283_row1_col4" class="data row1 col4" ></td>
#       <td id="T_2a283_row1_col5" class="data row1 col5" ></td>
#       <td id="T_2a283_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_2a283_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_2a283_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_2a283_row2_col3" class="data row2 col3" ></td>
#       <td id="T_2a283_row2_col4" class="data row2 col4" ></td>
#       <td id="T_2a283_row2_col5" class="data row2 col5" ></td>
#       <td id="T_2a283_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_2a283_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_2a283_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_2a283_row3_col3" class="data row3 col3" ></td>
#       <td id="T_2a283_row3_col4" class="data row3 col4" ></td>
#       <td id="T_2a283_row3_col5" class="data row3 col5" ></td>
#       <td id="T_2a283_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_2a283_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_2a283_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_2a283_row4_col3" class="data row4 col3" ></td>
#       <td id="T_2a283_row4_col4" class="data row4 col4" ></td>
#       <td id="T_2a283_row4_col5" class="data row4 col5" ></td>
#       <td id="T_2a283_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_2a283_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_2a283_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_2a283_row5_col3" class="data row5 col3" ></td>
#       <td id="T_2a283_row5_col4" class="data row5 col4" ></td>
#       <td id="T_2a283_row5_col5" class="data row5 col5" ></td>
#       <td id="T_2a283_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_2a283_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_2a283_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_2a283_row6_col3" class="data row6 col3" ></td>
#       <td id="T_2a283_row6_col4" class="data row6 col4" ></td>
#       <td id="T_2a283_row6_col5" class="data row6 col5" ></td>
#       <td id="T_2a283_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_2a283_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_2a283_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_2a283_row7_col3" class="data row7 col3" ></td>
#       <td id="T_2a283_row7_col4" class="data row7 col4" ></td>
#       <td id="T_2a283_row7_col5" class="data row7 col5" ></td>
#       <td id="T_2a283_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_2a283_row8_col0" class="data row8 col0" ></td>
#       <td id="T_2a283_row8_col1" class="data row8 col1" ></td>
#       <td id="T_2a283_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-2 : Whether the Reactor Building and BOP are nuclear grade equipment

# %%
# if the BOP is non-nuclear, the cost reduction factor for account 213 is 0.6
# Also, the cost reduction factor for account 232.1 is 0.6 (for factory and labor but not material)

# If the reactor building is non nuclear, the cost reduction factor for acount 212 is 0.6
db = pd.DataFrame()

db = Reactor_data_updated_1[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

db.loc[db.Account == 212, 'Site Material Cost'] = None # clear old values
db.loc[db.Account == 212, 'Site Labor Cost'] = None # clear old values
db.loc[db.Account ==  212, 'Site Labor Hours'] = None
db.loc[db.Account ==  212, 'Factory Equipment Cost'] = None

db.loc[db.Account ==  213, 'Site Material Cost'] = None
db.loc[db.Account ==  213, 'Site Labor Cost']  = None
db.loc[db.Account ==  213, 'Site Labor Hours'] = None
db.loc[db.Account ==  213, 'Factory Equipment Cost'] = None

db.loc[db.Account ==  '232.1', 'Factory Equipment Cost'] = None
db.loc[db.Account ==  '232.1', 'Site Labor Cost'] = None
db.loc[db.Account ==  '232.1', 'Site Labor Hours'] = None


if RB_grade == "non_nuclear":
    db.loc[db.Account == 212, 'Site Material Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Site Material Cost']).values)
    db.loc[db.Account == 212, 'Site Labor Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Site Labor Cost']).values)
    db.loc[db.Account == 212,'Site Labor Hours'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Site Labor Hours']).values)
    db.loc[db.Account == 212,'Factory Equipment Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Factory Equipment Cost']).values)

else:
    db.loc[db.Account == 212, 'Site Material Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Site Material Cost']).values)
    db.loc[db.Account == 212, 'Site Labor Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Site Labor Cost']).values)
    db.loc[db.Account == 212,'Site Labor Hours'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Site Labor Hours']).values)
    db.loc[db.Account == 212,'Factory Equipment Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 212, 'Site Labor Hours']).values)

    
if BOP_grade == "non_nuclear":
    db.loc[db.Account == 213, 'Site Material Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Site Material Cost']).values)
    db.loc[db.Account == 213, 'Site Labor Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Site Labor Cost']).values)
    db.loc[db.Account == 213, 'Site Labor Hours'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Site Labor Hours']).values)
    db.loc[db.Account == 213, 'Factory Equipment Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Factory Equipment Cost']).values)

    db.loc[db.Account == '232.1', 'Factory Equipment Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == '232.1', 'Factory Equipment Cost']).values)
    db.loc[db.Account == '232.1', 'Site Labor Hours'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == '232.1', 'Site Labor Hours']).values)
    db.loc[db.Account == '232.1', 'Site Labor Cost'] = 0.6*((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == '232.1', 'Site Labor Cost']).values)


else:
    db.loc[db.Account == 213, 'Site Material Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Site Material Cost']).values)
    db.loc[db.Account == 213, 'Site Labor Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Site Labor Cost']).values)
    db.loc[db.Account == 213, 'Site Labor Hours'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Site Labor Hours']).values)
    db.loc[db.Account == 213, 'Factory Equipment Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == 213, 'Factory Equipment Cost']).values)

    db.loc[db.Account == '232.1', 'Factory Equipment Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == '232.1', 'Factory Equipment Cost']).values)
    db.loc[db.Account == '232.1', 'Site Labor Hours'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == '232.1', 'Site Labor Hours']).values)
    db.loc[db.Account == '232.1', 'Site Labor Cost'] = ((Reactor_data_updated_1.loc[Reactor_data_updated_1.Account == '232.1', 'Site Labor Cost']).values)


Reactor_data_updated_2 = update_high_level_costs(db)

Reactor_data_updated_2_ = pd.DataFrame()
Reactor_data_updated_2_ = Reactor_data_updated_2[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_2_pretty = prettify(Reactor_data_updated_2_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_2_pretty
# Out:
# <style type="text/css">
# #T_66fa0 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_66fa0_row0_col0, #T_66fa0_row0_col1, #T_66fa0_row0_col2, #T_66fa0_row0_col3, #T_66fa0_row0_col4, #T_66fa0_row0_col5, #T_66fa0_row0_col6, #T_66fa0_row12_col0, #T_66fa0_row12_col1, #T_66fa0_row12_col2, #T_66fa0_row12_col3, #T_66fa0_row12_col4, #T_66fa0_row12_col5, #T_66fa0_row12_col6, #T_66fa0_row29_col0, #T_66fa0_row29_col1, #T_66fa0_row29_col2, #T_66fa0_row29_col3, #T_66fa0_row29_col4, #T_66fa0_row29_col5, #T_66fa0_row29_col6, #T_66fa0_row39_col0, #T_66fa0_row39_col1, #T_66fa0_row39_col2, #T_66fa0_row39_col3, #T_66fa0_row39_col4, #T_66fa0_row39_col5, #T_66fa0_row39_col6, #T_66fa0_row47_col0, #T_66fa0_row47_col1, #T_66fa0_row47_col2, #T_66fa0_row47_col3, #T_66fa0_row47_col4, #T_66fa0_row47_col5, #T_66fa0_row47_col6, #T_66fa0_row51_col0, #T_66fa0_row51_col1, #T_66fa0_row51_col2, #T_66fa0_row51_col3, #T_66fa0_row51_col4, #T_66fa0_row51_col5, #T_66fa0_row51_col6, #T_66fa0_row52_col0, #T_66fa0_row52_col1, #T_66fa0_row52_col2, #T_66fa0_row52_col3, #T_66fa0_row52_col4, #T_66fa0_row52_col5, #T_66fa0_row52_col6, #T_66fa0_row53_col0, #T_66fa0_row53_col1, #T_66fa0_row53_col2, #T_66fa0_row53_col3, #T_66fa0_row53_col4, #T_66fa0_row53_col5, #T_66fa0_row53_col6, #T_66fa0_row54_col0, #T_66fa0_row54_col1, #T_66fa0_row54_col2, #T_66fa0_row54_col3, #T_66fa0_row54_col4, #T_66fa0_row54_col5, #T_66fa0_row54_col6, #T_66fa0_row55_col0, #T_66fa0_row55_col1, #T_66fa0_row55_col2, #T_66fa0_row55_col3, #T_66fa0_row55_col4, #T_66fa0_row55_col5, #T_66fa0_row55_col6, #T_66fa0_row56_col0, #T_66fa0_row56_col1, #T_66fa0_row56_col2, #T_66fa0_row56_col3, #T_66fa0_row56_col4, #T_66fa0_row56_col5, #T_66fa0_row56_col6, #T_66fa0_row57_col0, #T_66fa0_row57_col1, #T_66fa0_row57_col2, #T_66fa0_row57_col3, #T_66fa0_row57_col4, #T_66fa0_row57_col5, #T_66fa0_row57_col6, #T_66fa0_row58_col0, #T_66fa0_row58_col1, #T_66fa0_row58_col2, #T_66fa0_row58_col3, #T_66fa0_row58_col4, #T_66fa0_row58_col5, #T_66fa0_row58_col6, #T_66fa0_row59_col0, #T_66fa0_row59_col1, #T_66fa0_row59_col2, #T_66fa0_row59_col3, #T_66fa0_row59_col4, #T_66fa0_row59_col5, #T_66fa0_row59_col6, #T_66fa0_row60_col0, #T_66fa0_row60_col1, #T_66fa0_row60_col2, #T_66fa0_row60_col3, #T_66fa0_row60_col4, #T_66fa0_row60_col5, #T_66fa0_row60_col6, #T_66fa0_row61_col0, #T_66fa0_row61_col1, #T_66fa0_row61_col2, #T_66fa0_row61_col3, #T_66fa0_row61_col4, #T_66fa0_row61_col5, #T_66fa0_row61_col6, #T_66fa0_row62_col0, #T_66fa0_row62_col1, #T_66fa0_row62_col2, #T_66fa0_row62_col3, #T_66fa0_row62_col4, #T_66fa0_row62_col5, #T_66fa0_row62_col6, #T_66fa0_row63_col0, #T_66fa0_row63_col1, #T_66fa0_row63_col2, #T_66fa0_row63_col3, #T_66fa0_row63_col4, #T_66fa0_row63_col5, #T_66fa0_row63_col6 {
#   font-weight: bold;
# }
# #T_66fa0_row64_col0, #T_66fa0_row64_col1, #T_66fa0_row64_col2, #T_66fa0_row64_col3, #T_66fa0_row64_col4, #T_66fa0_row64_col5, #T_66fa0_row64_col6, #T_66fa0_row65_col0, #T_66fa0_row65_col1, #T_66fa0_row65_col2, #T_66fa0_row65_col3, #T_66fa0_row65_col4, #T_66fa0_row65_col5, #T_66fa0_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_66fa0">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_66fa0_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_66fa0_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_66fa0_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_66fa0_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_66fa0_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_66fa0_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_66fa0_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_66fa0_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_66fa0_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_66fa0_row0_col2" class="data row0 col2" ></td>
#       <td id="T_66fa0_row0_col3" class="data row0 col3" ></td>
#       <td id="T_66fa0_row0_col4" class="data row0 col4" ></td>
#       <td id="T_66fa0_row0_col5" class="data row0 col5" ></td>
#       <td id="T_66fa0_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_66fa0_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_66fa0_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_66fa0_row1_col3" class="data row1 col3" ></td>
#       <td id="T_66fa0_row1_col4" class="data row1 col4" ></td>
#       <td id="T_66fa0_row1_col5" class="data row1 col5" ></td>
#       <td id="T_66fa0_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_66fa0_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_66fa0_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_66fa0_row2_col3" class="data row2 col3" ></td>
#       <td id="T_66fa0_row2_col4" class="data row2 col4" ></td>
#       <td id="T_66fa0_row2_col5" class="data row2 col5" ></td>
#       <td id="T_66fa0_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_66fa0_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_66fa0_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_66fa0_row3_col3" class="data row3 col3" ></td>
#       <td id="T_66fa0_row3_col4" class="data row3 col4" ></td>
#       <td id="T_66fa0_row3_col5" class="data row3 col5" ></td>
#       <td id="T_66fa0_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_66fa0_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_66fa0_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_66fa0_row4_col3" class="data row4 col3" ></td>
#       <td id="T_66fa0_row4_col4" class="data row4 col4" ></td>
#       <td id="T_66fa0_row4_col5" class="data row4 col5" ></td>
#       <td id="T_66fa0_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_66fa0_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_66fa0_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_66fa0_row5_col3" class="data row5 col3" ></td>
#       <td id="T_66fa0_row5_col4" class="data row5 col4" ></td>
#       <td id="T_66fa0_row5_col5" class="data row5 col5" ></td>
#       <td id="T_66fa0_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_66fa0_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_66fa0_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_66fa0_row6_col3" class="data row6 col3" ></td>
#       <td id="T_66fa0_row6_col4" class="data row6 col4" ></td>
#       <td id="T_66fa0_row6_col5" class="data row6 col5" ></td>
#       <td id="T_66fa0_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_66fa0_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_66fa0_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_66fa0_row7_col3" class="data row7 col3" ></td>
#       <td id="T_66fa0_row7_col4" class="data row7 col4" ></td>
#       <td id="T_66fa0_row7_col5" class="data row7 col5" ></td>
#       <td id="T_66fa0_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_66fa0_row8_col0" class="data row8 col0" ></td>
#       <td id="T_66fa0_row8_col1" class="data row8 col1" ></td>
#       <td id="T_66fa0_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-3  : Modularity

# %%
# If TRUE, increase factory cost by <factor>, reduce site material hours by <factor>, and reduce site labor hours & cost by <factor>.
# This applies only on accuount 21
# we apply the modularity on acoounts 212, 213, 211 plus 214 to 219	 and account 21 updates automatically
# The multipliers are 1.3, 0.3. 0.3

db = pd.DataFrame()

db = Reactor_data_updated_2[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()



# remove old stuff

for x in [212, 213,  '211 plus 214 to 219']:  
    db.loc[db.Account == x, 'Factory Equipment Cost'] = None # clear old values
    db.loc[db.Account == x, 'Site Labor Hours'] = None
    db.loc[db.Account == x, 'Site Labor Cost'] = None
    db.loc[db.Account == x, 'Site Material Cost'] = None



for x in [212, 213,'211 plus 214 to 219']: 
    if mod == 'modularized':
        db.loc[db.Account == x, 'Factory Equipment Cost'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Factory Equipment Cost']).values)*1.3
        
        db.loc[db.Account == x, 'Site Labor Hours'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Site Labor Hours']).values)*0.7
        
        db.loc[db.Account == x, 'Site Labor Cost'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Site Labor Cost']).values)*0.7
    
        db.loc[db.Account == x, 'Site Material Cost'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Site Material Cost']).values)*0.7

    else:
        db.loc[db.Account == x, 'Factory Equipment Cost'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Factory Equipment Cost']).values)*1
        
        db.loc[db.Account == x, 'Site Labor Hours'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Site Labor Hours']).values)*1
        
        db.loc[db.Account == x, 'Site Labor Cost'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Site Labor Cost']).values)*1
    
        db.loc[db.Account == x, 'Site Material Cost'] =\
        ((Reactor_data_updated_2.loc[Reactor_data_updated_2.Account == x, 'Site Material Cost']).values)*1

Reactor_data_updated_3 = update_high_level_costs(db)
Reactor_data_updated_3_ = pd.DataFrame()
Reactor_data_updated_3_ = Reactor_data_updated_3[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_3_pretty = prettify(Reactor_data_updated_3_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_3_pretty
# Out:
# <style type="text/css">
# #T_fd40b caption {
#   color: red;
#   font-size: 20px;
# }
# #T_fd40b_row0_col0, #T_fd40b_row0_col1, #T_fd40b_row0_col2, #T_fd40b_row0_col3, #T_fd40b_row0_col4, #T_fd40b_row0_col5, #T_fd40b_row0_col6, #T_fd40b_row12_col0, #T_fd40b_row12_col1, #T_fd40b_row12_col2, #T_fd40b_row12_col3, #T_fd40b_row12_col4, #T_fd40b_row12_col5, #T_fd40b_row12_col6, #T_fd40b_row29_col0, #T_fd40b_row29_col1, #T_fd40b_row29_col2, #T_fd40b_row29_col3, #T_fd40b_row29_col4, #T_fd40b_row29_col5, #T_fd40b_row29_col6, #T_fd40b_row39_col0, #T_fd40b_row39_col1, #T_fd40b_row39_col2, #T_fd40b_row39_col3, #T_fd40b_row39_col4, #T_fd40b_row39_col5, #T_fd40b_row39_col6, #T_fd40b_row47_col0, #T_fd40b_row47_col1, #T_fd40b_row47_col2, #T_fd40b_row47_col3, #T_fd40b_row47_col4, #T_fd40b_row47_col5, #T_fd40b_row47_col6, #T_fd40b_row51_col0, #T_fd40b_row51_col1, #T_fd40b_row51_col2, #T_fd40b_row51_col3, #T_fd40b_row51_col4, #T_fd40b_row51_col5, #T_fd40b_row51_col6, #T_fd40b_row52_col0, #T_fd40b_row52_col1, #T_fd40b_row52_col2, #T_fd40b_row52_col3, #T_fd40b_row52_col4, #T_fd40b_row52_col5, #T_fd40b_row52_col6, #T_fd40b_row53_col0, #T_fd40b_row53_col1, #T_fd40b_row53_col2, #T_fd40b_row53_col3, #T_fd40b_row53_col4, #T_fd40b_row53_col5, #T_fd40b_row53_col6, #T_fd40b_row54_col0, #T_fd40b_row54_col1, #T_fd40b_row54_col2, #T_fd40b_row54_col3, #T_fd40b_row54_col4, #T_fd40b_row54_col5, #T_fd40b_row54_col6, #T_fd40b_row55_col0, #T_fd40b_row55_col1, #T_fd40b_row55_col2, #T_fd40b_row55_col3, #T_fd40b_row55_col4, #T_fd40b_row55_col5, #T_fd40b_row55_col6, #T_fd40b_row56_col0, #T_fd40b_row56_col1, #T_fd40b_row56_col2, #T_fd40b_row56_col3, #T_fd40b_row56_col4, #T_fd40b_row56_col5, #T_fd40b_row56_col6, #T_fd40b_row57_col0, #T_fd40b_row57_col1, #T_fd40b_row57_col2, #T_fd40b_row57_col3, #T_fd40b_row57_col4, #T_fd40b_row57_col5, #T_fd40b_row57_col6, #T_fd40b_row58_col0, #T_fd40b_row58_col1, #T_fd40b_row58_col2, #T_fd40b_row58_col3, #T_fd40b_row58_col4, #T_fd40b_row58_col5, #T_fd40b_row58_col6, #T_fd40b_row59_col0, #T_fd40b_row59_col1, #T_fd40b_row59_col2, #T_fd40b_row59_col3, #T_fd40b_row59_col4, #T_fd40b_row59_col5, #T_fd40b_row59_col6, #T_fd40b_row60_col0, #T_fd40b_row60_col1, #T_fd40b_row60_col2, #T_fd40b_row60_col3, #T_fd40b_row60_col4, #T_fd40b_row60_col5, #T_fd40b_row60_col6, #T_fd40b_row61_col0, #T_fd40b_row61_col1, #T_fd40b_row61_col2, #T_fd40b_row61_col3, #T_fd40b_row61_col4, #T_fd40b_row61_col5, #T_fd40b_row61_col6, #T_fd40b_row62_col0, #T_fd40b_row62_col1, #T_fd40b_row62_col2, #T_fd40b_row62_col3, #T_fd40b_row62_col4, #T_fd40b_row62_col5, #T_fd40b_row62_col6, #T_fd40b_row63_col0, #T_fd40b_row63_col1, #T_fd40b_row63_col2, #T_fd40b_row63_col3, #T_fd40b_row63_col4, #T_fd40b_row63_col5, #T_fd40b_row63_col6 {
#   font-weight: bold;
# }
# #T_fd40b_row64_col0, #T_fd40b_row64_col1, #T_fd40b_row64_col2, #T_fd40b_row64_col3, #T_fd40b_row64_col4, #T_fd40b_row64_col5, #T_fd40b_row64_col6, #T_fd40b_row65_col0, #T_fd40b_row65_col1, #T_fd40b_row65_col2, #T_fd40b_row65_col3, #T_fd40b_row65_col4, #T_fd40b_row65_col5, #T_fd40b_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_fd40b">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_fd40b_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_fd40b_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_fd40b_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_fd40b_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_fd40b_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_fd40b_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_fd40b_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fd40b_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_fd40b_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_fd40b_row0_col2" class="data row0 col2" ></td>
#       <td id="T_fd40b_row0_col3" class="data row0 col3" ></td>
#       <td id="T_fd40b_row0_col4" class="data row0 col4" ></td>
#       <td id="T_fd40b_row0_col5" class="data row0 col5" ></td>
#       <td id="T_fd40b_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_fd40b_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_fd40b_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_fd40b_row1_col3" class="data row1 col3" ></td>
#       <td id="T_fd40b_row1_col4" class="data row1 col4" ></td>
#       <td id="T_fd40b_row1_col5" class="data row1 col5" ></td>
#       <td id="T_fd40b_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_fd40b_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_fd40b_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_fd40b_row2_col3" class="data row2 col3" ></td>
#       <td id="T_fd40b_row2_col4" class="data row2 col4" ></td>
#       <td id="T_fd40b_row2_col5" class="data row2 col5" ></td>
#       <td id="T_fd40b_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_fd40b_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_fd40b_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_fd40b_row3_col3" class="data row3 col3" ></td>
#       <td id="T_fd40b_row3_col4" class="data row3 col4" ></td>
#       <td id="T_fd40b_row3_col5" class="data row3 col5" ></td>
#       <td id="T_fd40b_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_fd40b_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_fd40b_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_fd40b_row4_col3" class="data row4 col3" ></td>
#       <td id="T_fd40b_row4_col4" class="data row4 col4" ></td>
#       <td id="T_fd40b_row4_col5" class="data row4 col5" ></td>
#       <td id="T_fd40b_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_fd40b_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_fd40b_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_fd40b_row5_col3" class="data row5 col3" ></td>
#       <td id="T_fd40b_row5_col4" class="data row5 col4" ></td>
#       <td id="T_fd40b_row5_col5" class="data row5 col5" ></td>
#       <td id="T_fd40b_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_fd40b_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_fd40b_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_fd40b_row6_col3" class="data row6 col3" ></td>
#       <td id="T_fd40b_row6_col4" class="data row6 col4" ></td>
#       <td id="T_fd40b_row6_col5" class="data row6 col5" ></td>
#       <td id="T_fd40b_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_fd40b_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_fd40b_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_fd40b_row7_col3" class="data row7 col3" ></td>
#       <td id="T_fd40b_row7_col4" class="data row7 col4" ></td>
#       <td id="T_fd40b_row7_col5" class="data row7 col5" ></td>
#       <td id="T_fd40b_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fd40b_row8_col0" class="data row8 col0" ></td>
#       <td id="T_fd40b_row8_col1" class="data row8 col1" ></td>
#       <td id="T_fd40b_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-4 : Bulk Ordering

# %%
#The factory equipment cost of  accounts 22 and 232.1 has to be divided by the number of orders
# The factory equipment cost of account 22 is multiplied by a reuction factor
# The factory equipment cost of account 232.1 is multiplied by a reduction factor

db = pd.DataFrame()

db = Reactor_data_updated_3[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

# esimtated learning rates
lr22   = 0.1802341659291420
lr2321 = 0.2607462372040820

# These reduction factor are calculated as follows
reduction_factor_22 = 0 # initialization
reduction_factor_2321 = 0

for ith_unit in  range(1,num_orders+1):
    reduction_factor_22+=((1 - lr22)**np.log2(ith_unit))/num_orders # for account 22
    reduction_factor_2321+=((1 - lr2321)**np.log2(ith_unit))/num_orders # for account 232.1


    
for x in [ 22, '232.1']:  
    db.loc[db.Account == x, 'Factory Equipment Cost'] = None # clear old values


db.loc[db.Account == 22, 'Factory Equipment Cost']       = reduction_factor_22   *  (( Reactor_data_updated_3.loc[ Reactor_data_updated_3.Account == 22, 'Factory Equipment Cost']))  
db.loc[db.Account == '232.1', 'Factory Equipment Cost']  = reduction_factor_2321 *  (( Reactor_data_updated_3.loc[ Reactor_data_updated_3.Account == '232.1', 'Factory Equipment Cost']))  

 

Reactor_data_updated_4 = update_high_level_costs(db)
Reactor_data_updated_4_ = pd.DataFrame()
Reactor_data_updated_4_ = Reactor_data_updated_4[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_4_pretty = prettify(Reactor_data_updated_4_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_4_pretty
# Out:
# <style type="text/css">
# #T_fc2c2 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_fc2c2_row0_col0, #T_fc2c2_row0_col1, #T_fc2c2_row0_col2, #T_fc2c2_row0_col3, #T_fc2c2_row0_col4, #T_fc2c2_row0_col5, #T_fc2c2_row0_col6, #T_fc2c2_row12_col0, #T_fc2c2_row12_col1, #T_fc2c2_row12_col2, #T_fc2c2_row12_col3, #T_fc2c2_row12_col4, #T_fc2c2_row12_col5, #T_fc2c2_row12_col6, #T_fc2c2_row29_col0, #T_fc2c2_row29_col1, #T_fc2c2_row29_col2, #T_fc2c2_row29_col3, #T_fc2c2_row29_col4, #T_fc2c2_row29_col5, #T_fc2c2_row29_col6, #T_fc2c2_row39_col0, #T_fc2c2_row39_col1, #T_fc2c2_row39_col2, #T_fc2c2_row39_col3, #T_fc2c2_row39_col4, #T_fc2c2_row39_col5, #T_fc2c2_row39_col6, #T_fc2c2_row47_col0, #T_fc2c2_row47_col1, #T_fc2c2_row47_col2, #T_fc2c2_row47_col3, #T_fc2c2_row47_col4, #T_fc2c2_row47_col5, #T_fc2c2_row47_col6, #T_fc2c2_row51_col0, #T_fc2c2_row51_col1, #T_fc2c2_row51_col2, #T_fc2c2_row51_col3, #T_fc2c2_row51_col4, #T_fc2c2_row51_col5, #T_fc2c2_row51_col6, #T_fc2c2_row52_col0, #T_fc2c2_row52_col1, #T_fc2c2_row52_col2, #T_fc2c2_row52_col3, #T_fc2c2_row52_col4, #T_fc2c2_row52_col5, #T_fc2c2_row52_col6, #T_fc2c2_row53_col0, #T_fc2c2_row53_col1, #T_fc2c2_row53_col2, #T_fc2c2_row53_col3, #T_fc2c2_row53_col4, #T_fc2c2_row53_col5, #T_fc2c2_row53_col6, #T_fc2c2_row54_col0, #T_fc2c2_row54_col1, #T_fc2c2_row54_col2, #T_fc2c2_row54_col3, #T_fc2c2_row54_col4, #T_fc2c2_row54_col5, #T_fc2c2_row54_col6, #T_fc2c2_row55_col0, #T_fc2c2_row55_col1, #T_fc2c2_row55_col2, #T_fc2c2_row55_col3, #T_fc2c2_row55_col4, #T_fc2c2_row55_col5, #T_fc2c2_row55_col6, #T_fc2c2_row56_col0, #T_fc2c2_row56_col1, #T_fc2c2_row56_col2, #T_fc2c2_row56_col3, #T_fc2c2_row56_col4, #T_fc2c2_row56_col5, #T_fc2c2_row56_col6, #T_fc2c2_row57_col0, #T_fc2c2_row57_col1, #T_fc2c2_row57_col2, #T_fc2c2_row57_col3, #T_fc2c2_row57_col4, #T_fc2c2_row57_col5, #T_fc2c2_row57_col6, #T_fc2c2_row58_col0, #T_fc2c2_row58_col1, #T_fc2c2_row58_col2, #T_fc2c2_row58_col3, #T_fc2c2_row58_col4, #T_fc2c2_row58_col5, #T_fc2c2_row58_col6, #T_fc2c2_row59_col0, #T_fc2c2_row59_col1, #T_fc2c2_row59_col2, #T_fc2c2_row59_col3, #T_fc2c2_row59_col4, #T_fc2c2_row59_col5, #T_fc2c2_row59_col6, #T_fc2c2_row60_col0, #T_fc2c2_row60_col1, #T_fc2c2_row60_col2, #T_fc2c2_row60_col3, #T_fc2c2_row60_col4, #T_fc2c2_row60_col5, #T_fc2c2_row60_col6, #T_fc2c2_row61_col0, #T_fc2c2_row61_col1, #T_fc2c2_row61_col2, #T_fc2c2_row61_col3, #T_fc2c2_row61_col4, #T_fc2c2_row61_col5, #T_fc2c2_row61_col6, #T_fc2c2_row62_col0, #T_fc2c2_row62_col1, #T_fc2c2_row62_col2, #T_fc2c2_row62_col3, #T_fc2c2_row62_col4, #T_fc2c2_row62_col5, #T_fc2c2_row62_col6, #T_fc2c2_row63_col0, #T_fc2c2_row63_col1, #T_fc2c2_row63_col2, #T_fc2c2_row63_col3, #T_fc2c2_row63_col4, #T_fc2c2_row63_col5, #T_fc2c2_row63_col6 {
#   font-weight: bold;
# }
# #T_fc2c2_row64_col0, #T_fc2c2_row64_col1, #T_fc2c2_row64_col2, #T_fc2c2_row64_col3, #T_fc2c2_row64_col4, #T_fc2c2_row64_col5, #T_fc2c2_row64_col6, #T_fc2c2_row65_col0, #T_fc2c2_row65_col1, #T_fc2c2_row65_col2, #T_fc2c2_row65_col3, #T_fc2c2_row65_col4, #T_fc2c2_row65_col5, #T_fc2c2_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_fc2c2">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_fc2c2_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_fc2c2_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_fc2c2_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_fc2c2_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_fc2c2_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_fc2c2_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_fc2c2_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fc2c2_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_fc2c2_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_fc2c2_row0_col2" class="data row0 col2" ></td>
#       <td id="T_fc2c2_row0_col3" class="data row0 col3" ></td>
#       <td id="T_fc2c2_row0_col4" class="data row0 col4" ></td>
#       <td id="T_fc2c2_row0_col5" class="data row0 col5" ></td>
#       <td id="T_fc2c2_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_fc2c2_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_fc2c2_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_fc2c2_row1_col3" class="data row1 col3" ></td>
#       <td id="T_fc2c2_row1_col4" class="data row1 col4" ></td>
#       <td id="T_fc2c2_row1_col5" class="data row1 col5" ></td>
#       <td id="T_fc2c2_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_fc2c2_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_fc2c2_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_fc2c2_row2_col3" class="data row2 col3" ></td>
#       <td id="T_fc2c2_row2_col4" class="data row2 col4" ></td>
#       <td id="T_fc2c2_row2_col5" class="data row2 col5" ></td>
#       <td id="T_fc2c2_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_fc2c2_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_fc2c2_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_fc2c2_row3_col3" class="data row3 col3" ></td>
#       <td id="T_fc2c2_row3_col4" class="data row3 col4" ></td>
#       <td id="T_fc2c2_row3_col5" class="data row3 col5" ></td>
#       <td id="T_fc2c2_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_fc2c2_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_fc2c2_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_fc2c2_row4_col3" class="data row4 col3" ></td>
#       <td id="T_fc2c2_row4_col4" class="data row4 col4" ></td>
#       <td id="T_fc2c2_row4_col5" class="data row4 col5" ></td>
#       <td id="T_fc2c2_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_fc2c2_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_fc2c2_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_fc2c2_row5_col3" class="data row5 col3" ></td>
#       <td id="T_fc2c2_row5_col4" class="data row5 col4" ></td>
#       <td id="T_fc2c2_row5_col5" class="data row5 col5" ></td>
#       <td id="T_fc2c2_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_fc2c2_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_fc2c2_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_fc2c2_row6_col3" class="data row6 col3" ></td>
#       <td id="T_fc2c2_row6_col4" class="data row6 col4" ></td>
#       <td id="T_fc2c2_row6_col5" class="data row6 col5" ></td>
#       <td id="T_fc2c2_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_fc2c2_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_fc2c2_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_fc2c2_row7_col3" class="data row7 col3" ></td>
#       <td id="T_fc2c2_row7_col4" class="data row7 col4" ></td>
#       <td id="T_fc2c2_row7_col5" class="data row7 col5" ></td>
#       <td id="T_fc2c2_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_fc2c2_row8_col0" class="data row8 col0" ></td>
#       <td id="T_fc2c2_row8_col1" class="data row8 col1" ></td>
#       <td id="T_fc2c2_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-5 : Reworking and labor productivity

# %%
#Reworking = f(AE, CE, design completion)

if reactor_type == "SFR":
    reworking_factor =  (-0.75*design_completion+ 1.75) * (-0.15*ae_exp+1.3) * (-0.15*ce_exp+1.3) 

if reactor_type == "HTGR":
    reworking_factor =  (-0.56*design_completion+ 1.56) * (-0.125*ae_exp+1.25) * (-0.125*ce_exp+1.25) 

db = pd.DataFrame()

db = Reactor_data_updated_4[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

for x in [212, 213, '211 plus 214 to 219',22, '232.1', 233, 24, 26]:  
    db.loc[db.Account == x, 'Factory Equipment Cost'] = None # clear old values
    db.loc[db.Account == x, 'Site Labor Hours'] = None
    db.loc[db.Account == x, 'Site Labor Cost'] = None
    db.loc[db.Account == x, 'Site Material Cost'] = None

for x in [212, 213, '211 plus 214 to 219',22, '232.1', 233, 24, 26]: 
    db.loc[db.Account == x, 'Factory Equipment Cost'] =\
        ((( Reactor_data_updated_4.loc[ Reactor_data_updated_4.Account == x, 'Factory Equipment Cost']).values)[0])*reworking_factor  
    db.loc[db.Account == x, 'Site Labor Hours'] =\
        ((( Reactor_data_updated_4.loc[ Reactor_data_updated_4.Account == x, 'Site Labor Hours']).values)[0])*reworking_factor/productivity
    db.loc[db.Account == x, 'Site Labor Cost'] =\
        ((( Reactor_data_updated_4.loc[ Reactor_data_updated_4.Account == x, 'Site Labor Cost']).values)[0])*reworking_factor/productivity 
    db.loc[db.Account == x, 'Site Material Cost'] =\
        ((( Reactor_data_updated_4.loc[ Reactor_data_updated_4.Account == x, 'Site Material Cost']).values)[0])*reworking_factor 


# update the construction duration

Reactor_data_updated_5 = update_high_level_costs(db)
Reactor_data_updated_5_ = pd.DataFrame()
Reactor_data_updated_5_ = Reactor_data_updated_5[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_5_pretty = prettify(Reactor_data_updated_5_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_5_pretty
# Out:
# <style type="text/css">
# #T_d091e caption {
#   color: red;
#   font-size: 20px;
# }
# #T_d091e_row0_col0, #T_d091e_row0_col1, #T_d091e_row0_col2, #T_d091e_row0_col3, #T_d091e_row0_col4, #T_d091e_row0_col5, #T_d091e_row0_col6, #T_d091e_row12_col0, #T_d091e_row12_col1, #T_d091e_row12_col2, #T_d091e_row12_col3, #T_d091e_row12_col4, #T_d091e_row12_col5, #T_d091e_row12_col6, #T_d091e_row29_col0, #T_d091e_row29_col1, #T_d091e_row29_col2, #T_d091e_row29_col3, #T_d091e_row29_col4, #T_d091e_row29_col5, #T_d091e_row29_col6, #T_d091e_row39_col0, #T_d091e_row39_col1, #T_d091e_row39_col2, #T_d091e_row39_col3, #T_d091e_row39_col4, #T_d091e_row39_col5, #T_d091e_row39_col6, #T_d091e_row47_col0, #T_d091e_row47_col1, #T_d091e_row47_col2, #T_d091e_row47_col3, #T_d091e_row47_col4, #T_d091e_row47_col5, #T_d091e_row47_col6, #T_d091e_row51_col0, #T_d091e_row51_col1, #T_d091e_row51_col2, #T_d091e_row51_col3, #T_d091e_row51_col4, #T_d091e_row51_col5, #T_d091e_row51_col6, #T_d091e_row52_col0, #T_d091e_row52_col1, #T_d091e_row52_col2, #T_d091e_row52_col3, #T_d091e_row52_col4, #T_d091e_row52_col5, #T_d091e_row52_col6, #T_d091e_row53_col0, #T_d091e_row53_col1, #T_d091e_row53_col2, #T_d091e_row53_col3, #T_d091e_row53_col4, #T_d091e_row53_col5, #T_d091e_row53_col6, #T_d091e_row54_col0, #T_d091e_row54_col1, #T_d091e_row54_col2, #T_d091e_row54_col3, #T_d091e_row54_col4, #T_d091e_row54_col5, #T_d091e_row54_col6, #T_d091e_row55_col0, #T_d091e_row55_col1, #T_d091e_row55_col2, #T_d091e_row55_col3, #T_d091e_row55_col4, #T_d091e_row55_col5, #T_d091e_row55_col6, #T_d091e_row56_col0, #T_d091e_row56_col1, #T_d091e_row56_col2, #T_d091e_row56_col3, #T_d091e_row56_col4, #T_d091e_row56_col5, #T_d091e_row56_col6, #T_d091e_row57_col0, #T_d091e_row57_col1, #T_d091e_row57_col2, #T_d091e_row57_col3, #T_d091e_row57_col4, #T_d091e_row57_col5, #T_d091e_row57_col6, #T_d091e_row58_col0, #T_d091e_row58_col1, #T_d091e_row58_col2, #T_d091e_row58_col3, #T_d091e_row58_col4, #T_d091e_row58_col5, #T_d091e_row58_col6, #T_d091e_row59_col0, #T_d091e_row59_col1, #T_d091e_row59_col2, #T_d091e_row59_col3, #T_d091e_row59_col4, #T_d091e_row59_col5, #T_d091e_row59_col6, #T_d091e_row60_col0, #T_d091e_row60_col1, #T_d091e_row60_col2, #T_d091e_row60_col3, #T_d091e_row60_col4, #T_d091e_row60_col5, #T_d091e_row60_col6, #T_d091e_row61_col0, #T_d091e_row61_col1, #T_d091e_row61_col2, #T_d091e_row61_col3, #T_d091e_row61_col4, #T_d091e_row61_col5, #T_d091e_row61_col6, #T_d091e_row62_col0, #T_d091e_row62_col1, #T_d091e_row62_col2, #T_d091e_row62_col3, #T_d091e_row62_col4, #T_d091e_row62_col5, #T_d091e_row62_col6, #T_d091e_row63_col0, #T_d091e_row63_col1, #T_d091e_row63_col2, #T_d091e_row63_col3, #T_d091e_row63_col4, #T_d091e_row63_col5, #T_d091e_row63_col6 {
#   font-weight: bold;
# }
# #T_d091e_row64_col0, #T_d091e_row64_col1, #T_d091e_row64_col2, #T_d091e_row64_col3, #T_d091e_row64_col4, #T_d091e_row64_col5, #T_d091e_row64_col6, #T_d091e_row65_col0, #T_d091e_row65_col1, #T_d091e_row65_col2, #T_d091e_row65_col3, #T_d091e_row65_col4, #T_d091e_row65_col5, #T_d091e_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_d091e">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_d091e_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_d091e_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_d091e_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_d091e_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_d091e_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_d091e_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_d091e_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d091e_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_d091e_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_d091e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_d091e_row0_col3" class="data row0 col3" ></td>
#       <td id="T_d091e_row0_col4" class="data row0 col4" ></td>
#       <td id="T_d091e_row0_col5" class="data row0 col5" ></td>
#       <td id="T_d091e_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_d091e_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_d091e_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_d091e_row1_col3" class="data row1 col3" ></td>
#       <td id="T_d091e_row1_col4" class="data row1 col4" ></td>
#       <td id="T_d091e_row1_col5" class="data row1 col5" ></td>
#       <td id="T_d091e_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_d091e_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_d091e_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_d091e_row2_col3" class="data row2 col3" ></td>
#       <td id="T_d091e_row2_col4" class="data row2 col4" ></td>
#       <td id="T_d091e_row2_col5" class="data row2 col5" ></td>
#       <td id="T_d091e_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_d091e_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_d091e_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_d091e_row3_col3" class="data row3 col3" ></td>
#       <td id="T_d091e_row3_col4" class="data row3 col4" ></td>
#       <td id="T_d091e_row3_col5" class="data row3 col5" ></td>
#       <td id="T_d091e_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_d091e_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_d091e_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_d091e_row4_col3" class="data row4 col3" ></td>
#       <td id="T_d091e_row4_col4" class="data row4 col4" ></td>
#       <td id="T_d091e_row4_col5" class="data row4 col5" ></td>
#       <td id="T_d091e_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_d091e_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_d091e_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_d091e_row5_col3" class="data row5 col3" ></td>
#       <td id="T_d091e_row5_col4" class="data row5 col4" ></td>
#       <td id="T_d091e_row5_col5" class="data row5 col5" ></td>
#       <td id="T_d091e_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_d091e_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_d091e_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_d091e_row6_col3" class="data row6 col3" ></td>
#       <td id="T_d091e_row6_col4" class="data row6 col4" ></td>
#       <td id="T_d091e_row6_col5" class="data row6 col5" ></td>
#       <td id="T_d091e_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_d091e_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_d091e_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_d091e_row7_col3" class="data row7 col3" ></td>
#       <td id="T_d091e_row7_col4" class="data row7 col4" ></td>
#       <td id="T_d091e_row7_col5" class="data row7 col5" ></td>
#       <td id="T_d091e_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_d091e_row8_col0" class="data row8 col0" ></td>
#       <td id="T_d091e_row8_col1" class="data row8 col1" ></td>
#       <td id="T_d091e_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-6 :Update construction duration from labor hours

# %%
#sum of labor hours for Account 20 in the initial estimation (well exectued scenario)
sum_old_lab_hrs = (Reactor_data_0.loc[Reactor_data_0.Account == 21, 'Site Labor Hours']).values +\
(Reactor_data_0.loc[Reactor_data_0.Account == 22, 'Site Labor Hours']).values +\
(Reactor_data_0.loc[Reactor_data_0.Account == 23, 'Site Labor Hours']).values+\
(Reactor_data_0.loc[Reactor_data_0.Account == 24, 'Site Labor Hours']).values+\
(Reactor_data_0.loc[Reactor_data_0.Account == 26, 'Site Labor Hours']).values



# #sum of labor hours for Account 20 in the new estimation 
sum_new_lab_hrs = (db.loc[db.Account == 21, 'Site Labor Hours']).values +\
(db.loc[db.Account == 22, 'Site Labor Hours']).values +\
(db.loc[db.Account == 23, 'Site Labor Hours']).values+\
(db.loc[db.Account == 24, 'Site Labor Hours']).values+\
(db.loc[db.Account == 26, 'Site Labor Hours']).values



# # # change in labor hours for account 20
labor_hour_ratio = (sum_new_lab_hrs)/sum_old_lab_hrs   # note that this number can be positive or negative
labor_hour_ratio 

# 	From the literature   we know that if labor hours changed from 3.8M hours to 20.5M hours (5.4 times), the construction duration changes from 33.2 months to 74.3 months (2.2 times).
# 	We also know that if the labor hours multiplier =1, the cons duration multiplier should be 1.
# 	Using these two points: 

# construction duration multiplier = 0.3 * the labor hours multiplier+0.7

actual_construction_duration = baseline_construction_duration*(0.3*labor_hour_ratio+0.7)

# %% [markdown]
# ### Section 3-7 supply chain delays

# %%
# For the accounts 21, 22, 23, 24, 25, 26, 
# The delays are D_21,D_22,D_23,D_24,D_25,D_26 
# The tasks lengths (in months) are B_21,B_22,B_23,B_24,B_25,B_26

# task length ratio between SFR and HTGR is 100/65
# We use this ratio to convert SFR to HTGT task lengths

if reactor_type == "SFR":
    task_length_multiplier = 1
elif reactor_type == "HTGR": 
    task_length_multiplier = 100/64
B_21 =  42.1 * task_length_multiplier # months 
B_22 = 60.2 * task_length_multiplier
B_23 = 14.8 * task_length_multiplier
B_24 = 3.6* task_length_multiplier
B_25 = 10.1* task_length_multiplier
B_26 = 43.9* task_length_multiplier


# The delays are 
D_21 =  accounts_vars["Supply Chain Delay (monthhs)"].values[0]
D_22 =  accounts_vars["Supply Chain Delay (monthhs)"].values[1]
D_23 =  accounts_vars["Supply Chain Delay (monthhs)"].values[2]
D_24 =  accounts_vars["Supply Chain Delay (monthhs)"].values[3]
D_25 =  accounts_vars["Supply Chain Delay (monthhs)"].values[4]
D_26 =  accounts_vars["Supply Chain Delay (monthhs)"].values[5]


# The tasks completion times (in months) are T_21,T_22,T_23,T_24,T_25,T_26
T_21 = B_21 + D_21 
T_22 = 0.09*(B_21+D_21)  +B_22+D_22
T_23 = 0.24*(B_21+D_21)  +B_23+D_23
T_24 = 0.24*(B_21+D_21) + 0.34*(B_23+D_23)  +B_24+D_24
T_25 = 0.18*(B_21+D_21)  +B_25+D_25
T_26 = 0.21*(B_21+D_21)   +B_26+D_26
T_end = max(T_21, T_22, T_23, T_24, T_25, T_26)
T_end
supply_chain_delay = max( T_end - baseline_construction_duration, 0)
final_construction_duration = actual_construction_duration + supply_chain_delay
print("\nThe actual construction duration is estimated to be : ", np.round(final_construction_duration[0] ,1), "months\n")
# Out:
# The actual construction duration is estimated to be :  91.7 months

# %% [markdown]
# ### Section 3-8 Learning by doing and standardization

# %%
# # Creating the table for the learning rates
# #These rates are from KS-TIMCAT results.
# # The learning rates are multiplied by the standardization divded by 0.7 (since the standatization of PWRs was 0.7)
fitted_LR = pd.DataFrame()
fitted_LR.loc[:, 'Account'] = Reactor_data.loc[:, 'Account']
fitted_LR.loc[:, 'Title'] = Reactor_data.loc[:, 'Title']
fitted_LR = fitted_LR.loc[fitted_LR['Account'].isin([212, 213, '211 plus 214 to 219', 22, '232.1', 233, 24, 26])]

fitted_LR['Mat LR'] = np.array([0.099588665391, 0.099588665391, 0.099588665391, 0.080817992281, 0.0000000, 0.099588665391,\
                                0.099588665391,0.099588665391])*standardization/0.7

fitted_LR['Lab LR'] =     np.array([0.180678729399, 0.180678729399, 0.180678729399,0.146555539499, 0.137148574884,\
                                    0.180678729399, 0.180678729399,0.180678729399])*standardization/0.7


db = pd.DataFrame()

db = Reactor_data_updated_5[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

for x in [212, 213, '211 plus 214 to 219', 22, '232.1', 233, 24, 26]:  
    db.loc[db.Account == x, 'Site Labor Hours'] = None
    db.loc[db.Account == x, 'Site Labor Cost'] = None
    db.loc[db.Account == x, 'Site Material Cost'] = None


# # # # Bulk order reduction	
for x in [212, 213, '211 plus 214 to 219', 22, '232.1', 233, 24, 26]:
    mat_cost_reduction_multiplier = (1 - (fitted_LR.loc[fitted_LR.Account == x, 'Mat LR'].values[0]))**np.log2(n_th)
    lab_cost_reduction_multiplier = (1 - (fitted_LR.loc[fitted_LR.Account == x, 'Lab LR'].values[0]))**np.log2(n_th)
    
    db.loc[db.Account == x, 'Site Material Cost'] =\
        (( Reactor_data_updated_5.loc[ Reactor_data_updated_5.Account == x, 'Site Material Cost']))* mat_cost_reduction_multiplier

    db.loc[db.Account == x, 'Site Labor Hours'] =\
        (( Reactor_data_updated_5.loc[ Reactor_data_updated_5.Account == x, 'Site Labor Hours']))* lab_cost_reduction_multiplier
   
    db.loc[db.Account == x, 'Site Labor Cost'] =\
        (( Reactor_data_updated_5.loc[ Reactor_data_updated_5.Account == x, 'Site Labor Cost']))* lab_cost_reduction_multiplier


    
   

Reactor_data_updated_6 = update_high_level_costs(db)
Reactor_data_updated_6_ = pd.DataFrame()
Reactor_data_updated_6_ = Reactor_data_updated_6[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_6_pretty = prettify(Reactor_data_updated_6_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_6_pretty
# Out:
# <style type="text/css">
# #T_8b2ab caption {
#   color: red;
#   font-size: 20px;
# }
# #T_8b2ab_row0_col0, #T_8b2ab_row0_col1, #T_8b2ab_row0_col2, #T_8b2ab_row0_col3, #T_8b2ab_row0_col4, #T_8b2ab_row0_col5, #T_8b2ab_row0_col6, #T_8b2ab_row12_col0, #T_8b2ab_row12_col1, #T_8b2ab_row12_col2, #T_8b2ab_row12_col3, #T_8b2ab_row12_col4, #T_8b2ab_row12_col5, #T_8b2ab_row12_col6, #T_8b2ab_row29_col0, #T_8b2ab_row29_col1, #T_8b2ab_row29_col2, #T_8b2ab_row29_col3, #T_8b2ab_row29_col4, #T_8b2ab_row29_col5, #T_8b2ab_row29_col6, #T_8b2ab_row39_col0, #T_8b2ab_row39_col1, #T_8b2ab_row39_col2, #T_8b2ab_row39_col3, #T_8b2ab_row39_col4, #T_8b2ab_row39_col5, #T_8b2ab_row39_col6, #T_8b2ab_row47_col0, #T_8b2ab_row47_col1, #T_8b2ab_row47_col2, #T_8b2ab_row47_col3, #T_8b2ab_row47_col4, #T_8b2ab_row47_col5, #T_8b2ab_row47_col6, #T_8b2ab_row51_col0, #T_8b2ab_row51_col1, #T_8b2ab_row51_col2, #T_8b2ab_row51_col3, #T_8b2ab_row51_col4, #T_8b2ab_row51_col5, #T_8b2ab_row51_col6, #T_8b2ab_row52_col0, #T_8b2ab_row52_col1, #T_8b2ab_row52_col2, #T_8b2ab_row52_col3, #T_8b2ab_row52_col4, #T_8b2ab_row52_col5, #T_8b2ab_row52_col6, #T_8b2ab_row53_col0, #T_8b2ab_row53_col1, #T_8b2ab_row53_col2, #T_8b2ab_row53_col3, #T_8b2ab_row53_col4, #T_8b2ab_row53_col5, #T_8b2ab_row53_col6, #T_8b2ab_row54_col0, #T_8b2ab_row54_col1, #T_8b2ab_row54_col2, #T_8b2ab_row54_col3, #T_8b2ab_row54_col4, #T_8b2ab_row54_col5, #T_8b2ab_row54_col6, #T_8b2ab_row55_col0, #T_8b2ab_row55_col1, #T_8b2ab_row55_col2, #T_8b2ab_row55_col3, #T_8b2ab_row55_col4, #T_8b2ab_row55_col5, #T_8b2ab_row55_col6, #T_8b2ab_row56_col0, #T_8b2ab_row56_col1, #T_8b2ab_row56_col2, #T_8b2ab_row56_col3, #T_8b2ab_row56_col4, #T_8b2ab_row56_col5, #T_8b2ab_row56_col6, #T_8b2ab_row57_col0, #T_8b2ab_row57_col1, #T_8b2ab_row57_col2, #T_8b2ab_row57_col3, #T_8b2ab_row57_col4, #T_8b2ab_row57_col5, #T_8b2ab_row57_col6, #T_8b2ab_row58_col0, #T_8b2ab_row58_col1, #T_8b2ab_row58_col2, #T_8b2ab_row58_col3, #T_8b2ab_row58_col4, #T_8b2ab_row58_col5, #T_8b2ab_row58_col6, #T_8b2ab_row59_col0, #T_8b2ab_row59_col1, #T_8b2ab_row59_col2, #T_8b2ab_row59_col3, #T_8b2ab_row59_col4, #T_8b2ab_row59_col5, #T_8b2ab_row59_col6, #T_8b2ab_row60_col0, #T_8b2ab_row60_col1, #T_8b2ab_row60_col2, #T_8b2ab_row60_col3, #T_8b2ab_row60_col4, #T_8b2ab_row60_col5, #T_8b2ab_row60_col6, #T_8b2ab_row61_col0, #T_8b2ab_row61_col1, #T_8b2ab_row61_col2, #T_8b2ab_row61_col3, #T_8b2ab_row61_col4, #T_8b2ab_row61_col5, #T_8b2ab_row61_col6, #T_8b2ab_row62_col0, #T_8b2ab_row62_col1, #T_8b2ab_row62_col2, #T_8b2ab_row62_col3, #T_8b2ab_row62_col4, #T_8b2ab_row62_col5, #T_8b2ab_row62_col6, #T_8b2ab_row63_col0, #T_8b2ab_row63_col1, #T_8b2ab_row63_col2, #T_8b2ab_row63_col3, #T_8b2ab_row63_col4, #T_8b2ab_row63_col5, #T_8b2ab_row63_col6 {
#   font-weight: bold;
# }
# #T_8b2ab_row64_col0, #T_8b2ab_row64_col1, #T_8b2ab_row64_col2, #T_8b2ab_row64_col3, #T_8b2ab_row64_col4, #T_8b2ab_row64_col5, #T_8b2ab_row64_col6, #T_8b2ab_row65_col0, #T_8b2ab_row65_col1, #T_8b2ab_row65_col2, #T_8b2ab_row65_col3, #T_8b2ab_row65_col4, #T_8b2ab_row65_col5, #T_8b2ab_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_8b2ab">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_8b2ab_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_8b2ab_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_8b2ab_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_8b2ab_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_8b2ab_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_8b2ab_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_8b2ab_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8b2ab_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_8b2ab_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_8b2ab_row0_col2" class="data row0 col2" ></td>
#       <td id="T_8b2ab_row0_col3" class="data row0 col3" ></td>
#       <td id="T_8b2ab_row0_col4" class="data row0 col4" ></td>
#       <td id="T_8b2ab_row0_col5" class="data row0 col5" ></td>
#       <td id="T_8b2ab_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_8b2ab_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_8b2ab_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_8b2ab_row1_col3" class="data row1 col3" ></td>
#       <td id="T_8b2ab_row1_col4" class="data row1 col4" ></td>
#       <td id="T_8b2ab_row1_col5" class="data row1 col5" ></td>
#       <td id="T_8b2ab_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_8b2ab_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_8b2ab_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_8b2ab_row2_col3" class="data row2 col3" ></td>
#       <td id="T_8b2ab_row2_col4" class="data row2 col4" ></td>
#       <td id="T_8b2ab_row2_col5" class="data row2 col5" ></td>
#       <td id="T_8b2ab_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_8b2ab_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_8b2ab_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_8b2ab_row3_col3" class="data row3 col3" ></td>
#       <td id="T_8b2ab_row3_col4" class="data row3 col4" ></td>
#       <td id="T_8b2ab_row3_col5" class="data row3 col5" ></td>
#       <td id="T_8b2ab_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_8b2ab_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_8b2ab_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_8b2ab_row4_col3" class="data row4 col3" ></td>
#       <td id="T_8b2ab_row4_col4" class="data row4 col4" ></td>
#       <td id="T_8b2ab_row4_col5" class="data row4 col5" ></td>
#       <td id="T_8b2ab_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_8b2ab_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_8b2ab_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_8b2ab_row5_col3" class="data row5 col3" ></td>
#       <td id="T_8b2ab_row5_col4" class="data row5 col4" ></td>
#       <td id="T_8b2ab_row5_col5" class="data row5 col5" ></td>
#       <td id="T_8b2ab_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_8b2ab_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_8b2ab_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_8b2ab_row6_col3" class="data row6 col3" ></td>
#       <td id="T_8b2ab_row6_col4" class="data row6 col4" ></td>
#       <td id="T_8b2ab_row6_col5" class="data row6 col5" ></td>
#       <td id="T_8b2ab_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_8b2ab_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_8b2ab_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_8b2ab_row7_col3" class="data row7 col3" ></td>
#       <td id="T_8b2ab_row7_col4" class="data row7 col4" ></td>
#       <td id="T_8b2ab_row7_col5" class="data row7 col5" ></td>
#       <td id="T_8b2ab_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_8b2ab_row8_col0" class="data row8 col0" ></td>
#       <td id="T_8b2ab_row8_col1" class="data row8 col1" ></td>
#       <td id="T_8b2ab_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-9 Calculate the Indirect Cost and the standardization impact

# %%
#   I use here the indirect cost correlations prepared by Jia

# When the standardization is  100%, the engineering service accound (Acct 35) is zero, 
# When the standardization is  70%, the engineering service accound (Acct 35) does not change
# The account 35 multiplier is


factor_35 = -3.33 * standardization + 3.331


db = pd.DataFrame()

db = Reactor_data_updated_6[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

for x in [31, 32, 33, 34, 35]:  
    db.loc[db.Account == x, 'Total Cost (USD)'] = None # clear old values


# # total direct mat cost, labor cost, labor hours
sum_new_mat_cost  = 0 # initilization
sum_new_lab_cost  = 0 # initilization
sum_new_lab_hrs  = 0 # initilization

for x in [21, 22, 23, 24, 26]:
    sum_new_mat_cost +=     (db.loc[db.Account == x, 'Site Material Cost']).values
    sum_new_lab_cost +=     (db.loc[db.Account == x, 'Site Labor Cost']).values
    sum_new_lab_hrs  +=     (db.loc[db.Account == x, 'Site Labor Hours']).values


# The new indirect costs   
db.loc[db.Account == 31, 'Total Cost (USD)'] =  (sum_new_mat_cost*0.785* sum_new_lab_hrs/final_construction_duration/160/1058)\
+ sum_new_lab_cost *0.36

db.loc[db.Account == 32, 'Total Cost (USD)'] =  sum_new_lab_cost *0.36*3.661* final_construction_duration/72

db.loc[db.Account == 33, 'Total Cost (USD)'] =  0.042 * (db.loc[db.Account == 32, 'Total Cost (USD)'].values[0] )

db.loc[db.Account == 34, 'Total Cost (USD)'] =  0.0035 * (db.loc[db.Account == 32, 'Total Cost (USD)'].values[0] )

db.loc[db.Account == 35, 'Total Cost (USD)'] = ( 0.27 * (db.loc[db.Account == 32, 'Total Cost (USD)'].values[0] ))*factor_35 






Reactor_data_updated_7 = update_high_level_costs(db)
Reactor_data_updated_7_ = pd.DataFrame()
Reactor_data_updated_7_ = Reactor_data_updated_7[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_7_pretty = prettify(Reactor_data_updated_7_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_7_pretty
# Out:
# <style type="text/css">
# #T_ad870 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_ad870_row0_col0, #T_ad870_row0_col1, #T_ad870_row0_col2, #T_ad870_row0_col3, #T_ad870_row0_col4, #T_ad870_row0_col5, #T_ad870_row0_col6, #T_ad870_row12_col0, #T_ad870_row12_col1, #T_ad870_row12_col2, #T_ad870_row12_col3, #T_ad870_row12_col4, #T_ad870_row12_col5, #T_ad870_row12_col6, #T_ad870_row29_col0, #T_ad870_row29_col1, #T_ad870_row29_col2, #T_ad870_row29_col3, #T_ad870_row29_col4, #T_ad870_row29_col5, #T_ad870_row29_col6, #T_ad870_row39_col0, #T_ad870_row39_col1, #T_ad870_row39_col2, #T_ad870_row39_col3, #T_ad870_row39_col4, #T_ad870_row39_col5, #T_ad870_row39_col6, #T_ad870_row47_col0, #T_ad870_row47_col1, #T_ad870_row47_col2, #T_ad870_row47_col3, #T_ad870_row47_col4, #T_ad870_row47_col5, #T_ad870_row47_col6, #T_ad870_row51_col0, #T_ad870_row51_col1, #T_ad870_row51_col2, #T_ad870_row51_col3, #T_ad870_row51_col4, #T_ad870_row51_col5, #T_ad870_row51_col6, #T_ad870_row52_col0, #T_ad870_row52_col1, #T_ad870_row52_col2, #T_ad870_row52_col3, #T_ad870_row52_col4, #T_ad870_row52_col5, #T_ad870_row52_col6, #T_ad870_row53_col0, #T_ad870_row53_col1, #T_ad870_row53_col2, #T_ad870_row53_col3, #T_ad870_row53_col4, #T_ad870_row53_col5, #T_ad870_row53_col6, #T_ad870_row54_col0, #T_ad870_row54_col1, #T_ad870_row54_col2, #T_ad870_row54_col3, #T_ad870_row54_col4, #T_ad870_row54_col5, #T_ad870_row54_col6, #T_ad870_row55_col0, #T_ad870_row55_col1, #T_ad870_row55_col2, #T_ad870_row55_col3, #T_ad870_row55_col4, #T_ad870_row55_col5, #T_ad870_row55_col6, #T_ad870_row56_col0, #T_ad870_row56_col1, #T_ad870_row56_col2, #T_ad870_row56_col3, #T_ad870_row56_col4, #T_ad870_row56_col5, #T_ad870_row56_col6, #T_ad870_row57_col0, #T_ad870_row57_col1, #T_ad870_row57_col2, #T_ad870_row57_col3, #T_ad870_row57_col4, #T_ad870_row57_col5, #T_ad870_row57_col6, #T_ad870_row58_col0, #T_ad870_row58_col1, #T_ad870_row58_col2, #T_ad870_row58_col3, #T_ad870_row58_col4, #T_ad870_row58_col5, #T_ad870_row58_col6, #T_ad870_row59_col0, #T_ad870_row59_col1, #T_ad870_row59_col2, #T_ad870_row59_col3, #T_ad870_row59_col4, #T_ad870_row59_col5, #T_ad870_row59_col6, #T_ad870_row60_col0, #T_ad870_row60_col1, #T_ad870_row60_col2, #T_ad870_row60_col3, #T_ad870_row60_col4, #T_ad870_row60_col5, #T_ad870_row60_col6, #T_ad870_row61_col0, #T_ad870_row61_col1, #T_ad870_row61_col2, #T_ad870_row61_col3, #T_ad870_row61_col4, #T_ad870_row61_col5, #T_ad870_row61_col6, #T_ad870_row62_col0, #T_ad870_row62_col1, #T_ad870_row62_col2, #T_ad870_row62_col3, #T_ad870_row62_col4, #T_ad870_row62_col5, #T_ad870_row62_col6, #T_ad870_row63_col0, #T_ad870_row63_col1, #T_ad870_row63_col2, #T_ad870_row63_col3, #T_ad870_row63_col4, #T_ad870_row63_col5, #T_ad870_row63_col6 {
#   font-weight: bold;
# }
# #T_ad870_row64_col0, #T_ad870_row64_col1, #T_ad870_row64_col2, #T_ad870_row64_col3, #T_ad870_row64_col4, #T_ad870_row64_col5, #T_ad870_row64_col6, #T_ad870_row65_col0, #T_ad870_row65_col1, #T_ad870_row65_col2, #T_ad870_row65_col3, #T_ad870_row65_col4, #T_ad870_row65_col5, #T_ad870_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_ad870">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_ad870_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_ad870_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_ad870_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_ad870_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_ad870_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_ad870_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_ad870_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ad870_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_ad870_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_ad870_row0_col2" class="data row0 col2" ></td>
#       <td id="T_ad870_row0_col3" class="data row0 col3" ></td>
#       <td id="T_ad870_row0_col4" class="data row0 col4" ></td>
#       <td id="T_ad870_row0_col5" class="data row0 col5" ></td>
#       <td id="T_ad870_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_ad870_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_ad870_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_ad870_row1_col3" class="data row1 col3" ></td>
#       <td id="T_ad870_row1_col4" class="data row1 col4" ></td>
#       <td id="T_ad870_row1_col5" class="data row1 col5" ></td>
#       <td id="T_ad870_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_ad870_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_ad870_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_ad870_row2_col3" class="data row2 col3" ></td>
#       <td id="T_ad870_row2_col4" class="data row2 col4" ></td>
#       <td id="T_ad870_row2_col5" class="data row2 col5" ></td>
#       <td id="T_ad870_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_ad870_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_ad870_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_ad870_row3_col3" class="data row3 col3" ></td>
#       <td id="T_ad870_row3_col4" class="data row3 col4" ></td>
#       <td id="T_ad870_row3_col5" class="data row3 col5" ></td>
#       <td id="T_ad870_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_ad870_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_ad870_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_ad870_row4_col3" class="data row4 col3" ></td>
#       <td id="T_ad870_row4_col4" class="data row4 col4" ></td>
#       <td id="T_ad870_row4_col5" class="data row4 col5" ></td>
#       <td id="T_ad870_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_ad870_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_ad870_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_ad870_row5_col3" class="data row5 col3" ></td>
#       <td id="T_ad870_row5_col4" class="data row5 col4" ></td>
#       <td id="T_ad870_row5_col5" class="data row5 col5" ></td>
#       <td id="T_ad870_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_ad870_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_ad870_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_ad870_row6_col3" class="data row6 col3" ></td>
#       <td id="T_ad870_row6_col4" class="data row6 col4" ></td>
#       <td id="T_ad870_row6_col5" class="data row6 col5" ></td>
#       <td id="T_ad870_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_ad870_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_ad870_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_ad870_row7_col3" class="data row7 col3" ></td>
#       <td id="T_ad870_row7_col4" class="data row7 col4" ></td>
#       <td id="T_ad870_row7_col5" class="data row7 col5" ></td>
#       <td id="T_ad870_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_ad870_row8_col0" class="data row8 col0" ></td>
#       <td id="T_ad870_row8_col1" class="data row8 col1" ></td>
#       <td id="T_ad870_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-7 :  Insurance

# %%
# insurance increases linearly when increaing the sum of the 20s and 30s account
db = pd.DataFrame()

db = Reactor_data_updated_7[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()
db0 = Reactor_data_0
db.loc[db.Account == 52, 'Total Cost (USD)'] = None # clear old values

change_in_insuance_cost = (db.loc[db.Title =='20s - Subtotal', 'Total Cost (USD)'].values\
                        + db.loc[db.Title =='30s - Subtotal', 'Total Cost (USD)'].values)/ (db0.loc[db0.Title =='20s - Subtotal', 'Total Cost (USD)'].values\
                        + db0.loc[db0.Title =='30s - Subtotal', 'Total Cost (USD)'].values)

db.loc[db.Account == 52, 'Total Cost (USD)'] =  (change_in_insuance_cost[0])* (Reactor_data_updated_7.loc[db.Account == 52, 'Total Cost (USD)'])

Reactor_data_updated_8 = update_high_level_costs(db)

Reactor_data_updated_8_ = pd.DataFrame()
Reactor_data_updated_8_ = Reactor_data_updated_8[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_8_pretty = prettify(Reactor_data_updated_8_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_8_pretty
# Out:
# <style type="text/css">
# #T_371dc caption {
#   color: red;
#   font-size: 20px;
# }
# #T_371dc_row0_col0, #T_371dc_row0_col1, #T_371dc_row0_col2, #T_371dc_row0_col3, #T_371dc_row0_col4, #T_371dc_row0_col5, #T_371dc_row0_col6, #T_371dc_row12_col0, #T_371dc_row12_col1, #T_371dc_row12_col2, #T_371dc_row12_col3, #T_371dc_row12_col4, #T_371dc_row12_col5, #T_371dc_row12_col6, #T_371dc_row29_col0, #T_371dc_row29_col1, #T_371dc_row29_col2, #T_371dc_row29_col3, #T_371dc_row29_col4, #T_371dc_row29_col5, #T_371dc_row29_col6, #T_371dc_row39_col0, #T_371dc_row39_col1, #T_371dc_row39_col2, #T_371dc_row39_col3, #T_371dc_row39_col4, #T_371dc_row39_col5, #T_371dc_row39_col6, #T_371dc_row47_col0, #T_371dc_row47_col1, #T_371dc_row47_col2, #T_371dc_row47_col3, #T_371dc_row47_col4, #T_371dc_row47_col5, #T_371dc_row47_col6, #T_371dc_row51_col0, #T_371dc_row51_col1, #T_371dc_row51_col2, #T_371dc_row51_col3, #T_371dc_row51_col4, #T_371dc_row51_col5, #T_371dc_row51_col6, #T_371dc_row52_col0, #T_371dc_row52_col1, #T_371dc_row52_col2, #T_371dc_row52_col3, #T_371dc_row52_col4, #T_371dc_row52_col5, #T_371dc_row52_col6, #T_371dc_row53_col0, #T_371dc_row53_col1, #T_371dc_row53_col2, #T_371dc_row53_col3, #T_371dc_row53_col4, #T_371dc_row53_col5, #T_371dc_row53_col6, #T_371dc_row54_col0, #T_371dc_row54_col1, #T_371dc_row54_col2, #T_371dc_row54_col3, #T_371dc_row54_col4, #T_371dc_row54_col5, #T_371dc_row54_col6, #T_371dc_row55_col0, #T_371dc_row55_col1, #T_371dc_row55_col2, #T_371dc_row55_col3, #T_371dc_row55_col4, #T_371dc_row55_col5, #T_371dc_row55_col6, #T_371dc_row56_col0, #T_371dc_row56_col1, #T_371dc_row56_col2, #T_371dc_row56_col3, #T_371dc_row56_col4, #T_371dc_row56_col5, #T_371dc_row56_col6, #T_371dc_row57_col0, #T_371dc_row57_col1, #T_371dc_row57_col2, #T_371dc_row57_col3, #T_371dc_row57_col4, #T_371dc_row57_col5, #T_371dc_row57_col6, #T_371dc_row58_col0, #T_371dc_row58_col1, #T_371dc_row58_col2, #T_371dc_row58_col3, #T_371dc_row58_col4, #T_371dc_row58_col5, #T_371dc_row58_col6, #T_371dc_row59_col0, #T_371dc_row59_col1, #T_371dc_row59_col2, #T_371dc_row59_col3, #T_371dc_row59_col4, #T_371dc_row59_col5, #T_371dc_row59_col6, #T_371dc_row60_col0, #T_371dc_row60_col1, #T_371dc_row60_col2, #T_371dc_row60_col3, #T_371dc_row60_col4, #T_371dc_row60_col5, #T_371dc_row60_col6, #T_371dc_row61_col0, #T_371dc_row61_col1, #T_371dc_row61_col2, #T_371dc_row61_col3, #T_371dc_row61_col4, #T_371dc_row61_col5, #T_371dc_row61_col6, #T_371dc_row62_col0, #T_371dc_row62_col1, #T_371dc_row62_col2, #T_371dc_row62_col3, #T_371dc_row62_col4, #T_371dc_row62_col5, #T_371dc_row62_col6, #T_371dc_row63_col0, #T_371dc_row63_col1, #T_371dc_row63_col2, #T_371dc_row63_col3, #T_371dc_row63_col4, #T_371dc_row63_col5, #T_371dc_row63_col6 {
#   font-weight: bold;
# }
# #T_371dc_row64_col0, #T_371dc_row64_col1, #T_371dc_row64_col2, #T_371dc_row64_col3, #T_371dc_row64_col4, #T_371dc_row64_col5, #T_371dc_row64_col6, #T_371dc_row65_col0, #T_371dc_row65_col1, #T_371dc_row65_col2, #T_371dc_row65_col3, #T_371dc_row65_col4, #T_371dc_row65_col5, #T_371dc_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_371dc">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_371dc_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_371dc_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_371dc_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_371dc_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_371dc_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_371dc_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_371dc_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_371dc_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_371dc_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_371dc_row0_col2" class="data row0 col2" ></td>
#       <td id="T_371dc_row0_col3" class="data row0 col3" ></td>
#       <td id="T_371dc_row0_col4" class="data row0 col4" ></td>
#       <td id="T_371dc_row0_col5" class="data row0 col5" ></td>
#       <td id="T_371dc_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_371dc_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_371dc_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_371dc_row1_col3" class="data row1 col3" ></td>
#       <td id="T_371dc_row1_col4" class="data row1 col4" ></td>
#       <td id="T_371dc_row1_col5" class="data row1 col5" ></td>
#       <td id="T_371dc_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_371dc_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_371dc_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_371dc_row2_col3" class="data row2 col3" ></td>
#       <td id="T_371dc_row2_col4" class="data row2 col4" ></td>
#       <td id="T_371dc_row2_col5" class="data row2 col5" ></td>
#       <td id="T_371dc_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_371dc_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_371dc_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_371dc_row3_col3" class="data row3 col3" ></td>
#       <td id="T_371dc_row3_col4" class="data row3 col4" ></td>
#       <td id="T_371dc_row3_col5" class="data row3 col5" ></td>
#       <td id="T_371dc_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_371dc_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_371dc_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_371dc_row4_col3" class="data row4 col3" ></td>
#       <td id="T_371dc_row4_col4" class="data row4 col4" ></td>
#       <td id="T_371dc_row4_col5" class="data row4 col5" ></td>
#       <td id="T_371dc_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_371dc_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_371dc_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_371dc_row5_col3" class="data row5 col3" ></td>
#       <td id="T_371dc_row5_col4" class="data row5 col4" ></td>
#       <td id="T_371dc_row5_col5" class="data row5 col5" ></td>
#       <td id="T_371dc_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_371dc_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_371dc_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_371dc_row6_col3" class="data row6 col3" ></td>
#       <td id="T_371dc_row6_col4" class="data row6 col4" ></td>
#       <td id="T_371dc_row6_col5" class="data row6 col5" ></td>
#       <td id="T_371dc_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_371dc_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_371dc_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_371dc_row7_col3" class="data row7 col3" ></td>
#       <td id="T_371dc_row7_col4" class="data row7 col4" ></td>
#       <td id="T_371dc_row7_col5" class="data row7 col5" ></td>
#       <td id="T_371dc_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_371dc_row8_col0" class="data row8 col0" ></td>
#       <td id="T_371dc_row8_col1" class="data row8 col1" ></td>
#       <td id="T_371dc_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3-6 :  Interest

# %%
# Read the ref spending curve
sp = pd.read_excel('SFR_HTGR_data.xlsx', sheet_name = "Ref Spending Curve", nrows= 104, usecols='A : D')
Months = sp['Month'].tolist()
CDFs  = sp['CDF'].tolist()

annual_periods = np.linspace(12, 12*int(final_construction_duration/12),int(final_construction_duration/12))
if max(annual_periods) < int(final_construction_duration)-1:
    annual_periods_1= np.append( annual_periods, int(final_construction_duration)-1)

annual_cum_spend = []
for period in annual_periods_1:
    new_period = 103*period/int(final_construction_duration)
    annual_cum_spend.append(np.interp(new_period, Months, CDFs))
    
annual_cum_spend1 = np.append(annual_cum_spend[0], np.diff(annual_cum_spend ))
tot_overnight_cost = (Reactor_data_updated_8.loc[Reactor_data_updated_8.Title == 'Total Overnight Cost (Accounts 10 to 50)' , 'Total Cost (USD)']).values[0]


annual_loan_add =  annual_cum_spend1 *tot_overnight_cost

interest_exp = ((1+interest_rate)**((final_construction_duration -annual_periods_1)/12)) * annual_loan_add - annual_loan_add

tot_int_exp_construction = sum(interest_exp )

int_exp_startup = (tot_int_exp_construction + tot_overnight_cost)*((1+interest_rate)**(startup/12))-(tot_int_exp_construction + tot_overnight_cost)



db = pd.DataFrame()

db = Reactor_data_updated_8[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()
db.loc[db.Account == 62, 'Total Cost (USD)'] = None # clear old values

(db.loc[db.Account == 62, 'Total Cost (USD)']) = int_exp_startup +tot_int_exp_construction 


Reactor_data_updated_9 = update_high_level_costs(db)

Reactor_data_updated_9_ = pd.DataFrame()
Reactor_data_updated_9_ = Reactor_data_updated_9[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_9_pretty = prettify(Reactor_data_updated_9_, "Reactor-FOAK Capital Cost Summary - Updated ", 'no_subsidies')
Reactor_data_updated_9_pretty
# Out:
# <style type="text/css">
# #T_90396 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_90396_row0_col0, #T_90396_row0_col1, #T_90396_row0_col2, #T_90396_row0_col3, #T_90396_row0_col4, #T_90396_row0_col5, #T_90396_row0_col6, #T_90396_row12_col0, #T_90396_row12_col1, #T_90396_row12_col2, #T_90396_row12_col3, #T_90396_row12_col4, #T_90396_row12_col5, #T_90396_row12_col6, #T_90396_row29_col0, #T_90396_row29_col1, #T_90396_row29_col2, #T_90396_row29_col3, #T_90396_row29_col4, #T_90396_row29_col5, #T_90396_row29_col6, #T_90396_row39_col0, #T_90396_row39_col1, #T_90396_row39_col2, #T_90396_row39_col3, #T_90396_row39_col4, #T_90396_row39_col5, #T_90396_row39_col6, #T_90396_row47_col0, #T_90396_row47_col1, #T_90396_row47_col2, #T_90396_row47_col3, #T_90396_row47_col4, #T_90396_row47_col5, #T_90396_row47_col6, #T_90396_row51_col0, #T_90396_row51_col1, #T_90396_row51_col2, #T_90396_row51_col3, #T_90396_row51_col4, #T_90396_row51_col5, #T_90396_row51_col6, #T_90396_row52_col0, #T_90396_row52_col1, #T_90396_row52_col2, #T_90396_row52_col3, #T_90396_row52_col4, #T_90396_row52_col5, #T_90396_row52_col6, #T_90396_row53_col0, #T_90396_row53_col1, #T_90396_row53_col2, #T_90396_row53_col3, #T_90396_row53_col4, #T_90396_row53_col5, #T_90396_row53_col6, #T_90396_row54_col0, #T_90396_row54_col1, #T_90396_row54_col2, #T_90396_row54_col3, #T_90396_row54_col4, #T_90396_row54_col5, #T_90396_row54_col6, #T_90396_row55_col0, #T_90396_row55_col1, #T_90396_row55_col2, #T_90396_row55_col3, #T_90396_row55_col4, #T_90396_row55_col5, #T_90396_row55_col6, #T_90396_row56_col0, #T_90396_row56_col1, #T_90396_row56_col2, #T_90396_row56_col3, #T_90396_row56_col4, #T_90396_row56_col5, #T_90396_row56_col6, #T_90396_row57_col0, #T_90396_row57_col1, #T_90396_row57_col2, #T_90396_row57_col3, #T_90396_row57_col4, #T_90396_row57_col5, #T_90396_row57_col6, #T_90396_row58_col0, #T_90396_row58_col1, #T_90396_row58_col2, #T_90396_row58_col3, #T_90396_row58_col4, #T_90396_row58_col5, #T_90396_row58_col6, #T_90396_row59_col0, #T_90396_row59_col1, #T_90396_row59_col2, #T_90396_row59_col3, #T_90396_row59_col4, #T_90396_row59_col5, #T_90396_row59_col6, #T_90396_row60_col0, #T_90396_row60_col1, #T_90396_row60_col2, #T_90396_row60_col3, #T_90396_row60_col4, #T_90396_row60_col5, #T_90396_row60_col6, #T_90396_row61_col0, #T_90396_row61_col1, #T_90396_row61_col2, #T_90396_row61_col3, #T_90396_row61_col4, #T_90396_row61_col5, #T_90396_row61_col6, #T_90396_row62_col0, #T_90396_row62_col1, #T_90396_row62_col2, #T_90396_row62_col3, #T_90396_row62_col4, #T_90396_row62_col5, #T_90396_row62_col6, #T_90396_row63_col0, #T_90396_row63_col1, #T_90396_row63_col2, #T_90396_row63_col3, #T_90396_row63_col4, #T_90396_row63_col5, #T_90396_row63_col6 {
#   font-weight: bold;
# }
# #T_90396_row64_col0, #T_90396_row64_col1, #T_90396_row64_col2, #T_90396_row64_col3, #T_90396_row64_col4, #T_90396_row64_col5, #T_90396_row64_col6, #T_90396_row65_col0, #T_90396_row65_col1, #T_90396_row65_col2, #T_90396_row65_col3, #T_90396_row65_col4, #T_90396_row65_col5, #T_90396_row65_col6 {
#   font-weight: bold;
#   color: white;
#   background-color: white;
# }
# </style>
# <table id="T_90396">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_90396_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_90396_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_90396_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_90396_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_90396_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_90396_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_90396_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_90396_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_90396_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_90396_row0_col2" class="data row0 col2" ></td>
#       <td id="T_90396_row0_col3" class="data row0 col3" ></td>
#       <td id="T_90396_row0_col4" class="data row0 col4" ></td>
#       <td id="T_90396_row0_col5" class="data row0 col5" ></td>
#       <td id="T_90396_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_90396_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_90396_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_90396_row1_col3" class="data row1 col3" ></td>
#       <td id="T_90396_row1_col4" class="data row1 col4" ></td>
#       <td id="T_90396_row1_col5" class="data row1 col5" ></td>
#       <td id="T_90396_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_90396_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_90396_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_90396_row2_col3" class="data row2 col3" ></td>
#       <td id="T_90396_row2_col4" class="data row2 col4" ></td>
#       <td id="T_90396_row2_col5" class="data row2 col5" ></td>
#       <td id="T_90396_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_90396_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_90396_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_90396_row3_col3" class="data row3 col3" ></td>
#       <td id="T_90396_row3_col4" class="data row3 col4" ></td>
#       <td id="T_90396_row3_col5" class="data row3 col5" ></td>
#       <td id="T_90396_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_90396_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_90396_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_90396_row4_col3" class="data row4 col3" ></td>
#       <td id="T_90396_row4_col4" class="data row4 col4" ></td>
#       <td id="T_90396_row4_col5" class="data row4 col5" ></td>
#       <td id="T_90396_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_90396_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_90396_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_90396_row5_col3" class="data row5 col3" ></td>
#       <td id="T_90396_row5_col4" class="data row5 col4" ></td>
#       <td id="T_90396_row5_col5" class="data row5 col5" ></td>
#       <td id="T_90396_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_90396_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_90396_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_90396_row6_col3" class="data row6 col3" ></td>
#       <td id="T_90396_row6_col4" class="data row6 col4" ></td>
#       <td id="T_90396_row6_col5" class="data row6 col5" ></td>
#       <td id="T_90396_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_90396_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_90396_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_90396_row7_col3" class="data row7 col3" ></td>
#       <td id="T_90396_row7_col4" class="data row7 col4" ></td>
#       <td id="T_90396_row7_col5" class="data row7 col5" ></td>
#       <td id="T_90396_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_90396_row8_col0" class="data row8 col0" ></td>
#       <td id="T_90396_row8_col1" class="data row8 col1" ></td>
#       <td id="T_90396_row8_col2" class="data row8 col2" ></td>
#       <td id=

# %% [markdown]
# ### Section 3 - 8 :  ITC Subsidies

# %%
db1 = pd.DataFrame()
db1 = Reactor_data_updated_9[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

ITC_cost_reduction_factor = 0.9387*ITC- 0.0046

ITC_reduced_OCC =tot_overnight_cost - tot_overnight_cost*ITC_cost_reduction_factor



tot_cap_investment = db.loc[db.Title =='Total Capital Investment Cost (All Accounts)', 'Total Cost (USD)'].values



db1.loc[db1.Title== 'Total Capital Investment Cost - ITC reduced', 'Total Cost (USD)'] = None # clear old values
db1.loc[db1.Title== 'Total Capital Investment Cost - ITC reduced (US$/kWe)', 'Total Cost (USD)'] = None


db1.loc[db1.Title== 'Total Capital Investment Cost - ITC reduced', 'Total Cost (USD)'] = tot_cap_investment - tot_overnight_cost*ITC_cost_reduction_factor
 
db1.loc[db1.Title== 'Total Capital Investment Cost - ITC reduced (US$/kWe)', 'Total Cost (USD)'] = (db1.loc[db1.Title== 'Total Capital Investment Cost - ITC reduced', 'Total Cost (USD)'].values[0])/reactor_power


Reactor_data_updated_10 = update_high_level_costs(db1)

Reactor_data_updated_10_ = pd.DataFrame()
Reactor_data_updated_10_ = Reactor_data_updated_10[['Account', 'Title', 'Total Cost (USD)', 'Factory Equipment Cost', 'Site Labor Hours', 'Site Labor Cost',\
                 'Site Material Cost']].copy()

Reactor_data_updated_10_pretty = prettify(Reactor_data_updated_10_, "Reactor-FOAK Capital Cost Summary - Updated ", 'subsidies')
Reactor_data_updated_10_pretty
# Out:
# <style type="text/css">
# #T_74982 caption {
#   color: red;
#   font-size: 20px;
# }
# #T_74982_row0_col0, #T_74982_row0_col1, #T_74982_row0_col2, #T_74982_row0_col3, #T_74982_row0_col4, #T_74982_row0_col5, #T_74982_row0_col6, #T_74982_row12_col0, #T_74982_row12_col1, #T_74982_row12_col2, #T_74982_row12_col3, #T_74982_row12_col4, #T_74982_row12_col5, #T_74982_row12_col6, #T_74982_row29_col0, #T_74982_row29_col1, #T_74982_row29_col2, #T_74982_row29_col3, #T_74982_row29_col4, #T_74982_row29_col5, #T_74982_row29_col6, #T_74982_row39_col0, #T_74982_row39_col1, #T_74982_row39_col2, #T_74982_row39_col3, #T_74982_row39_col4, #T_74982_row39_col5, #T_74982_row39_col6, #T_74982_row47_col0, #T_74982_row47_col1, #T_74982_row47_col2, #T_74982_row47_col3, #T_74982_row47_col4, #T_74982_row47_col5, #T_74982_row47_col6, #T_74982_row51_col0, #T_74982_row51_col1, #T_74982_row51_col2, #T_74982_row51_col3, #T_74982_row51_col4, #T_74982_row51_col5, #T_74982_row51_col6, #T_74982_row52_col0, #T_74982_row52_col1, #T_74982_row52_col2, #T_74982_row52_col3, #T_74982_row52_col4, #T_74982_row52_col5, #T_74982_row52_col6, #T_74982_row53_col0, #T_74982_row53_col1, #T_74982_row53_col2, #T_74982_row53_col3, #T_74982_row53_col4, #T_74982_row53_col5, #T_74982_row53_col6, #T_74982_row54_col0, #T_74982_row54_col1, #T_74982_row54_col2, #T_74982_row54_col3, #T_74982_row54_col4, #T_74982_row54_col5, #T_74982_row54_col6, #T_74982_row55_col0, #T_74982_row55_col1, #T_74982_row55_col2, #T_74982_row55_col3, #T_74982_row55_col4, #T_74982_row55_col5, #T_74982_row55_col6, #T_74982_row56_col0, #T_74982_row56_col1, #T_74982_row56_col2, #T_74982_row56_col3, #T_74982_row56_col4, #T_74982_row56_col5, #T_74982_row56_col6, #T_74982_row57_col0, #T_74982_row57_col1, #T_74982_row57_col2, #T_74982_row57_col3, #T_74982_row57_col4, #T_74982_row57_col5, #T_74982_row57_col6, #T_74982_row58_col0, #T_74982_row58_col1, #T_74982_row58_col2, #T_74982_row58_col3, #T_74982_row58_col4, #T_74982_row58_col5, #T_74982_row58_col6, #T_74982_row59_col0, #T_74982_row59_col1, #T_74982_row59_col2, #T_74982_row59_col3, #T_74982_row59_col4, #T_74982_row59_col5, #T_74982_row59_col6, #T_74982_row60_col0, #T_74982_row60_col1, #T_74982_row60_col2, #T_74982_row60_col3, #T_74982_row60_col4, #T_74982_row60_col5, #T_74982_row60_col6, #T_74982_row61_col0, #T_74982_row61_col1, #T_74982_row61_col2, #T_74982_row61_col3, #T_74982_row61_col4, #T_74982_row61_col5, #T_74982_row61_col6, #T_74982_row62_col0, #T_74982_row62_col1, #T_74982_row62_col2, #T_74982_row62_col3, #T_74982_row62_col4, #T_74982_row62_col5, #T_74982_row62_col6, #T_74982_row63_col0, #T_74982_row63_col1, #T_74982_row63_col2, #T_74982_row63_col3, #T_74982_row63_col4, #T_74982_row63_col5, #T_74982_row63_col6, #T_74982_row64_col0, #T_74982_row64_col1, #T_74982_row64_col2, #T_74982_row64_col3, #T_74982_row64_col4, #T_74982_row64_col5, #T_74982_row64_col6, #T_74982_row65_col0, #T_74982_row65_col1, #T_74982_row65_col2, #T_74982_row65_col3, #T_74982_row65_col4, #T_74982_row65_col5, #T_74982_row65_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_74982">
#   <caption>Reactor-FOAK Capital Cost Summary - Updated </caption>
#   <thead>
#     <tr>
#       <th id="T_74982_level0_col0" class="col_heading level0 col0" >Account</th>
#       <th id="T_74982_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_74982_level0_col2" class="col_heading level0 col2" >Total Cost (USD)</th>
#       <th id="T_74982_level0_col3" class="col_heading level0 col3" >Factory Equipment Cost</th>
#       <th id="T_74982_level0_col4" class="col_heading level0 col4" >Site Labor Hours</th>
#       <th id="T_74982_level0_col5" class="col_heading level0 col5" >Site Labor Cost</th>
#       <th id="T_74982_level0_col6" class="col_heading level0 col6" >Site Material Cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_74982_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_74982_row0_col1" class="data row0 col1" >Capitalized Pre-Construction Costs</td>
#       <td id="T_74982_row0_col2" class="data row0 col2" ></td>
#       <td id="T_74982_row0_col3" class="data row0 col3" ></td>
#       <td id="T_74982_row0_col4" class="data row0 col4" ></td>
#       <td id="T_74982_row0_col5" class="data row0 col5" ></td>
#       <td id="T_74982_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_74982_row1_col1" class="data row1 col1" >Land & Land Rights</td>
#       <td id="T_74982_row1_col2" class="data row1 col2" >$ 11,000,000</td>
#       <td id="T_74982_row1_col3" class="data row1 col3" ></td>
#       <td id="T_74982_row1_col4" class="data row1 col4" ></td>
#       <td id="T_74982_row1_col5" class="data row1 col5" ></td>
#       <td id="T_74982_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_74982_row2_col1" class="data row2 col1" >Site Permits</td>
#       <td id="T_74982_row2_col2" class="data row2 col2" >$ 1,598,891</td>
#       <td id="T_74982_row2_col3" class="data row2 col3" ></td>
#       <td id="T_74982_row2_col4" class="data row2 col4" ></td>
#       <td id="T_74982_row2_col5" class="data row2 col5" ></td>
#       <td id="T_74982_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_74982_row3_col1" class="data row3 col1" >Plant Licensing</td>
#       <td id="T_74982_row3_col2" class="data row3 col2" >$ 24,382,988</td>
#       <td id="T_74982_row3_col3" class="data row3 col3" ></td>
#       <td id="T_74982_row3_col4" class="data row3 col4" ></td>
#       <td id="T_74982_row3_col5" class="data row3 col5" ></td>
#       <td id="T_74982_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_74982_row4_col1" class="data row4 col1" >Plant Permits</td>
#       <td id="T_74982_row4_col2" class="data row4 col2" >$ 12,679,167</td>
#       <td id="T_74982_row4_col3" class="data row4 col3" ></td>
#       <td id="T_74982_row4_col4" class="data row4 col4" ></td>
#       <td id="T_74982_row4_col5" class="data row4 col5" ></td>
#       <td id="T_74982_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_74982_row5_col1" class="data row5 col1" >Plant Studies</td>
#       <td id="T_74982_row5_col2" class="data row5 col2" >$ 12,679,167</td>
#       <td id="T_74982_row5_col3" class="data row5 col3" ></td>
#       <td id="T_74982_row5_col4" class="data row5 col4" ></td>
#       <td id="T_74982_row5_col5" class="data row5 col5" ></td>
#       <td id="T_74982_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_74982_row6_col1" class="data row6 col1" >Plant Reports</td>
#       <td id="T_74982_row6_col2" class="data row6 col2" >$ 3,972,186</td>
#       <td id="T_74982_row6_col3" class="data row6 col3" ></td>
#       <td id="T_74982_row6_col4" class="data row6 col4" ></td>
#       <td id="T_74982_row6_col5" class="data row6 col5" ></td>
#       <td id="T_74982_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row7_col0" class="data row7 col0" >18</td>
#       <td id="T_74982_row7_col1" class="data row7 col1" >Other Pre-Construction Costs</td>
#       <td id="T_74982_row7_col2" class="data row7 col2" >$ 12,679,167</td>
#       <td id="T_74982_row7_col3" class="data row7 col3" ></td>
#       <td id="T_74982_row7_col4" class="data row7 col4" ></td>
#       <td id="T_74982_row7_col5" class="data row7 col5" ></td>
#       <td id="T_74982_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <td id="T_74982_row8_col0" class="data row8 col0" ></td>
#       <td id="T_74982_row8_col1" class="data row8 col1" ></td>
#       <td id="T_74982_row8_col2" class="data row8 col2" ></td>
#       <td id="T_74982_row8_col3" class="data row8 col3" ></td>
#       <td id="T_7

# %%
x = 10*np.array([1 , 2])
x
# Out:
# array([10, 20])

# %%
 np.arange(2)
# Out:
# array([0, 1])
